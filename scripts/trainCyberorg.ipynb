# %%
import sys
sys.path.append('/home/zhx/word/DriverOrderOfflineRL/cage-challenge-1/CybORG')
sys.path.append('/home/zhx/word/DriverOrderOfflineRL/tianshou')

# %% [markdown]
# ### args define

# %%
import argparse
import datetime
import os
import pprint

import numpy as np
import torch
from torch.utils.tensorboard import SummaryWriter
from torch import nn

from tianshou.data import Collector, VectorReplayBuffer
from tianshou.policy import DQNPolicy
from tianshou.policy.modelbased.icm import ICMPolicy
from tianshou.trainer import offpolicy_trainer
from tianshou.utils import TensorboardLogger, WandbLogger
from tianshou.utils.net.discrete import IntrinsicCuriosityModule
from tianshou.env import SubprocVectorEnv

from typing import Any, Dict, Optional, Sequence, Tuple, Union


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--task", type=str, default="cyborg")
    parser.add_argument("--seed", type=int, default=0)
    parser.add_argument("--scale-obs", type=int, default=0)
    parser.add_argument("--eps-test", type=float, default=0.005)
    parser.add_argument("--eps-train", type=float, default=1.)
    parser.add_argument("--eps-train-final", type=float, default=0.05)
    parser.add_argument("--buffer-size", type=int, default=100000)
    parser.add_argument("--lr", type=float, default=0.0001)
    parser.add_argument("--gamma", type=float, default=0.99)
    parser.add_argument("--n-step", type=int, default=3)
    parser.add_argument("--target-update-freq", type=int, default=500)
    parser.add_argument("--epoch", type=int, default=10000)
    parser.add_argument("--step-per-epoch", type=int, default=1000)
    parser.add_argument("--step-per-collect", type=int, default=10)
    parser.add_argument("--update-per-step", type=float, default=0.1)
    parser.add_argument("--batch-size", type=int, default=64)
    parser.add_argument("--training-num", type=int, default=10)
    parser.add_argument("--test-num", type=int, default=10)
    parser.add_argument("--logdir", type=str, default="log")
    parser.add_argument("--render", type=float, default=0.)
    parser.add_argument(
        "--device", type=str, default="cuda" if torch.cuda.is_available() else "cpu"
    )
    parser.add_argument("--frames-stack", type=int, default=1)
    parser.add_argument("--resume-path", type=str, default=None)
    parser.add_argument("--resume-id", type=str, default=None)
    parser.add_argument(
        "--logger",
        type=str,
        default="wandb",
        choices=["tensorboard", "wandb"],
    )
    parser.add_argument("--wandb-project", type=str, default="cyborg.dqn")
    parser.add_argument(
        "--watch",
        default=False,
        action="store_true",
        help="watch the play of pre-trained policy only"
    )
    parser.add_argument("--save-buffer-name", type=str, default=None)
    parser.add_argument(
        "--icm-lr-scale",
        type=float,
        default=0.,
        help="use intrinsic curiosity module with this lr scale"
    )
    parser.add_argument(
        "--icm-reward-scale",
        type=float,
        default=0.01,
        help="scaling factor for intrinsic curiosity reward"
    )
    parser.add_argument(
        "--icm-forward-loss-weight",
        type=float,
        default=0.2,
        help="weight for the forward model loss in ICM"
    )
    return parser.parse_args(args=[])
# Out:
# /home/zhx/miniconda3/envs/tianshou/lib/python3.11/site-packages/wandb/sdk/launch/builder/build.py:11: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %% [markdown]
# ### env

# %%
args = get_args()

# %%
import inspect
from pprint import pprint
from CybORG import CybORG
from CybORG.Shared.Actions import *
from CybORG.Agents import RedMeanderAgent, B_lineAgent
from CybORG.Agents.Wrappers import *

path = str(inspect.getfile(CybORG))
path = path[:-10] + '/Shared/Scenarios/Scenario1b.yaml'

# seed
np.random.seed(args.seed)
torch.manual_seed(args.seed)

# env
CYBORG = CybORG(path,'sim', agents={'Red': B_lineAgent})
env = ChallengeWrapper(env=CYBORG, agent_name="Blue", max_steps=args.step_per_epoch)
train_envs = SubprocVectorEnv([lambda: ChallengeWrapper(env=CybORG(path,'sim', agents={'Red': B_lineAgent}), 
                                                        agent_name="Blue", max_steps=args.step_per_epoch) for _ in range(1)])
test_envs = SubprocVectorEnv([lambda: ChallengeWrapper(env=CybORG(path,'sim', agents={'Red': B_lineAgent}), 
                                                       agent_name="Blue", max_steps=args.step_per_epoch) for _ in range(1)])

# %%
args.state_shape = env.observation_space.shape or env.observation_space.n
args.action_shape = env.action_space.shape or env.action_space.n
print("Observations shape:", args.state_shape)
print("Actions shape:", args.action_shape)
# Out:
# Observations shape: (52,)
# Actions shape: 54

# %% [markdown]
# ### network

# %%
class DQN(nn.Module):
    """Reference: Human-level control through deep reinforcement learning.

    For advanced usage (how to customize the network), please refer to
    :ref:`build_the_network`.
    """

    def __init__(
        self,
        state_shape: Sequence[int],
        action_shape: Sequence[int],
        device: Union[str, int, torch.device] = "cpu",
        features_only: bool = False,
        output_dim: Optional[int] = None,
    ) -> None:
        super().__init__()
        self.device = device
        self.net = nn.Sequential(
            nn.Linear(state_shape, 512), nn.ReLU(inplace=True),
            nn.Linear(512, action_shape), nn.ReLU(inplace=True)
        )
#         with torch.no_grad():
#             self.output_dim = np.prod(self.net(torch.zeros(1, state_shape)).shape[1:])
#         if not features_only:
#             self.net = nn.Sequential(
#                 self.net, nn.Linear(self.output_dim, 512), nn.ReLU(inplace=True),
#                 nn.Linear(512, np.prod(action_shape))
#             )
#             self.output_dim = np.prod(action_shape)
#         elif output_dim is not None:
#             self.net = nn.Sequential(
#                 self.net, nn.Linear(self.output_dim, output_dim),
#                 nn.ReLU(inplace=True)
#             )
#             self.output_dim = output_dim

    def forward(
        self,
        obs: Union[np.ndarray, torch.Tensor],
        state: Optional[Any] = None,
        info: Dict[str, Any] = {},
    ) -> Tuple[torch.Tensor, Any]:
        r"""Mapping: s -> Q(s, \*)."""
        obs = torch.as_tensor(obs, device=self.device, dtype=torch.float32)
        return self.net(obs), state

# %% [markdown]
# ### define policy

# %%
# define model
net = DQN(args.state_shape[0], args.action_shape, args.device).to(args.device)
optim = torch.optim.Adam(net.parameters(), lr=args.lr)
# define policy
policy = DQNPolicy(
    net,
    optim,
    args.gamma,
    args.n_step,
    target_update_freq=args.target_update_freq
)

# %%
if args.icm_lr_scale > 0:
    feature_net = DQN(
        args.state_shape[0], args.action_shape, args.device, features_only=True
    )
    action_dim = np.prod(args.action_shape)
    feature_dim = feature_net.output_dim
    icm_net = IntrinsicCuriosityModule(
        feature_net.net,
        feature_dim,
        action_dim,
        hidden_sizes=[512],
        device=args.device
    )
    icm_optim = torch.optim.Adam(icm_net.parameters(), lr=args.lr)
    policy = ICMPolicy(
        policy, icm_net, icm_optim, args.icm_lr_scale, args.icm_reward_scale,
        args.icm_forward_loss_weight
    ).to(args.device)

# %% [markdown]
# ### load policy

# %%
# load a previous policy
if args.resume_path:
    policy.load_state_dict(torch.load(args.resume_path, map_location=args.device))
    print("Loaded agent from: ", args.resume_path)

# %% [markdown]
# ### replay buffer

# %%
# replay buffer: `save_last_obs` and `stack_num` can be removed together
# when you have enough RAM
buffer = VectorReplayBuffer(
    args.buffer_size,
    buffer_num=len(train_envs),
    ignore_obs_next=False,
    save_only_last_obs=False,
    stack_num=args.frames_stack
)

# %% [markdown]
# ### collector

# %%
# collector
train_collector = Collector(policy, train_envs, buffer, exploration_noise=True)
test_collector = Collector(policy, test_envs, exploration_noise=True)

# %% [markdown]
# ### log

# %%
# log
now = datetime.datetime.now().strftime("%y%m%d-%H%M%S")
args.algo_name = "dqn_icm" if args.icm_lr_scale > 0 else "dqn"
log_name = os.path.join(args.task, args.algo_name, str(args.seed), now)
log_path = os.path.join(args.logdir, log_name)

# %%
# logger
if args.logger == "wandb":
    logger = WandbLogger(
        save_interval=1,
        name=log_name.replace(os.path.sep, "__"),
        run_id=args.resume_id,
        config=args,
        project=args.wandb_project,
    )
writer = SummaryWriter(log_path)
writer.add_text("args", str(args))
if args.logger == "tensorboard":
    logger = TensorboardLogger(writer)
else:  # wandb
    logger.load(writer)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: hongxi. Use `wandb login --relogin` to force relogin
# /home/zhx/miniconda3/envs/tianshou/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/zhx/word/DriverOrderOfflineRL/scripts/wandb/run-20231115_093827-ygelf9x5</code>
# Syncing run <strong><a href='https://wandb.ai/hongxi/cyborg.dqn/runs/ygelf9x5' target="_blank">cyborg__dqn__0__231115-093823</a></strong> to <a href='https://wandb.ai/hongxi/cyborg.dqn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hongxi/cyborg.dqn' target="_blank">https://wandb.ai/hongxi/cyborg.dqn</a>
#  View run at <a href='https://wandb.ai/hongxi/cyborg.dqn/runs/ygelf9x5' target="_blank">https://wandb.ai/hongxi/cyborg.dqn/runs/ygelf9x5</a>

# %% [markdown]
# ### train helper funciton

# %%
def save_best_fn(policy):
    torch.save(policy.state_dict(), os.path.join(log_path, "policy.pth"))

def stop_fn(mean_rewards):
    return mean_rewards >= 0

def train_fn(epoch, env_step):
    # nature DQN setting, linear decay in the first 1M steps
    if env_step <= 1e6:
        eps = args.eps_train - env_step / 1e6 * \
            (args.eps_train - args.eps_train_final)
    else:
        eps = args.eps_train_final
    policy.set_eps(eps)
    if env_step % 1000 == 0:
        logger.write("train/env_step", env_step, {"train/eps": eps})

def test_fn(epoch, env_step):
    policy.set_eps(args.eps_test)

def save_checkpoint_fn(epoch, env_step, gradient_step):
    # see also: https://pytorch.org/tutorials/beginner/saving_loading_models.html
    ckpt_path = os.path.join(log_path, "checkpoint.pth")
    torch.save({"model": policy.state_dict()}, ckpt_path)
    return ckpt_path

# watch agent's performance
def watch():
    print("Setup test envs ...")
    policy.eval()
    policy.set_eps(args.eps_test)
    test_envs.seed(args.seed)
    if args.save_buffer_name:
        print(f"Generate buffer with size {args.buffer_size}")
        buffer = VectorReplayBuffer(
            args.buffer_size,
            buffer_num=len(test_envs),
            ignore_obs_next=True,
            save_only_last_obs=True,
            stack_num=args.frames_stack
        )
        collector = Collector(policy, test_envs, buffer, exploration_noise=True)
        result = collector.collect(n_step=args.buffer_size)
        print(f"Save buffer into {args.save_buffer_name}")
        # Unfortunately, pickle will cause oom with 1M buffer size
        buffer.save_hdf5(args.save_buffer_name)
    else:
        print("Testing agent ...")
        test_collector.reset()
        result = test_collector.collect(
            n_episode=args.test_num, render=args.render
        )
    rew = result["rews"].mean()
    print(f"Mean reward (over {result['n/ep']} episodes): {rew}")

# %%
### train core

# %%
if args.watch:
    watch()
    exit(0)

# test train_collector and start filling replay buffer
train_collector.collect(n_step=args.batch_size * args.training_num)
# trainer
result = offpolicy_trainer(
    policy,
    train_collector,
    test_collector,
    args.epoch,
    args.step_per_epoch,
    args.step_per_collect,
    args.test_num,
    args.batch_size,
    train_fn=train_fn,
    test_fn=test_fn,
    stop_fn=stop_fn,
    save_best_fn=save_best_fn,
    logger=logger,
    update_per_step=args.update_per_step,
    test_in_train=False,
    resume_from_log=args.resume_id is not None,
    save_checkpoint_fn=save_checkpoint_fn,
)

pprint.pprint(result)
watch()
# Out:
# Epoch #1: 1001it [06:57,  2.40it/s, env_step=1000, len=0, loss=1002.911, n/ep=0, n/st=10, rew=0.00]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.

# %% [markdown]
# ### keyboard agent envTest

# %%
from CybORG import CybORG
import inspect

from CybORG.Agents.SimpleAgents.BlueMonitorAgent import BlueMonitorAgent
from CybORG.Agents.SimpleAgents.KeyboardAgent import KeyboardAgent
from CybORG.Agents.Wrappers.RedTableWrapper import RedTableWrapper

print("Setup")
path = str(inspect.getfile(CybORG))
path = path[:-10] + '/Shared/Scenarios/Scenario1b.yaml'

cyborg = RedTableWrapper(env=CybORG(path, 'sim',agents={'Blue':BlueMonitorAgent}), output_mode='table')
agent_name = 'Red'

results = cyborg.reset(agent=agent_name)
observation = results.observation
action_space = results.action_space

agent = KeyboardAgent()

reward = 0
done = False
while True:
    action = agent.get_action(observation, action_space)
    results = cyborg.step(agent=agent_name, action=action)

    reward += results.reward
    observation = results.observation
    action_space = results.action_space
    if done:
        print(f"Game Over. Total reward: {reward}")
        break
# Out:
# Setup
#
# ************************************ Turn 1: Observation *************************************
#
# +----------------+-------------+----------+---------+------------+
# |     Subnet     |  IP Address | Hostname | Scanned |   Access   |
# +----------------+-------------+----------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |  User0   |  False  | Privileged |
# +----------------+-------------+----------+---------+------------+
#
# ********************************* Turn 1: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 1: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 2: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 2: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 2: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.119.82
# 1 10.0.119.94
# 2 10.0.119.92
# 3 10.0.119.88
# 4 10.0.119.85
# You chose 10.0.119.85.
#
# ************************************ Turn 3: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 3: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 3: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.119.82
# 1 10.0.119.94
# 2 10.0.119.92
# 3 10.0.119.88
# 4 10.0.119.85
# You chose 10.0.119.88.
#
# ************************************ Turn 4: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# The action failed!
# **********************************************************************************************
#
# ********************************* Turn 4: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 4: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.119.82
# 1 10.0.119.94
# 2 10.0.119.92
# 3 10.0.119.88
# 4 10.0.119.85
# You chose 10.0.119.85.
#
# ************************************ Turn 5: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 5: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 5: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 6: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 6: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 6: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 7: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 7: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 7: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 8: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 8: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 8: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 9: Observation *************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 9: Command Selection **********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 9: Parameter Selection *********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.119.82
# 1 10.0.119.94
# 2 10.0.119.92
# 3 10.0.119.88
# 4 10.0.119.85
# You chose 10.0.119.88.
#
# ************************************ Turn 10: Observation ************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 | UNKNOWN_HOST: 2 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 10: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 10: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.119.82
# 1 10.0.119.94
# 2 10.0.119.92
# 3 10.0.119.88
# 4 10.0.119.85
# You chose 10.0.119.88.
#
# ************************************ Turn 11: Observation ************************************
#
# +----------------+-------------+-----------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname    | Scanned |   Access   |
# +----------------+-------------+-----------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0      |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# | 10.0.119.80/28 | 10.0.119.88 |      User3      |   True  |    User    |
# | 10.0.119.80/28 | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# | 10.0.119.80/28 | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# +----------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 11: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose PrivilegeEscalate.
#
#
# ******************************** Turn 11: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 User0
# 1 User3
# Choose a number in range.....
# You chose User3.
#
# ************************************ Turn 12: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 12: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 12: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.85.
#
# ************************************ Turn 13: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 13: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 13: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.85.
#
# ************************************ Turn 14: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 | UNKNOWN_HOST: 3 |   True  |    None    |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 14: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 14: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.85.
#
# ************************************ Turn 15: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 15: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 15: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 16: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 16: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 16: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 17: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 17: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 17: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# Automatically choosing 10.0.119.80/28 as it is the only option.
#
# ************************************ Turn 18: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |  False  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 18: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 18: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.92.
#
# ************************************ Turn 19: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 | UNKNOWN_HOST: 1 |   True  |    None    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 19: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 19: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.92.
#
# ************************************ Turn 20: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  |    User    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 20: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 20: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.94.
#
# ************************************ Turn 21: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  |    User    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |   True  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 21: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 21: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.94.
#
# ************************************ Turn 22: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  |    User    |
# |   10.0.119.80/28  | 10.0.119.94 | UNKNOWN_HOST: 0 |   True  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 22: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 22: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.119.82
# 2 10.0.119.94
# 3 10.0.119.92
# 4 10.0.119.88
# 5 10.0.119.85
# You chose 10.0.119.94.
#
# ************************************ Turn 23: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  |    User    |
# |   10.0.119.80/28  | 10.0.119.94 |      User1      |   True  |    User    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 23: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose PrivilegeEscalate.
#
#
# ******************************** Turn 23: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 User0
# 1 User1
# 2 User2
# 3 User3
# 4 User4
# You chose User2.
#
# ************************************ Turn 24: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.94 |      User1      |   True  |    User    |
# | UNKNOWN_SUBNET: 6 | 10.0.16.125 | UNKNOWN_HOST: 7 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 24: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 24: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.16.125
# 2 10.0.119.82
# 3 10.0.119.94
# 4 10.0.119.92
# 5 10.0.119.88
# 6 10.0.119.85
# You chose 10.0.119.94.
#
# ************************************ Turn 25: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.94 |      User1      |   True  |    User    |
# | UNKNOWN_SUBNET: 6 | 10.0.16.125 | UNKNOWN_HOST: 7 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# The action failed!
# **********************************************************************************************
#
# ********************************* Turn 25: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose ExploitRemoteService.
#
#
# ******************************** Turn 25: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.126
# 1 10.0.16.125
# 2 10.0.119.82
# 3 10.0.119.94
# 4 10.0.119.92
# 5 10.0.119.88
# 6 10.0.119.85
# You chose 10.0.119.94.
#
# ************************************ Turn 26: Observation ************************************
#
# +-------------------+-------------+-----------------+---------+------------+
# |       Subnet      |  IP Address |     Hostname    | Scanned |   Access   |
# +-------------------+-------------+-----------------+---------+------------+
# |   10.0.119.80/28  | 10.0.119.82 |      User0      |  False  | Privileged |
# |   10.0.119.80/28  | 10.0.119.85 |      User4      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.88 |      User3      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.92 |      User2      |   True  | Privileged |
# |   10.0.119.80/28  | 10.0.119.94 |      User1      |   True  |    User    |
# | UNKNOWN_SUBNET: 6 | 10.0.16.125 | UNKNOWN_HOST: 7 |  False  |    None    |
# | UNKNOWN_SUBNET: 4 | 10.0.16.126 | UNKNOWN_HOST: 5 |  False  |    None    |
# +-------------------+-------------+-----------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 26: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose PrivilegeEscalate.
#
#
# ******************************** Turn 26: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 User0
# 1 User1
# 2 User2
# 3 User3
# 4 User4
# You chose User1.
#
# ...
# | UNKNOWN_SUBNET: 10 | 10.0.16.126 | Enterprise0 |   True  | Privileged |
# +--------------------+-------------+-------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Outcome of action is unknown...
# **********************************************************************************************
#
# ********************************* Turn 41: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose Impact.
#
#
# ******************************** Turn 41: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 Enterprise0
# 1 Enterprise1
# 2 User0
# 3 User1
# 4 User2
# 5 User3
# 6 User4
# You chose Enterprise0.
#
# ************************************ Turn 42: Observation ************************************
#
# +--------------------+-------------+-------------+---------+------------+
# |       Subnet       |  IP Address |   Hostname  | Scanned |   Access   |
# +--------------------+-------------+-------------+---------+------------+
# |   10.0.119.80/28   | 10.0.119.82 |    User0    |  False  | Privileged |
# |   10.0.119.80/28   | 10.0.119.85 |    User4    |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.88 |    User3    |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.92 |    User2    |   True  |    User    |
# |   10.0.119.80/28   | 10.0.119.94 |    User1    |   True  | Privileged |
# | UNKNOWN_SUBNET: 8  | 10.0.16.125 | Enterprise1 |   True  | Privileged |
# | UNKNOWN_SUBNET: 10 | 10.0.16.126 | Enterprise0 |   True  | Privileged |
# +--------------------+-------------+-------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# The action failed!
# **********************************************************************************************
#
# ********************************* Turn 42: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose Impact.
#
#
# ******************************** Turn 42: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 Enterprise0
# 1 Enterprise1
# 2 User0
# 3 User1
# 4 User2
# 5 User3
# 6 User4
# You chose User2.
#
# ************************************ Turn 43: Observation ************************************
#
# +--------------------+-------------+-------------+---------+------------+
# |       Subnet       |  IP Address |   Hostname  | Scanned |   Access   |
# +--------------------+-------------+-------------+---------+------------+
# |   10.0.119.80/28   | 10.0.119.82 |    User0    |  False  | Privileged |
# |   10.0.119.80/28   | 10.0.119.85 |    User4    |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.88 |    User3    |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.92 |    User2    |   True  |    User    |
# |   10.0.119.80/28   | 10.0.119.94 |    User1    |   True  | Privileged |
# | UNKNOWN_SUBNET: 8  | 10.0.16.125 | Enterprise1 |   True  | Privileged |
# | UNKNOWN_SUBNET: 10 | 10.0.16.126 | Enterprise0 |   True  | Privileged |
# +--------------------+-------------+-------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# The action failed!
# **********************************************************************************************
#
# ********************************* Turn 43: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose PrivilegeEscalate.
#
#
# ******************************** Turn 43: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 Enterprise0
# 1 Enterprise1
# 2 User0
# 3 User1
# 4 User2
# 5 User3
# 6 User4
# You chose User2.
#
# ************************************ Turn 44: Observation ************************************
#
# +--------------------+-------------+------------------+---------+------------+
# |       Subnet       |  IP Address |     Hostname     | Scanned |   Access   |
# +--------------------+-------------+------------------+---------+------------+
# |   10.0.119.80/28   | 10.0.119.82 |      User0       |  False  | Privileged |
# |   10.0.119.80/28   | 10.0.119.85 |      User4       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.88 |      User3       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.92 |      User2       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.94 |      User1       |   True  | Privileged |
# | UNKNOWN_SUBNET: 12 | 10.0.16.125 | UNKNOWN_HOST: 13 |   True  | Privileged |
# | UNKNOWN_SUBNET: 10 | 10.0.16.126 |   Enterprise0    |   True  | Privileged |
# +--------------------+-------------+------------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 44: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose PrivilegeEscalate.
#
#
# ******************************** Turn 44: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------- Hostname Selection -------------------------------------
# 0 Enterprise0
# 1 Enterprise1
# 2 User0
# 3 User1
# 4 User2
# 5 User3
# 6 User4
# You chose User2.
#
# ************************************ Turn 45: Observation ************************************
#
# +--------------------+-------------+------------------+---------+------------+
# |       Subnet       |  IP Address |     Hostname     | Scanned |   Access   |
# +--------------------+-------------+------------------+---------+------------+
# |   10.0.119.80/28   | 10.0.119.82 |      User0       |  False  | Privileged |
# |   10.0.119.80/28   | 10.0.119.85 |      User4       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.88 |      User3       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.92 |      User2       |   True  | Privileged |
# |   10.0.119.80/28   | 10.0.119.94 |      User1       |   True  | Privileged |
# | UNKNOWN_SUBNET: 14 | 10.0.16.125 | UNKNOWN_HOST: 15 |   True  | Privileged |
# | UNKNOWN_SUBNET: 10 | 10.0.16.126 |   Enterprise0    |   True  | Privileged |
# +--------------------+-------------+------------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 45: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverRemoteSystems.
#
#
# ******************************** Turn 45: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# -------------------------------------- Subnet Selection --------------------------------------
# 0 10.0.16.112/28
# 1 10.0.119.80/28
# You chose 10.0.16.112/28.
#
# ************************************ Turn 46: Observation ************************************
#
# +----------------+-------------+------------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname     | Scanned |   Access   |
# +----------------+-------------+------------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0       |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 |      User4       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.88 |      User3       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.92 |      User2       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.94 |      User1       |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.116 | UNKNOWN_HOST: 16 |  False  |    None    |
# | 10.0.16.112/28 | 10.0.16.117 | UNKNOWN_HOST: 17 |  False  |    None    |
# | 10.0.16.112/28 | 10.0.16.125 | UNKNOWN_HOST: 15 |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.126 |   Enterprise0    |   True  | Privileged |
# +----------------+-------------+------------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 46: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose DiscoverNetworkServices.
#
#
# ******************************** Turn 46: Parameter Selection ********************************
#
#
# ------------------------------------- Session Selection --------------------------------------
# Automatically choosing 0 as it is the only option.
# -------------------------------------- Agent Selection ---------------------------------------
# Automatically choosing Red as it is the only option.
# ------------------------------------ Ip_address Selection ------------------------------------
# 0 10.0.16.117
# 1 10.0.16.126
# 2 10.0.16.125
# 3 10.0.16.116
# 4 10.0.119.82
# 5 10.0.119.94
# 6 10.0.119.92
# 7 10.0.119.88
# 8 10.0.119.85
# You chose 10.0.16.117.
#
# ************************************ Turn 47: Observation ************************************
#
# +----------------+-------------+------------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname     | Scanned |   Access   |
# +----------------+-------------+------------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0       |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 |      User4       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.88 |      User3       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.92 |      User2       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.94 |      User1       |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.116 | UNKNOWN_HOST: 16 |  False  |    None    |
# | 10.0.16.112/28 | 10.0.16.117 | UNKNOWN_HOST: 17 |   True  |    None    |
# | 10.0.16.112/28 | 10.0.16.125 | UNKNOWN_HOST: 15 |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.126 |   Enterprise0    |   True  | Privileged |
# +----------------+-------------+------------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Yay! The Action was a Success!
# **********************************************************************************************
#
# ********************************* Turn 47: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You chose Sleep.
#
#
# ******************************** Turn 47: Parameter Selection ********************************
#
#
#
# ************************************ Turn 48: Observation ************************************
#
# +----------------+-------------+------------------+---------+------------+
# |     Subnet     |  IP Address |     Hostname     | Scanned |   Access   |
# +----------------+-------------+------------------+---------+------------+
# | 10.0.119.80/28 | 10.0.119.82 |      User0       |  False  | Privileged |
# | 10.0.119.80/28 | 10.0.119.85 |      User4       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.88 |      User3       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.92 |      User2       |   True  | Privileged |
# | 10.0.119.80/28 | 10.0.119.94 |      User1       |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.116 | UNKNOWN_HOST: 16 |  False  |    None    |
# | 10.0.16.112/28 | 10.0.16.117 | UNKNOWN_HOST: 17 |   True  |    None    |
# | 10.0.16.112/28 | 10.0.16.125 | UNKNOWN_HOST: 15 |   True  | Privileged |
# | 10.0.16.112/28 | 10.0.16.126 |   Enterprise0    |   True  | Privileged |
# +----------------+-------------+------------------+---------+------------+
# ----------------------------------------------------------------------------------------------
# Outcome of action is unknown...
# **********************************************************************************************
#
# ********************************* Turn 48: Command Selection *********************************
#
# 0 Sleep
# 1 DiscoverRemoteSystems
# 2 DiscoverNetworkServices
# 3 ExploitRemoteService
# 4 PrivilegeEscalate
# 5 Impact
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
# You didn't type in a valid Command...
