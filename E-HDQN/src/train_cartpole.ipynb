# %% [markdown]
# ## memory

# %%
import numpy as np
import collections

class Memory:
    def __init__(self, max_memory):
        self.max_memory = max_memory
        self.state = []
        self.new_state = []
        self.action = []
        self.reward = []
        self.is_terminal = []
        self.idx = 0

    def __len__(self):
        return len(self.state)

    def store_transition(self, s, s1, a, r, is_terminal):
        if len(self.state) <= self.max_memory:
            self.state.append(s)
            self.new_state.append(s1)
            self.action.append(a)
            self.reward.append(r)
            self.is_terminal.append(is_terminal)
        else:
            self.state[self.idx] = s
            self.new_state[self.idx] = s1
            self.action[self.idx] = a
            self.reward[self.idx] = r
            self.is_terminal[self.idx] = is_terminal
            self.idx = (self.idx + 1) % self.max_memory
        assert len(self.state) == len(self.new_state) == len(self.reward) == len(self.is_terminal) == len(self.action)


    def clear_memory(self):
        del self.state[:]
        del self.new_state[:]
        del self.action[:]
        del self.reward[:]
        del self.is_terminal[:]

    def sample(self, bs):
        idx = np.random.randint(len(self.state), size=bs)
        state, new_state, action, reward, is_terminal = [], [], [], [], []
        for i in idx:
            state.append(self.state[i])
            new_state.append(self.new_state[i])
            action.append(self.action[i])
            reward.append(self.reward[i])
            is_terminal.append(int(self.is_terminal[i]))
        return state, new_state, action, reward, is_terminal

    def update(self, **kwargs):
        pass

# %% [markdown]
# ## model DQN

# %%
import numpy as np
import torch
from rl.model import DDQN_Model, ICM_Model
from rl.per import PERMemory
from torch.nn.functional import mse_loss, cross_entropy, smooth_l1_loss, softmax
import settings as sett
import itertools
import os


class DQN:
    def __init__(self, state_dim, tau, action_dim, gamma, hidd_ch, lam, lr,
                 eps_sub, eps_sub_decay, beta, bs, target_interval, train_steps, max_memory,
                 conv, reward_rescale, n_proc, per=False, norm_input=True, logger=None):
        """
        :param state_dim: Shape of the state
        :param float tau: Weight for agent loss
        :param int action_dim: Number of actions
        :param float gamma: Discount for sub controller
        :param int hidd_ch: Number of hidden channels
        :param float lam: Scaler for ICM reward
        :param float lr: Learning rate
        :param float eps_sub: Eps greedy change for sub policies
        :param float eps_sub_decay: Epsilon decay for sub policy computed as eps * (1 - eps_decay) each step
        :param float beta: Weight for loss of fwd net vs inv net
        :param int bs: Batch size
        :param int target_interval: Number of train steps between target updates
        :param int train_steps: Number of training iterations for each call
        :param int max_memory: Max memory
        :param bool conv: Use or not convolutional networks
        :param bool per: Use or not prioritized experience replay
        """

        # Parameters
        self.logger = logger
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.target_interval = target_interval
        self.lr = lr
        self.bs = bs
        # policy parameters
        self.tau = tau
        self.eps_sub = eps_sub
        self.eps_sub_decay = 1 - eps_sub_decay
        self.gamma = gamma
        # ICM parameters
        self.beta = beta
        self.lam = lam

        self.n_proc = n_proc
        self.train_steps = train_steps
        self.reward_rescale = reward_rescale
        self.norm_input = norm_input
        self.per = per
        self.target_count = 0

        if self.per:
            memory = PERMemory
        else:
            memory = Memory

        # Create Policies / ICM modules / Memories
        self.agent = DDQN_Model(self.state_dim, self.action_dim, hidd_ch)
        self.agent_target = DDQN_Model(self.state_dim, self.action_dim, hidd_ch)
        self.agent_target.update_target(self.agent)
        self.agent_memory = memory(max_memory)
        self.agent_opt = torch.optim.Adam(self.agent.parameters(), lr=self.lr)
        self.icm = ICM_Model(self.state_dim, self.action_dim, conv).to(sett.device)
        self.icm_opt = torch.optim.Adam(self.icm.parameters(), lr=1e-3)

        # Send macro to correct device
        self.agent = self.agent.to(sett.device)
        self.agent_target = self.agent_target.to(sett.device)

    def act(self, obs, deterministic=False):
        x = torch.from_numpy(obs).float().to(sett.device)
        if self.norm_input:
            x /= 255

        eps = max(0.01, self.eps_sub) if not deterministic else 0.01
        actions = self.agent.act(x, eps=eps)
        return actions

    def set_mode(self, training=False):
        self.agent.train(training)

    def process_reward(self, reward):
        # Rescale reward if a scaling is provided
        if self.reward_rescale != 0:
            if self.reward_rescale == 1:
                reward = np.sign(reward)
            elif self.reward_rescale == 2:
                reward = np.clip(reward, -1, 1)
            else:
                reward *= self.reward_rescale
        return reward

    def save(self, i):
        if not os.path.isdir(sett.SAVEPATH):
            os.makedirs(sett.SAVEPATH)
        torch.save(self.agent.state_dict(), os.path.join(sett.SAVEPATH, 'agent_%s.pth' % i))

    def load(self, path, i):
        self.agent.load_state_dict(torch.load(os.path.join(path, 'agent_%s.pth' % i), map_location=sett.device))

    def store_transition(self, s, s1, a, reward, is_terminal):
        reward = self.process_reward(reward)
        self.agent_memory.store_transition(s, s1, a, reward, is_terminal)
#         for i in range(len(s)):
#             self.agent_memory.store_transition(s[i], s1[i], a[i], reward[i], is_terminal[i])

    def update(self):
        for i in range(self.train_steps):
            self._update()
            if self.logger is not None:
                self.logger.step += 1

    def _update(self):
        # First train each sub policy
        i = 0
        memory = self.agent_memory
        if len(memory) < self.bs * 10:
            return

        policy = self.agent
        target = self.agent_target
        icm = self.icm
        policy_opt = self.agent_opt
        icm_opt = self.icm_opt

        if self.per:
            state, new_state, action, reward, is_terminal, idxs, w_is = memory.sample(self.bs)
            reduction = 'none'
            self.logger.log_scalar(tag='Beta PER %i' % i, value=memory.beta)
        else:
            state, new_state, action, reward, is_terminal = memory.sample(self.bs)
            reduction = 'mean'

        if self.norm_input:
            state = np.array(state, dtype=np.float) / 255
            new_state = np.array(new_state, dtype=np.float) / 255

        state = torch.tensor(np.stack(state), dtype=torch.float).detach().to(sett.device)
        new_state = torch.tensor(np.stack(new_state), dtype=torch.float).detach().to(sett.device)
        action = torch.tensor(action).detach().to(sett.device)
        reward = torch.tensor(reward, dtype=torch.float).detach().to(sett.device)
        is_terminal = 1. - torch.tensor(is_terminal, dtype=torch.float).detach().to(sett.device)

        # Augment rewards with curiosity
        # curiosity_rewards = icm.curiosity_rew(state, new_state, action)
        # reward = (1 - 0.01) * reward + 0.01 * self.lam * curiosity_rewards
        reward = reward

        # Policy loss
        q = policy.forward(state)[torch.arange(self.bs), action]
        max_action = torch.argmax(policy.forward(new_state), dim=1)
        y = reward + self.gamma * target.forward(new_state)[torch.arange(self.bs), max_action] * is_terminal
        policy_loss = smooth_l1_loss(input=q, target=y.detach(), reduction=reduction).mean(-1)

        # ICM Loss
        # phi_hat = icm.forward(state, action)
        # phi_true = icm.phi_state(new_state)
        # fwd_loss = mse_loss(input=phi_hat, target=phi_true.detach(), reduction=reduction).mean(-1)
        # a_hat = icm.inverse_pred(state, new_state)
        # inv_loss = cross_entropy(input=a_hat, target=action.detach(), reduction=reduction)

        # Total loss
        # inv_loss = (1 - self.beta) * inv_loss
        # fwd_loss = self.beta * fwd_loss * 288
        # loss = self.tau * policy_loss + inv_loss + fwd_loss
        loss = policy_loss

        policy_opt.zero_grad()
        # icm_opt.zero_grad()
        loss.backward()
        for param in policy.parameters():
            param.grad.data.clamp(-1, 1)
        policy_opt.step()
        # icm_opt.step()

        self.target_count += 1
        if self.target_count == self.target_interval:
            self.target_count = 0
            self.agent_target.update_target(self.agent)

        print('Policy Loss %i' % i, policy_loss.mean().cpu().data.numpy())
#         print('ICM Fwd Loss %i' % i, fwd_loss.mean().cpu().data.numpy())
#         print('ICM Inv Loss %i' % i, inv_loss.mean().cpu().data.numpy())
#         print('Total Policy Loss %i' % i, loss.mean().cpu().data.numpy())
#         print('Mean Curiosity Reward %i' % i, curiosity_rewards.mean().cpu().data.numpy())
        # print('Q values %i' % i, q.mean().cpu().data.numpy())
#         print('Target Boltz %i' % i, y.mean().cpu().data.numpy())

        # Reduce sub eps
        self.eps_sub = self.eps_sub * self.eps_sub_decay

        
import torch
from torch import nn
import torch.nn.functional as F
import numpy as np
import settings as sett


class DDQN_Model(nn.Module):
    def __init__(self, state_size, action_size, conv, macro=None, hidd_ch=256, conv_ch=32):
        super(DDQN_Model, self).__init__()
        self.action_size = action_size
        self.hidd_ch = hidd_ch
        state_size = 16
        if macro is None:
            self.backbone = nn.Sequential(
                nn.Linear(16, 256),
                nn.ReLU(),
            )


        self.features = nn.Sequential(
            nn.Linear(256, hidd_ch),
            nn.ReLU(),
            #nn.Linear(hidd_ch, hidd_ch),
            #nn.ReLU()
        )

        out_shape = hidd_ch
        self.lstm_out = nn.LSTM(out_shape, hidd_ch, 1, batch_first=True)

        self.advantage = nn.Sequential(
            nn.Linear(hidd_ch, self.action_size)
        )

        self.value = nn.Sequential(
            nn.Linear(hidd_ch, 1)
        )

    def forward(self, obs, macro=None):
        obs = obs.view(-1, 16).float()
        backbone = self.backbone if macro is None else macro.backbone
        x = self.features(backbone(obs))
        x = x.view(x.size(0), -1)

        h0 = torch.zeros(1, self.hidd_ch).to(sett.device)
        c0 = torch.zeros(1, self.hidd_ch).to(sett.device)

        lstm_out, (hn, cn) = self.lstm_out(x, (h0.detach(), c0.detach()))
        x = lstm_out
        adv = self.advantage(x)
        value = self.value(x)
        return value + (adv - adv.mean(-1, keepdim=True))

    def act(self, state, eps, backbone=None):
        if np.random.random() > eps:
            q = self.forward(state, backbone)
            action = torch.argmax(q, dim=-1).cpu().data.numpy()
        else:
            action = np.random.randint(self.action_size, size=1)
        return action.item() if action.shape == (1,) else list(action.astype(np.int64))

    def update_target(self, model):
        self.load_state_dict(model.state_dict())


class ICM_Model(nn.Module):
    def __init__(self, state_size, action_size, conv):
        super(ICM_Model, self).__init__()

        self.action_size = action_size
        self.state_size = 16

        self.phi = nn.Sequential(
            nn.Linear(16, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU()
        )

        out_shape = self.phi(torch.randn(*((1,) + tuple([self.state_size])))).view(-1).size().numel()

        # Forward Model
        self.fwd = nn.Sequential(
            nn.Linear(out_shape + 1, 256),
            nn.ReLU(),
            nn.Linear(256, out_shape)
        )

        # Inverse Model
        self.inv = nn.Sequential(
            nn.Linear(out_shape * 2, 256),
            nn.ELU(),
            nn.Linear(256, action_size)
        )

    def forward(self, *input):
        obs, action = input
        action = action.view(-1, 1)
        phi = self.phi_state(obs)
        x = torch.cat((phi, action.float()), -1)
        phi_hat = self.fwd(x)
        return phi_hat

    def phi_state(self, s):
        s = s.view(-1, 16)
        x = s
        x = self.phi(x)
        return x.view(x.size(0), -1)

    def inverse_pred(self, s, s1):
        s = self.phi_state(s.view(-1, 16).float())
        s1 = self.phi_state(s1.view(-1, 16).float())
        x = torch.cat((s, s1), -1)
        return self.inv(x)

    def curiosity_rew(self, s, s1, a):
        phi_hat = self.forward(s.view(-1, 16), a)
        phi_s1 = self.phi_state(s1.view(-1, 16))
        cur_rew = 1 / 2 * (torch.norm(phi_hat - phi_s1, p=2, dim=-1) ** 2)
        return cur_rew

# %% [markdown]
# ## wrapper

# %%
import numpy as np
from gym import Wrapper
from gym.spaces import Box


class TimeLimit(Wrapper):
    def __init__(self, env, max_episode_steps=None):
        super(TimeLimit, self).__init__(env)
        self.max_episode_steps = max_episode_steps
        self._max_episode_steps = max_episode_steps
        self._elapsed_steps = None

    def step(self, action):
        observation, reward, done, _, info = self.env.step(action)
        self._elapsed_steps += 1
        if self._elapsed_steps >= self._max_episode_steps:
            done = True
        return observation, reward, done, info

    def reset(self, **kwargs):
        self._elapsed_steps = 0
        obs, info = self.env.reset(**kwargs)
        return obs

    from collections import deque
import numpy as np

from gym.spaces import Box
from gym import ObservationWrapper
from collections import deque


class LazyFrames(object):
    r"""Ensures common frames are only stored once to optimize memory use. 

    To further reduce the memory use, it is optionally to turn on lz4 to 
    compress the observations.

    .. note::

        This object should only be converted to numpy array just before forward pass. 

    """
    def __init__(self, frames, lz4_compress=False):
        if lz4_compress:
            from lz4.block import compress
            self.shape = frames[0].shape
            self.dtype = frames[0].dtype
            frames = [compress(frame) for frame in frames]
        self._frames = frames
        self.lz4_compress = lz4_compress

    def __array__(self, dtype=None):
        if self.lz4_compress:
            from lz4.block import decompress
            frames = [np.frombuffer(decompress(frame), dtype=self.dtype).reshape(self.shape) for frame in self._frames]
        else:
            frames = self._frames
        out = np.stack(frames, axis=0)
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self.__array__())

    def __getitem__(self, i):
        return self.__array__()[i]


class FrameStack(ObservationWrapper):
    r"""Observation wrapper that stacks the observations in a rolling manner. 

    For example, if the number of stacks is 4, then the returned observation contains
    the most recent 4 observations. For environment 'Pendulum-v0', the original observation
    is an array with shape [3], so if we stack 4 observations, the processed observation
    has shape [3, 4]. 

    .. note::

        To be memory efficient, the stacked observations are wrapped by :class:`LazyFrame`.

    .. note::

        The observation space must be `Box` type. If one uses `Dict`
        as observation space, it should apply `FlattenDictWrapper` at first. 

    Example::

        >>> import gym
        >>> env = gym.make('PongNoFrameskip-v0')
        >>> env = FrameStack(env, 4)
        >>> env.observation_space
        Box(4, 210, 160, 3)

    Args:
        env (Env): environment object
        num_stack (int): number of stacks

    """
    def __init__(self, env, num_stack, lz4_compress=False):
        super(FrameStack, self).__init__(env)
        self.num_stack = num_stack
        self.lz4_compress = lz4_compress

        self.frames = deque(maxlen=num_stack)

        low = np.repeat(self.observation_space.low[np.newaxis, ...], num_stack, axis=0)
        high = np.repeat(self.observation_space.high[np.newaxis, ...], num_stack, axis=0)
        self.observation_space = Box(low=low, high=high, dtype=self.observation_space.dtype)

    def _get_observation(self):
        assert len(self.frames) == self.num_stack, (len(self.frames), self.num_stack)
        return LazyFrames(list(self.frames), self.lz4_compress)

    def step(self, action):
        observation, reward, done, info = self.env.step(action)
        self.frames.append(observation)
        return self._get_observation(), reward, done, info

    def reset(self, **kwargs):
        observation = self.env.reset(**kwargs)
        [self.frames.append(observation) for _ in range(self.num_stack)]
        return self._get_observation()

# %% [markdown]
# ## env

# %%
from gym import Env
import numpy as np
from gym import error, spaces, utils
from gym.utils import seeding
import logging
import gym

logger = logging.getLogger(__name__)


class DimGridEnvironment(Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, size, hard):
        super(DimGridEnvironment, self).__init__()
        self.size = size
        self.observation_space = spaces.Box(0, 1, [self.size, self.size, 1])
        self.action_space = spaces.Discrete(5)
        self.alternate_dim = False
        self.dim0 = None
        self.dim1 = None
        self.dict = {'0': {'empty': 0, 'wall': 0.33, 'player': 0.66, 'goal': 1},
                     '1': {'empty': 1, 'wall': 0.66, 'player': 0.33, 'goal': 0}}
        self.action_dict = {0: [0, -1], 1: [-1, 0], 2: [0, 1], 3: [1, 0], 4: 4}
        self.goal = None
        self.player_pos = None
        self.walls = None
        self.hard = hard
        self.seed = self._seed()

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return seed

    def _compute_action(self, action):
        action = self.action_dict[action]
        reward = 0.

        if action == 4: # Change dimension
            self.alternate_dim = not self.alternate_dim
        else:
            new_pos = tuple(np.array(self.player_pos) + action)
            if any(np.array(new_pos) == self.size) or any(np.array(new_pos) < 0):
                reward = -1. if not self.hard else 0.
                return reward, True
            self.player_pos = new_pos
            touched_wall = self.walls[self.player_pos]
            if self.alternate_dim:
                reward += -0.1
            else:
                if touched_wall:
                    reward += -0.5
                    if self.hard:
                        return 0., True

        terminal = True if self.player_pos == self.goal else False
        reward += int(terminal)
        return reward, terminal

    def step(self, action):
        reward, terminal = self._compute_action(action)
        obs = self._get_obs()
        return obs, reward, terminal, {}

    def _get_obs(self):
        if self.alternate_dim:
            self.dim1[self.walls] = self.dict['1']['wall']
            self.dim1[self.player_pos] = self.dict['1']['player']
            return self.dim1
        else:
            self.dim0[self.walls] = self.dict['0']['wall']
            self.dim0[self.player_pos] = self.dict['0']['player']
            return self.dim0

    def reset(self):
        y = np.random.choice(self.size, 2, replace=False)
        x = np.random.choice(self.size, 2, replace=False)
        self.player_pos = tuple([x[0], y[0]])
        self.goal = tuple([x[1], y[1]])

        # Fill dim0
        self.dim0 = np.zeros(self.observation_space.shape)
        self.walls = np.random.rand(*self.observation_space.shape) > 0.5
        self.dim0[self.walls] = self.dict['0']['wall']
        self.dim0[self.goal] = self.dict['0']['goal']
        self.dim0[self.player_pos] = self.dict['0']['player']

        # Fill dim1
        self.dim1 = np.ones(self.observation_space.shape)
        self.dim1[self.walls] = self.dict['1']['wall']
        self.dim1[self.goal] = self.dict['1']['goal']
        self.dim1[self.player_pos] = self.dict['1']['player']

        self.walls[self.goal] = False
        self.walls[self.player_pos] = False
        self.alternate_dim = False
        return self._get_obs()

    def render(self, mode='human', close=False):
        logger.info('\n Dim0: %s \n Dim1:  %s' % (self.dim0, self.dim1))

# %% [markdown]
# ## core

# %%
# Setup env
env = gym.make('CartPole-v1')
env = TimeLimit(env, max_episode_steps=500)
env = FrameStack(env, num_stack=4)

# %%
obs = env.reset()

# Setup Model
n_actions = env.action_space.n if env.action_space.shape == () else env.action_space.shape[0]
n_state = env.observation_space.n if env.observation_space.shape == () else env.observation_space.shape
print('n_actions', n_actions)
print('n_state', n_state)

conv = True if isinstance(n_state, tuple) else False
conv = False
print('conv', conv)
# Out:
# n_actions 2
# n_state (4, 4)
# conv False

# %%
dqn = DQN(state_dim=16,
          tau=0.001,
          action_dim=n_actions,
          gamma=0.95,
          hidd_ch=256,
          lam=0.001,
          lr=1e-4,
          eps_sub=0.3,
          eps_sub_decay=0.99,
          beta=0.9,
          bs=128,
          target_interval=500,
          train_steps=100,
          max_memory=1_000_000,
          conv=conv,
          per=None,
          n_proc=1,
          reward_rescale=False,
          logger=None,
          norm_input=False
          )

# %%
np.array(obs).reshape(-1)
# Out:
# array([ 0.02023707,  0.00398971, -0.01783948,  0.03999455,  0.02023707,
#         0.00398971, -0.01783948,  0.03999455,  0.02023707,  0.00398971,
#        -0.01783948,  0.03999455,  0.02023707,  0.00398971, -0.01783948,
#         0.03999455], dtype=float32)

# %%
obs = env.reset()
action = dqn.act(np.array(obs).reshape(-1))
obs_new, r, is_terminal, info = env.step(action)
dqn.store_transition(np.array(obs).reshape(-1), np.array(obs_new).reshape(-1), action, r, is_terminal)

# %%
dqn.set_mode(training=False)
obs = env.reset()
for i in range(10000):
    action = dqn.act(np.array(obs).reshape(-1))
    obs_new, r, is_terminal, info = env.step(action)
    dqn.store_transition(np.array(obs).reshape(-1), np.array(obs_new).reshape(-1), action, r, is_terminal)
dqn.set_mode(training=True)
for i in range(20):
    dqn.update()
# Out:
# Policy Loss 0 1.067291e-06
# Policy Loss 0 1.0020274e-06
# Policy Loss 0 8.5314923e-07
# Policy Loss 0 6.591175e-07
# Policy Loss 0 4.2861856e-07
# Policy Loss 0 2.403263e-07
# Policy Loss 0 1.0364546e-07
# Policy Loss 0 2.6760471e-08
# Policy Loss 0 1.6230556e-08
# Policy Loss 0 5.470515e-08
# Policy Loss 0 0.00556058
# Policy Loss 0 1.6511335e-08
# Policy Loss 0 0.003904133
# Policy Loss 0 3.2504875e-07
# Policy Loss 0 8.8912196e-07
# Policy Loss 0 1.5690571e-06
# Policy Loss 0 2.094006e-06
# Policy Loss 0 0.0038910685
# Policy Loss 0 3.3232363e-06
# Policy Loss 0 4.1507046e-06
# Policy Loss 0 4.38384e-06
# Policy Loss 0 4.1402136e-06
# Policy Loss 0 3.5246371e-06
# Policy Loss 0 2.6851558e-06
# Policy Loss 0 1.7465337e-06
# Policy Loss 0 9.783969e-07
# Policy Loss 0 3.9638584e-07
# Policy Loss 0 0.0043577626
# Policy Loss 0 4.887206e-08
# Policy Loss 0 3.202905e-08
# Policy Loss 0 2.698442e-08
# Policy Loss 0 1.2307253e-08
# Policy Loss 0 0.0039057825
# Policy Loss 0 5.725028e-08
# Policy Loss 0 1.9479197e-07
# Policy Loss 0 3.8527787e-07
# Policy Loss 0 5.4008467e-07
# Policy Loss 0 6.4682143e-07
# Policy Loss 0 6.6682003e-07
# Policy Loss 0 6.296504e-07
# Policy Loss 0 5.339342e-07
# Policy Loss 0 4.0845407e-07
# Policy Loss 0 2.7391255e-07
# Policy Loss 0 1.6183964e-07
# Policy Loss 0 7.1617194e-08
# Policy Loss 0 3.3951597e-08
# Policy Loss 0 1.910736e-08
# Policy Loss 0 3.9318444e-08
# Policy Loss 0 0.01012803
# Policy Loss 0 6.4195416e-07
# Policy Loss 0 5.290425e-07
# Policy Loss 0 1.1950449e-06
# Policy Loss 0 1.8257972e-06
# Policy Loss 0 2.3359296e-06
# Policy Loss 0 2.6086534e-06
# Policy Loss 0 2.57069e-06
# Policy Loss 0 0.0055403244
# Policy Loss 0 2.6885805e-06
# Policy Loss 0 2.726742e-06
# Policy Loss 0 2.6250418e-06
# Policy Loss 0 2.1868213e-06
# Policy Loss 0 1.6727954e-06
# Policy Loss 0 1.1117584e-06
# Policy Loss 0 6.039586e-07
# Policy Loss 0 2.5973955e-07
# Policy Loss 0 6.647575e-08
# Policy Loss 0 2.8036265e-08
# Policy Loss 0 1.11490685e-07
# Policy Loss 0 2.6839683e-07
# Policy Loss 0 4.27394e-07
# Policy Loss 0 5.592425e-07
# Policy Loss 0 6.429292e-07
# Policy Loss 0 6.392361e-07
# Policy Loss 0 5.843099e-07
# Policy Loss 0 4.699883e-07
# Policy Loss 0 3.6128816e-07
# Policy Loss 0 2.2957298e-07
# Policy Loss 0 1.2402847e-07
# Policy Loss 0 5.201727e-08
# Policy Loss 0 2.2704553e-08
# Policy Loss 0 0.0044384375
# Policy Loss 0 2.2566016e-07
# Policy Loss 0 6.539092e-07
# Policy Loss 0 1.14098e-06
# Policy Loss 0 1.4994084e-06
# Policy Loss 0 1.7494406e-06
# Policy Loss 0 1.8547506e-06
# Policy Loss 0 1.6960555e-06
# Policy Loss 0 1.3931776e-06
# Policy Loss 0 1.0434235e-06
# Policy Loss 0 6.644515e-07
# Policy Loss 0 3.6520805e-07
# Policy Loss 0 1.4454746e-07
# Policy Loss 0 4.5077055e-08
# Policy Loss 0 6.5551393e-07
# Policy Loss 0 9.035581e-08
# Policy Loss 0 1.8419881e-07
# Policy Loss 0 2.8905845e-07
# Policy Loss 0 3.688193e-07
# Policy Loss 0 4.041214e-07
# Policy Loss 0 4.1042935e-07
# Policy Loss 0 3.734226e-07
# Policy Loss 0 3.1162955e-07
# Policy Loss 0 2.2883067e-07
# Policy Loss 0 1.4656794e-07
# Policy Loss 0 8.1511544e-08
# Policy Loss 0 4.0271633e-08
# Policy Loss 0 2.2524553e-08
# Policy Loss 0 3.5470602e-08
# Policy Loss 0 4.2917712e-08
# Policy Loss 0 7.253445e-08
# Policy Loss 0 7.564999e-08
# Policy Loss 0 9.707153e-08
# Policy Loss 0 1.0759159e-07
# Policy Loss 0 1.04729544e-07
# Policy Loss 0 8.752363e-08
# Policy Loss 0 7.160236e-08
# Policy Loss 0 4.9111254e-08
# Policy Loss 0 3.4779106e-08
# Policy Loss 0 0.0039048006
# Policy Loss 0 1.3235221e-07
# Policy Loss 0 3.1029828e-07
# Policy Loss 0 4.994471e-07
# Policy Loss 0 6.2038896e-07
# Policy Loss 0 7.061619e-07
# Policy Loss 0 7.277407e-07
# Policy Loss 0 6.667432e-07
# Policy Loss 0 5.319888e-07
# Policy Loss 0 0.0049172333
# Policy Loss 0 6.3439296e-07
# Policy Loss 0 7.8267124e-07
# Policy Loss 0 8.9603714e-07
# Policy Loss 0 8.8200403e-07
# Policy Loss 0 7.942176e-07
# Policy Loss 0 1.2577667e-06
# Policy Loss 0 4.7443834e-07
# Policy Loss 0 2.933844e-07
# Policy Loss 0 0.0048409705
# Policy Loss 0 8.3494876e-07
# Policy Loss 0 3.7018927e-07
# Policy Loss 0 0.004789621
# Policy Loss 0 9.233126e-07
# Policy Loss 0 1.4101778e-06
# Policy Loss 0 2.298707e-06
# Policy Loss 0 1.8877934e-06
# Policy Loss 0 1.8495587e-06
# Policy Loss 0 1.6073745e-06
# Policy Loss 0 1.3244148e-06
# Policy Loss 0 0.0049296124
# Policy Loss 0 1.0402223e-06
# Policy Loss 0 1.0829133e-06
# Policy Loss 0 1.0144151e-06
# Policy Loss 0 8.457548e-07
# Policy Loss 0 6.283457e-07
# Policy Loss 0 4.2092046e-07
# Policy Loss 0 2.3372166e-07
# Policy Loss 0 1.106017e-07
# Policy Loss 0 3.1431377e-08
# Policy Loss 0 5.6736866e-08
# Policy Loss 0 6.0271006e-08
# Policy Loss 0 0.009419866
# Policy Loss 0 4.0331713e-08
# Policy Loss 0 0.005623239
# Policy Loss 0 2.145005e-06
# Policy Loss 0 3.1473517e-06
# Policy Loss 0 4.5917395e-06
# Policy Loss 0 5.769464e-06
# Policy Loss 0 6.052912e-06
# Policy Loss 0 5.6805443e-06
# Policy Loss 0 4.9714336e-06
# Policy Loss 0 3.875308e-06
# Policy Loss 0 2.478798e-06
# Policy Loss 0 1.4416156e-06
# Policy Loss 0 0.0054014036
# Policy Loss 0 4.824126e-07
# Policy Loss 0 3.0869114e-07
# Policy Loss 0 1.5701646e-07
# Policy Loss 0 6.883892e-07
# Policy Loss 0 1.5470373e-08
# Policy Loss 0 2.9065498e-08
# Policy Loss 0 6.403735e-08
# Policy Loss 0 9.867108e-08
# Policy Loss 0 1.5738927e-07
# Policy Loss 0 1.8908827e-07
# Policy Loss 0 2.065459e-07
# Policy Loss 0 2.0812877e-07
# Policy Loss 0 1.8602228e-07
# Policy Loss 0 1.437777e-07
# Policy Loss 0 1.00542756e-07
# Policy Loss 0 6.766801e-08
# Policy Loss 0 3.7378975e-08
# Policy Loss 0 2.0241188e-08
# Policy Loss 0 1.834941e-08
# Policy Loss 0 1.500625e-08
# Policy Loss 0 2.1048784e-08
# Policy Loss 0 3.4435192e-08
# Policy Loss 0 4.3105707e-08
# Policy Loss 0 5.1784426e-08
# Policy Loss 0 0.005316279
# Policy Loss 0 2.4927084e-07
# Policy Loss 0 5.5127936e-07
# Policy Loss 0 7.917064e-07
# Policy Loss 0 1.0222864e-06
# Policy Loss 0 1.1416007e-06
# Policy Loss 0 1.1263065e-06
# Policy Loss 0 9.757791e-07
# Policy Loss 0 7.497144e-07
# Policy Loss 0 0.005125231
# Policy Loss 0 1.3894281e-06
# Policy Loss 0 8.686287e-07
# Policy Loss 0 8.976238e-07
# Policy Loss 0 8.1752444e-07
# Policy Loss 0 6.8635836e-07
# Policy Loss 0 5.369028e-07
# Policy Loss 0 3.499461e-07
# Policy Loss 0 0.005219399
# Policy Loss 0 3.0307308e-07
# Policy Loss 0 4.264603e-07
# Policy Loss 0 4.895971e-07
# Policy Loss 0 4.947093e-07
# Policy Loss 0 4.6613206e-07
# Policy Loss 0 3.8688302e-07
# Policy Loss 0 2.7767445e-07
# Policy Loss 0 1.7881985e-07
# Policy Loss 0 9.901986e-08
# Policy Loss 0 4.502531e-08
# Policy Loss 0 1.4842291e-08
# Policy Loss 0 1.3649775e-08
# Policy Loss 0 2.7448806e-08
# Policy Loss 0 5.463953e-08
# Policy Loss 0 9.260029e-08
# Policy Loss 0 1.1006463e-07
# Policy Loss 0 1.2260449e-07
# Policy Loss 0 7.370626e-07
# Policy Loss 0 1.19195086e-07
# Policy Loss 0 9.312467e-08
# Policy Loss 0 7.300115e-08
# Policy Loss 0 5.746613e-08
# Policy Loss 0 3.4089005e-08
# Policy Loss 0 1.5073912e-08
# Policy Loss 0 1.3091131e-08
# Policy Loss 0 1.4451047e-08
# Policy Loss 0 1.8053724e-08
# Policy Loss 0 2.4608312e-08
# Policy Loss 0 2.7893918e-08
# Policy Loss 0 3.2941998e-08
# Policy Loss 0 3.4776264e-08
# Policy Loss 0 3.7652992e-08
# Policy Loss 0 3.2366568e-08
# Policy Loss 0 2.788918e-08
# Policy Loss 0 2.095408e-08
# Policy Loss 0 5.4097825e-07
# Policy Loss 0 1.9322911e-08
# Policy Loss 0 1.061229e-08
# Policy Loss 0 1.0552485e-08
# Policy Loss 0 2.1991575e-08
# Policy Loss 0 1.1874732e-08
# Policy Loss 0 1.3014265e-08
# Policy Loss 0 0.005680885
# Policy Loss 0 6.31423e-08
# Policy Loss 0 2.354421e-07
# Policy Loss 0 4.5210408e-07
# Policy Loss 0 6.7298856e-07
# Policy Loss 0 8.368881e-07
# Policy Loss 0 8.657242e-07
# Policy Loss 0 8.3665554e-07
# Policy Loss 0 7.170329e-07
# Policy Loss 0 5.552299e-07
# Policy Loss 0 3.6669968e-07
# Policy Loss 0 2.1597927e-07
# Policy Loss 0 1.0073689e-07
# Policy Loss 0 2.996499e-08
# Policy Loss 0 1.42762495e-08
# Policy Loss 0 4.5851188e-08
# Policy Loss 0 8.67294e-08
# Policy Loss 0 1.326158e-07
# Policy Loss 0 1.7550339e-07
# Policy Loss 0 2.0464351e-07
# Policy Loss 0 2.0614615e-07
# Policy Loss 0 1.9100335e-07
# Policy Loss 0 1.6725303e-07
# Policy Loss 0 1.2233264e-07
# Policy Loss 0 8.347854e-08
# Policy Loss 0 4.6027715e-08
# Policy Loss 0 2.1231575e-08
# Policy Loss 0 1.4467059e-08
# Policy Loss 0 5.039718e-07
# Policy Loss 0 1.9126759e-08
# Policy Loss 0 3.4278642e-08
# Policy Loss 0 4.365652e-08
# Policy Loss 0 5.732241e-08
# Policy Loss 0 5.8651764e-08
# Policy Loss 0 0.00533187
# Policy Loss 0 2.7071926e-07
# Policy Loss 0 5.534723e-07
# Policy Loss 0 8.161458e-07
# Policy Loss 0 1.019679e-06
# Policy Loss 0 1.0748681e-06
# Policy Loss 0 1.0977394e-06
# Policy Loss 0 9.2783694e-07
# Policy Loss 0 6.98535e-07
# Policy Loss 0 4.9671695e-07
# Policy Loss 0 2.7893867e-07
# Policy Loss 0 1.284581e-07
# Policy Loss 0 0.0053568543
# Policy Loss 0 1.0364583e-07
# Policy Loss 0 1.6469863e-07
# Policy Loss 0 2.3066369e-07
# Policy Loss 0 2.6474032e-07
# Policy Loss 0 0.004673625
# Policy Loss 0 6.30629e-07
# Policy Loss 0 1.0117126e-06
# Policy Loss 0 1.3133467e-06
# Policy Loss 0 1.4854957e-06
# Policy Loss 0 1.4652312e-06
# Policy Loss 0 1.3131795e-06
# Policy Loss 0 1.0364265e-06
# Policy Loss 0 7.235535e-07
# Policy Loss 0 4.4356824e-07
# Policy Loss 0 2.0827979e-07
# Policy Loss 0 6.148969e-08
# Policy Loss 0 1.5001248e-08
# Policy Loss 0 3.9469107e-08
# Policy Loss 0 1.1710324e-07
# Policy Loss 0 2.1335717e-07
# Policy Loss 0 2.8794648e-07
# Policy Loss 0 3.5623543e-07
# Policy Loss 0 3.6881715e-07
# Policy Loss 0 3.5827264e-07
# Policy Loss 0 2.958408e-07
# Policy Loss 0 2.1945156e-07
# Policy Loss 0 1.5592315e-07
# Policy Loss 0 8.585798e-08
# Policy Loss 0 4.2793864e-08
# Policy Loss 0 1.951441e-08
# Policy Loss 0 0.0048349304
# Policy Loss 0 1.8803186e-07
# Policy Loss 0 5.6746256e-07
# Policy Loss 0 0.0038964362
# Policy Loss 0 2.2040997e-06
# Policy Loss 0 3.3149295e-06
# Policy Loss 0 4.196325e-06
# Policy Loss 0 4.5200077e-06
# Policy Loss 0 4.1836124e-06
# Policy Loss 0 0.005666604
# Policy Loss 0 0.0047516203
# Policy Loss 0 4.8967972e-06
# Policy Loss 0 5.4936872e-06
# Policy Loss 0 5.483979e-06
# Policy Loss 0 4.6137193e-06
# Policy Loss 0 3.8019461e-06
# Policy Loss 0 2.6308492e-06
# Policy Loss 0 0.005474223
# Policy Loss 0 1.3480287e-06
# Policy Loss 0 1.0425663e-06
# Policy Loss 0 0.010992189
# Policy Loss 0 1.443808e-06
# Policy Loss 0 2.0858765e-06
# Policy Loss 0 2.7374872e-06
# Policy Loss 0 2.9085563e-06
# Policy Loss 0 0.0051947194
# Policy Loss 0 3.5407256e-06
# Policy Loss 0 0.0048975386
# Policy Loss 0 5.070695e-06
# Policy Loss 0 0.005552415
# Policy Loss 0 6.7046376e-06
# Policy Loss 0 7.2249786e-06
# Policy Loss 0 7.211046e-06
# Policy Loss 0 6.3068132e-06
# Policy Loss 0 4.954747e-06
# Policy Loss 0 3.4480213e-06
# Policy Loss 0 1.9740417e-06
# Policy Loss 0 8.9689337e-07
# Policy Loss 0 2.734527e-07
# Policy Loss 0 4.5968378e-08
# Policy Loss 0 1.8277447e-07
# Policy Loss 0 5.5233625e-07
# Policy Loss 0 1.0176204e-06
# Policy Loss 0 0.0049557746
# Policy Loss 0 1.0243742e-06
# Policy Loss 0 6.307772e-07
# Policy Loss 0 3.1674693e-07
# Policy Loss 0 1.0980709e-07
# Policy Loss 0 2.7767852e-08
# Policy Loss 0 4.3475104e-08
# Policy Loss 0 6.532933e-07
# Policy Loss 0 2.678935e-07
# Policy Loss 0 3.8884775e-07
# Policy Loss 0 4.555885e-07
# Policy Loss 0 5.033314e-07
# Policy Loss 0 4.7564313e-07
# Policy Loss 0 4.1399207e-07
# Policy Loss 0 3.2085464e-07
# Policy Loss 0 2.2835087e-07
# Policy Loss 0 1.3959271e-07
# Policy Loss 0 7.690077e-08
# Policy Loss 0 4.3255017e-08
# Policy Loss 0 2.4964983e-08
# Policy Loss 0 3.637144e-08
# Policy Loss 0 5.984161e-08
# Policy Loss 0 6.04414e-07
# Policy Loss 0 1.1860883e-07
# Policy Loss 0 1.2210984e-07
# Policy Loss 0 1.3539584e-07
# Policy Loss 0 0.004742298
# Policy Loss 0 1.9072903e-08
# Policy Loss 0 1.1300622e-07
# Policy Loss 0 3.2422543e-07
# Policy Loss 0 5.3444006e-07
# Policy Loss 0 7.6462976e-07
# Policy Loss 0 9.206334e-07
# Policy Loss 0 9.695443e-07
# Policy Loss 0 8.976251e-07
# Policy Loss 0 0.005334123
# Policy Loss 0 1.1154096e-06
# Policy Loss 0 1.3160918e-06
# Policy Loss 0 1.4205311e-06
# Policy Loss 0 1.4180489e-06
# Policy Loss 0 1.1799e-06
# Policy Loss 0 9.14958e-07
# Policy Loss 0 6.036019e-07
# Policy Loss 0 3.5240566e-07
# Policy Loss 0 1.6128928e-07
# Policy Loss 0 4.4452953e-08
# Policy Loss 0 2.535743e-08
# Policy Loss 0 5.599113e-08
# Policy Loss 0 1.3264889e-07
# Policy Loss 0 0.0052104876
# Policy Loss 0 0.0051465137
# Policy Loss 0 9.0122114e-08
# Policy Loss 0 5.329629e-07
# Policy Loss 0 1.1700822e-06
# Policy Loss 0 1.8395867e-06
# Policy Loss 0 2.322967e-06
# Policy Loss 0 2.5435525e-06
# Policy Loss 0 0.00481107
# Policy Loss 0 0.003890457
# Policy Loss 0 4.68172e-06
# Policy Loss 0 5.6277927e-06
# Policy Loss 0 5.7445427e-06
# Policy Loss 0 5.6299805e-06
# Policy Loss 0 4.96961e-06
# Policy Loss 0 3.962954e-06
# Policy Loss 0 2.505839e-06
# Policy Loss 0 2.0935436e-06
# Policy Loss 0 6.8708425e-07
# Policy Loss 0 1.8649077e-07
# Policy Loss 0 2.9221852e-08
# Policy Loss 0 7.8197877e-07
# Policy Loss 0 0.003916162
# Policy Loss 0 3.824385e-07
# Policy Loss 0 8.7694093e-07
# Policy Loss 0 1.854494e-07
# Policy Loss 0 9.966302e-08
# Policy Loss 0 4.231117e-08
# Policy Loss 0 5.08432e-07
# Policy Loss 0 2.0267318e-08
# Policy Loss 0 3.482578e-08
# Policy Loss 0 0.0039040383
# Policy Loss 0 0.0044407304
# Policy Loss 0 1.3709351e-06
# Policy Loss 0 2.6197167e-06
# Policy Loss 0 3.844196e-06
# Policy Loss 0 4.5916618e-06
# Policy Loss 0 4.8811935e-06
# Policy Loss 0 0.0044420045
# Policy Loss 0 0.0048654894
# Policy Loss 0 6.6987986e-06
# Policy Loss 0 7.4129935e-06
# Policy Loss 0 7.2236608e-06
# Policy Loss 0 6.4022533e-06
# Policy Loss 0 5.134704e-06
# Policy Loss 0 3.431653e-06
# Policy Loss 0 2.1031942e-06
# Policy Loss 0 1.0016212e-06
# Policy Loss 0 3.4786126e-07
# Policy Loss 0 4.6958203e-08
# Policy Loss 0 2.0358212e-07
# Policy Loss 0 4.9901803e-07
# Policy Loss 0 9.676256e-07
# Policy Loss 0 1.3638206e-06
# Policy Loss 0 1.6457649e-06
# Policy Loss 0 1.7488193e-06
# Policy Loss 0 1.6146889e-06
# Policy Loss 0 1.8740006e-06
# Policy Loss 0 1.0118489e-06
# Policy Loss 0 6.651154e-07
# Policy Loss 0 3.6064364e-07
# Policy Loss 0 1.5448407e-07
# Policy Loss 0 3.252331e-08
# Policy Loss 0 4.7459395e-07
# Policy Loss 0 8.1738776e-08
# Policy Loss 0 0.009753886
# Policy Loss 0 1.2575651e-06
# Policy Loss 0 2.844431e-06
# Policy Loss 0 4.3858954e-06
# Policy Loss 0 5.6744752e-06
# Policy Loss 0 6.1007813e-06
# Policy Loss 0 6.1020282e-06
# Policy Loss 0 5.1991406e-06
# Policy Loss 0 4.1826665e-06
# Policy Loss 0 2.985441e-06
# Policy Loss 0 0.0050747795
# Policy Loss 0 1.5063888e-06
# Policy Loss 0 1.1390605e-06
# Policy Loss 0 7.7967877e-07
# Policy Loss 0 4.3822473e-07
# Policy Loss 0 2.7975554e-07
# Policy Loss 0 2.4109852e-08
# Policy Loss 0 9.759114e-08
# Policy Loss 0 1.7619709e-07
# Policy Loss 0 2.4826284e-07
# Policy Loss 0 3.526959e-07
# Policy Loss 0 4.1771256e-07
# Policy Loss 0 0.0050426074
# Policy Loss 0 1.305359e-07
# Policy Loss 0 9.690177e-09
# Policy Loss 0 5.0307982e-08
# Policy Loss 0 1.9433402e-07
# Policy Loss 0 3.8858545e-07
# Policy Loss 0 5.691033e-07
# Policy Loss 0 0.0046747057
# Policy Loss 0 0.0055531724
# Policy Loss 0 2.7591127e-06
# Policy Loss 0 4.145966e-06
# Policy Loss 0 5.1765637e-06
# Policy Loss 0 5.6080653e-06
# Policy Loss 0 5.307583e-06
# Policy Loss 0 0.004723331
# Policy Loss 0 5.008803e-06
# Policy Loss 0 4.5541246e-06
# Policy Loss 0 3.953436e-06
# Policy Loss 0 2.9634925e-06
# Policy Loss 0 2.0591237e-06
# Policy Loss 0 1.1886211e-06
# Policy Loss 0 6.139934e-07
# Policy Loss 0 2.1226435e-07
# Policy Loss 0 3.076868e-08
# Policy Loss 0 3.3540908e-07
# Policy Loss 0 4.342936e-07
# Policy Loss 0 6.823098e-07
# Policy Loss 0 9.335111e-07
# Policy Loss 0 1.0759677e-06
# Policy Loss 0 0.005245451
# Policy Loss 0 5.1867625e-07
# Policy Loss 0 1.5530297e-07
# Policy Loss 0 1.5672315e-08
# Policy Loss 0 5.746673e-08
# Policy Loss 0 2.5292422e-07
# Policy Loss 0 4.8985453e-07
# Policy Loss 0 6.913632e-07
# Policy Loss 0 8.235511e-07
# Policy Loss 0 9.0066e-07
# Policy Loss 0 8.5123907e-07
# Policy Loss 0 7.4209106e-07
# Policy Loss 0 5.5020655e-07
# Policy Loss 0 3.809351e-07
# Policy Loss 0 2.2004737e-07
# Policy Loss 0 9.421389e-08
# Policy Loss 0 5.355872e-07
# Policy Loss 0 1.0259248e-08
# Policy Loss 0 2.2939568e-08
# Policy Loss 0 7.2901315e-08
# Policy Loss 0 1.2101319e-07
# Policy Loss 0 1.7159985e-07
# Policy Loss 0 2.0659641e-07
# Policy Loss 0 0.0052103065
# Policy Loss 0 4.0458513e-08
# Policy Loss 0 2.8940864e-08
# Policy Loss 0 1.5272212e-07
# Policy Loss 0 3.4195685e-07
# Policy Loss 0 5.3309304e-07
# Policy Loss 0 6.790287e-07
# Policy Loss 0 7.61454e-07
# Policy Loss 0 7.4067543e-07
# Policy Loss 0 6.8200563e-07
# Policy Loss 0 0.005336021
# Policy Loss 0 8.458739e-07
# Policy Loss 0 1.0557853e-06
# Policy Loss 0 1.200782e-06
# Policy Loss 0 1.1225187e-06
# Policy Loss 0 0.0038960548
# Policy Loss 0 1.3808599e-06
# Policy Loss 0 1.584179e-06
# Policy Loss 0 1.6773511e-06
# Policy Loss 0 1.5832852e-06
# Policy Loss 0 1.3507744e-06
# Policy Loss 0 1.5238204e-06
# Policy Loss 0 6.9599696e-07
# Policy Loss 0 3.8800528e-07
# Policy Loss 0 6.655718e-07
# Policy Loss 0 4.358418e-08
# Policy Loss 0 1.4918754e-08
# Policy Loss 0 5.8162243e-08
# Policy Loss 0 1.4543785e-07
# Policy Loss 0 2.5937067e-07
# Policy Loss 0 3.4644856e-07
# Policy Loss 0 4.103939e-07
# Policy Loss 0 4.0643408e-07
# Policy Loss 0 3.7290556e-07
# Policy Loss 0 3.0505686e-07
# Policy Loss 0 2.2421071e-07
# Policy Loss 0 1.4745711e-07
# Policy Loss 0 8.4518874e-08
# Policy Loss 0 3.5930917e-08
# Policy Loss 0 1.3041246e-08
# Policy Loss 0 1.0883134e-08
# Policy Loss 0 2.7472915e-08
# Policy Loss 0 4.9214307e-08
# Policy Loss 0 0.0046621673
# Policy Loss 0 3.3787836e-07
# Policy Loss 0 0.0049146726
# Policy Loss 0 1.764359e-06
# Policy Loss 0 2.848825e-06
# Policy Loss 0 3.7154098e-06
# Policy Loss 0 4.098687e-06
# Policy Loss 0 4.181225e-06
# Policy Loss 0 3.7035456e-06
# Policy Loss 0 3.0595816e-06
# Policy Loss 0 2.2235454e-06
# Policy Loss 0 1.4001779e-06
# Policy Loss 0 7.230293e-07
# Policy Loss 0 2.8450864e-07
# Policy Loss 0 6.060087e-08
# Policy Loss 0 4.3838817e-08
# Policy Loss 0 2.0968412e-07
# Policy Loss 0 4.4475436e-07
# Policy Loss 0 7.140739e-07
# Policy Loss 0 8.812999e-07
# Policy Loss 0 9.646221e-07
# Policy Loss 0 9.538053e-07
# Policy Loss 0 8.5462e-07
# Policy Loss 0 6.7211215e-07
# Policy Loss 0 4.820053e-07
# Policy Loss 0 3.0016827e-07
# Policy Loss 0 1.4024943e-07
# Policy Loss 0 5.809873e-08
# Policy Loss 0 1.5826945e-08
# Policy Loss 0 3.3169144e-08
# Policy Loss 0 0.009603603
# Policy Loss 0 8.386987e-07
# Policy Loss 0 2.2033496e-06
# Policy Loss 0 3.4934235e-06
# Policy Loss 0 4.846196e-06
# Policy Loss 0 5.449092e-06
# Policy Loss 0 5.4300945e-06
# Policy Loss 0 0.004964931
# Policy Loss 0 5.553372e-06
# Policy Loss 0 5.3234216e-06
# Policy Loss 0 4.589275e-06
# Policy Loss 0 3.6467131e-06
# Policy Loss 0 2.4767485e-06
# Policy Loss 0 1.5057872e-06
# Policy Loss 0 7.66387e-07
# Policy Loss 0 2.1551992e-07
# Policy Loss 0 1.2903445e-07
# Policy Loss 0 7.337746e-07
# Policy Loss 0 9.673811e-07
# Policy Loss 0 6.9833163e-07
# Policy Loss 0 9.583825e-07
# Policy Loss 0 1.1428721e-06
# Policy Loss 0 1.2059679e-06
# Policy Loss 0 1.169844e-06
# Policy Loss 0 9.675204e-07
# Policy Loss 0 7.8114147e-07
# Policy Loss 0 5.415123e-07
# Policy Loss 0 3.4861716e-07
# Policy Loss 0 1.2971024e-07
# Policy Loss 0 7.870365e-08
# Policy Loss 0 3.2483605e-08
# Policy Loss 0 1.5765346e-07
# Policy Loss 0 0.005333591
# Policy Loss 0 5.4577805e-07
# Policy Loss 0 1.1409934e-06
# Policy Loss 0 1.6298914e-06
# Policy Loss 0 2.0214784e-06
# Policy Loss 0 2.1500007e-06
# Policy Loss 0 2.0127027e-06
# Policy Loss 0 0.0041614305
# Policy Loss 0 1.9417791e-06
# Policy Loss 0 1.8680307e-06
# Policy Loss 0 1.703147e-06
# Policy Loss 0 1.3502982e-06
# Policy Loss 0 9.44211e-07
# Policy Loss 0 5.971558e-07
# Policy Loss 0 3.441881e-07
# Policy Loss 0 1.5328193e-07
# Policy Loss 0 5.7925515e-08
# Policy Loss 0 8.960905e-08
# Policy Loss 0 7.645679e-07
# Policy Loss 0 4.2180466e-07
# Policy Loss 0 4.4632012e-07
# Policy Loss 0 4.9714606e-07
# Policy Loss 0 4.7545615e-07
# Policy Loss 0 4.2799667e-07
# Policy Loss 0 3.6564347e-07
# Policy Loss 0 2.737478e-07
# Policy Loss 0 1.8734261e-07
# Policy Loss 0 0.005128328
# Policy Loss 0 1.1461462e-07
# Policy Loss 0 3.8922093e-07
# Policy Loss 0 8.3318116e-07
# Policy Loss 0 1.1904237e-06
# Policy Loss 0 1.5556107e-06
# Policy Loss 0 1.744658e-06
# Policy Loss 0 1.6383624e-06
# Policy Loss 0 1.7405457e-06
# Policy Loss 0 1.0835295e-06
# Policy Loss 0 0.0045955027
# Policy Loss 0 8.751948e-07
# Policy Loss 0 0.0047312025
# Policy Loss 0 1.6302783e-06
# Policy Loss 0 2.0688099e-06
# Policy Loss 0 0.0046969065
# Policy Loss 0 3.4912896e-06
# Policy Loss 0 4.1513795e-06
# Policy Loss 0 4.303045e-06
# Policy Loss 0 3.983104e-06
# Policy Loss 0 3.3671063e-06
# Policy Loss 0 2.4977912e-06
# Policy Loss 0 1.6062722e-06
# Policy Loss 0 9.054324e-07
# Policy Loss 0 4.0459136e-07
# Policy Loss 0 1.1937342e-07
# Policy Loss 0 0.0039075166
# Policy Loss 0 7.644476e-08
# Policy Loss 0 0.0039071445
# Policy Loss 0 9.330967e-08
# Policy Loss 0 2.967876e-07
# Policy Loss 0 5.6226787e-07
# Policy Loss 0 8.1402175e-07
# Policy Loss 0 0.004542473
# Policy Loss 0 1.7139114e-06
# Policy Loss 0 2.354077e-06
# Policy Loss 0 0.0038901044
# Policy Loss 0 3.9828437e-06
# Policy Loss 0 4.770036e-06
# Policy Loss 0 4.971301e-06
# Policy Loss 0 4.7061e-06
# Policy Loss 0 3.8614917e-06
# Policy Loss 0 2.906268e-06
# Policy Loss 0 1.8843995e-06
# Policy Loss 0 1.0350041e-06
# Policy Loss 0 4.16168e-07
# Policy Loss 0 9.9046105e-08
# Policy Loss 0 6.6263006e-08
# Policy Loss 0 1.9610937e-07
# Policy Loss 0 4.7263205e-07
# Policy Loss 0 7.3977634e-07
# Policy Loss 0 0.00900016
# Policy Loss 0 2.74106e-07
# Policy Loss 0 2.6031596e-08
# Policy Loss 0 1.8436602e-07
# Policy Loss 0 6.148247e-07
# Policy Loss 0 1.1443868e-06
# Policy Loss 0 1.617811e-06
# Policy Loss 0 1.9699974e-06
# Policy Loss 0 2.0970156e-06
# Policy Loss 0 1.9260103e-06
# Policy Loss 0 1.6854449e-06
# Policy Loss 0 0.00889536
# Policy Loss 0 2.2197707e-06
# Policy Loss 0 3.1446666e-06
# Policy Loss 0 3.6105002e-06
# Policy Loss 0 3.5998728e-06
# Policy Loss 0 3.4109532e-06
# Policy Loss 0 0.005290317
# Policy Loss 0 3.0726533e-06
# Policy Loss 0 3.0186302e-06
# Policy Loss 0 2.5894888e-06
# Policy Loss 0 1.9751294e-06
# Policy Loss 0 1.4042201e-06
# Policy Loss 0 8.427611e-07
# Policy Loss 0 9.748514e-07
# Policy Loss 0 1.3556037e-07
# Policy Loss 0 1.7149539e-08
# Policy Loss 0 6.4341606e-08
# Policy Loss 0 0.0051024193
# Policy Loss 0 1.1530481e-07
# Policy Loss 0 5.17683e-08
# Policy Loss 0 1.5410944e-08
# Policy Loss 0 1.11275575e-08
# Policy Loss 0 2.4576927e-08
# Policy Loss 0 4.437908e-08
# Policy Loss 0 7.51536e-08
# Policy Loss 0 9.6053526e-08
# Policy Loss 0 1.1269468e-07
# Policy Loss 0 1.1790493e-07
# Policy Loss 0 1.1213932e-07
# Policy Loss 0 9.5998345e-08
# Policy Loss 0 7.740939e-08
# Policy Loss 0 5.1206854e-08
# Policy Loss 0 3.2830464e-08
# Policy Loss 0 2.1043864e-08
# Policy Loss 0 1.3660272e-08
# Policy Loss 0 9.574466e-09
# Policy Loss 0 1.8457026e-08
# Policy Loss 0 1.8947496e-08
# Policy Loss 0 2.5301429e-08
# Policy Loss 0 3.615631e-08
# Policy Loss 0 3.0465287e-08
# Policy Loss 0 3.2701244e-08
# Policy Loss 0 3.273893e-08
# Policy Loss 0 0.0039078426
# Policy Loss 0 3.633845e-08
# Policy Loss 0 1.9054363e-07
# Policy Loss 0 4.2968736e-07
# Policy Loss 0 6.503841e-07
# Policy Loss 0 8.5438694e-07
# Policy Loss 0 9.139038e-07
# Policy Loss 0 8.873037e-07
# Policy Loss 0 8.4661156e-07
# Policy Loss 0 6.391151e-07
# Policy Loss 0 4.9891844e-07
# Policy Loss 0 0.0043318276
# Policy Loss 0 4.5956386e-07
# Policy Loss 0 5.733626e-07
# Policy Loss 0 6.3974517e-07
# Policy Loss 0 6.17544e-07
# Policy Loss 0 5.316697e-07
# Policy Loss 0 4.2086498e-07
# Policy Loss 0 3.158176e-07
# Policy Loss 0 1.8960885e-07
# Policy Loss 0 1.023072e-07
# Policy Loss 0 4.1304514e-08
# Policy Loss 0 8.3240295e-09
# Policy Loss 0 1.2206865e-08
# Policy Loss 0 3.913267e-08
# Policy Loss 0 7.059275e-08
# Policy Loss 0 0.0046012807
# Policy Loss 0 1.8330656e-08
# Policy Loss 0 5.3979403e-07
# Policy Loss 0 1.3056663e-07
# Policy Loss 0 0.0039002714
# Policy Loss 0 0.0052009616
# Policy Loss 0 2.3079037e-06
# Policy Loss 0 3.8919125e-06
# Policy Loss 0 0.0046174843
# Policy Loss 0 7.477997e-06
# Policy Loss 0 8.795694e-06
# Policy Loss 0 9.653384e-06
# Policy Loss 0 9.280941e-06
# Policy Loss 0 8.117598e-06
# Policy Loss 0 6.111737e-06
# Policy Loss 0 0.0049225115
# Policy Loss 0 3.5093876e-06
# Policy Loss 0 2.494294e-06
# Policy Loss 0 1.5804426e-06
# Policy Loss 0 8.24406e-07
# Policy Loss 0 4.0298164e-07
# Policy Loss 0 1.5599139e-07
# Policy Loss 0 1.6313385e-07
# Policy Loss 0 2.6575884e-07
# Policy Loss 0 5.014857e-07
# Policy Loss 0 0.0047155255
# Policy Loss 0 4.6823263e-07
# Policy Loss 0 7.0996816e-07
# Policy Loss 0 8.627167e-08
# Policy Loss 0 2.5616158e-08
# Policy Loss 0 2.3838824e-08
# Policy Loss 0 9.376554e-08
# Policy Loss 0 2.1121247e-07
# Policy Loss 0 2.9148993e-07
# Policy Loss 0 3.5520426e-07
# Policy Loss 0 3.8403817e-07
# Policy Loss 0 3.3117124e-07
# Policy Loss 0 0.0043393327
# Policy Loss 0 6.0214796e-07
# Policy Loss 0 8.4686735e-07
# Policy Loss 0 1.0460187e-06
# Policy Loss 0 1.1348014e-06
# Policy Loss 0 1.0570236e-06
# Policy Loss 0 1.3845942e-06
# Policy Loss 0 7.285335e-07
# Policy Loss 0 5.299044e-07
# Policy Loss 0 3.205037e-07
# Policy Loss 0 0.0049793427
# Policy Loss 0 2.5517673e-07
# Policy Loss 0 3.3501914e-07
# Policy Loss 0 0.014185407
# Policy Loss 0 2.070553e-06
# Policy Loss 0 4.3046957e-06
# Policy Loss 0 6.9002376e-06
# Policy Loss 0 8.922201e-06
# Policy Loss 0 9.665719e-06
# Policy Loss 0 9.4485495e-06
# Policy Loss 0 8.379155e-06
# Policy Loss 0 6.915185e-06
# Policy Loss 0 4.80753e-06
# Policy Loss 0 3.2242633e-06
# Policy Loss 0 1.6116423e-06
# Policy Loss 0 6.3874677e-07
# Policy Loss 0 1.6078475e-07
# Policy Loss 0 7.044529e-08
# Policy Loss 0 3.7318708e-07
# Policy Loss 0 1.3307244e-06
# Policy Loss 0 1.3511753e-06
# Policy Loss 0 1.7857524e-06
# Policy Loss 0 2.0637417e-06
# Policy Loss 0 2.0466e-06
# Policy Loss 0 1.8830465e-06
# Policy Loss 0 1.5716804e-06
# Policy Loss 0 1.1667685e-06
# Policy Loss 0 7.6795413e-07
# Policy Loss 0 4.2295454e-07
# Policy Loss 0 0.0045271087
# Policy Loss 0 2.9394865e-08
# Policy Loss 0 0.0048344657
# Policy Loss 0 1.5179353e-06
# Policy Loss 0 3.1108502e-06
# Policy Loss 0 4.547235e-06
# Policy Loss 0 5.78492e-06
# Policy Loss 0 0.0050400984
# Policy Loss 0 7.3040014e-06
# Policy Loss 0 7.977993e-06
# Policy Loss 0 7.3891506e-06
# Policy Loss 0 6.444415e-06
# Policy Loss 0 5.0347726e-06
# Policy Loss 0 3.5163494e-06
# Policy Loss 0 2.0981329e-06
# Policy Loss 0 1.1602688e-06
# Policy Loss 0 0.009940822
# Policy Loss 0 5.148577e-07
# Policy Loss 0 5.8983073e-07
# Policy Loss 0 0.0047986857
# Policy Loss 0 1.1204195e-06
# Policy Loss 0 1.5360937e-06
# Policy Loss 0 1.8161213e-06
# Policy Loss 0 1.9744282e-06
# Policy Loss 0 1.9185784e-06
# Policy Loss 0 1.6711344e-06
# Policy Loss 0 1.2872545e-06
# Policy Loss 0 9.100459e-07
# Policy Loss 0 0.004269279
# Policy Loss 0 6.1464686e-07
# Policy Loss 0 6.2951256e-07
# Policy Loss 0 5.782324e-07
# Policy Loss 0 4.7057898e-07
# Policy Loss 0 3.5497175e-07
# Policy Loss 0 6.5227937e-07
# Policy Loss 0 1.261366e-07
# Policy Loss 0 6.4894834e-08
# Policy Loss 0 1.573779e-08
# Policy Loss 0 1.0246846e-08
# Policy Loss 0 2.5479729e-08
# Policy Loss 0 5.829196e-08
# Policy Loss 0 9.6215956e-08
# Policy Loss 0 1.3005658e-07
# Policy Loss 0 1.4631843e-07
# Policy Loss 0 1.4365037e-07
# Policy Loss 0 1.4024181e-07
# Policy Loss 0 1.17516144e-07
# Policy Loss 0 9.017416e-08
# Policy Loss 0 6.6981634e-08
# Policy Loss 0 0.0039076437
# Policy Loss 0 3.381912e-08
# Policy Loss 0 2.1800278e-07
# Policy Loss 0 4.9157245e-07
# Policy Loss 0 7.8989757e-07
# Policy Loss 0 9.960081e-07
# Policy Loss 0 1.5932678e-06
# Policy Loss 0 1.093382e-06
# Policy Loss 0 1.0638186e-06
# Policy Loss 0 9.061259e-07
# Policy Loss 0 1.0924671e-06
# Policy Loss 0 4.3908338e-07
# Policy Loss 0 2.451277e-07
# Policy Loss 0 1.0163602e-07
# Policy Loss 0 2.8432478e-08
# Policy Loss 0 9.119354e-09
# Policy Loss 0 3.7167474e-08
# Policy Loss 0 9.557302e-08
# Policy Loss 0 1.4988089e-07
# Policy Loss 0 2.1732299e-07
# Policy Loss 0 2.4938205e-07
# Policy Loss 0 2.5906823e-07
# Policy Loss 0 2.530486e-07
# Policy Loss 0 2.1759517e-07
# Policy Loss 0 1.7528e-07
# Policy Loss 0 1.2545078e-07
# Policy Loss 0 7.283565e-08
# Policy Loss 0 4.0878007e-08
# Policy Loss 0 1.6132883e-08
# Policy Loss 0 0.004927365
# Policy Loss 0 1.2019038e-07
# Policy Loss 0 3.9656427e-07
# Policy Loss 0 7.4878096e-07
# Policy Loss 0 1.0641375e-06
# Policy Loss 0 1.2787991e-06
# Policy Loss 0 1.3182321e-06
# Policy Loss 0 1.3350425e-06
# Policy Loss 0 1.1372047e-06
# Policy Loss 0 8.9489515e-07
# Policy Loss 0 6.2584877e-07
# Policy Loss 0 0.0049600923
# Policy Loss 0 5.100597e-07
# Policy Loss 0 5.7119314e-07
# Policy Loss 0 5.829095e-07
# Policy Loss 0 5.2203836e-07
# Policy Loss 0 0.0047092917
# Policy Loss 0 1.1067544e-06
# Policy Loss 0 8.673787e-07
# Policy Loss 0 9.4221656e-07
# Policy Loss 0 9.707901e-07
# Policy Loss 0 8.948731e-07
# Policy Loss 0 0.005168791
# Policy Loss 0 9.811747e-07
# Policy Loss 0 1.2094301e-06
# Policy Loss 0 1.2826554e-06
# Policy Loss 0 1.216227e-06
# Policy Loss 0 1.074756e-06
# Policy Loss 0 8.392086e-07
# Policy Loss 0 0.008351691
# Policy Loss 0 1.3061233e-06
# Policy Loss 0 1.9769684e-06
# Policy Loss 0 2.5681288e-06
# Policy Loss 0 2.9321172e-06
# Policy Loss 0 2.8359893e-06
# Policy Loss 0 2.5184872e-06
# Policy Loss 0 2.056222e-06
# Policy Loss 0 1.4862817e-06
# Policy Loss 0 9.66166e-07
# Policy Loss 0 5.1011153e-07
# Policy Loss 0 2.1105986e-07
# Policy Loss 0 6.534738e-08
# Policy Loss 0 4.9398125e-07
# Policy Loss 0 1.3120078e-07
# Policy Loss 0 2.7878906e-07
# Policy Loss 0 4.3093274e-07
# Policy Loss 0 5.6892304e-07
# Policy Loss 0 6.312851e-07
# Policy Loss 0 6.3226423e-07
# Policy Loss 0 5.841477e-07
# Policy Loss 0 4.770321e-07
# Policy Loss 0 0.0045445138
# Policy Loss 0 5.2095256e-08
# Policy Loss 0 0.0042001475
# Policy Loss 0 6.223852e-07
# Policy Loss 0 1.6380391e-06
# Policy Loss 0 2.789559e-06
# Policy Loss 0 3.7105665e-06
# Policy Loss 0 4.236962e-06
# Policy Loss 0 4.1930675e-06
# Policy Loss 0 3.967731e-06
# Policy Loss 0 3.3278343e-06
# Policy Loss 0 2.464782e-06
# Policy Loss 0 1.6583888e-06
# Policy Loss 0 9.849217e-07
# Policy Loss 0 4.847059e-07
# Policy Loss 0 2.499135e-07
# Policy Loss 0 6.414193e-08
# Policy Loss 0 1.886727e-07
# Policy Loss 0 3.4180493e-07
# Policy Loss 0 5.5948806e-07
# Policy Loss 0 7.3283434e-07
# Policy Loss 0 8.784271e-07
# Policy Loss 0 9.138683e-07
# Policy Loss 0 8.551914e-07
# Policy Loss 0 1.1963475e-06
# Policy Loss 0 5.808427e-07
# Policy Loss 0 3.9775972e-07
# Policy Loss 0 2.4792257e-07
# Policy Loss 0 1.3932755e-07
# Policy Loss 0 6.827766e-08
# Policy Loss 0 2.7578881e-08
# Policy Loss 0 4.408747e-08
# Policy Loss 0 9.298539e-08
# Policy Loss 0 1.2885803e-07
# Policy Loss 0 1.6664035e-07
# Policy Loss 0 2.2816013e-07
# Policy Loss 0 2.0372252e-07
# Policy Loss 0 1.9977e-07
# Policy Loss 0 1.5220826e-07
# Policy Loss 0 1.1974697e-07
# Policy Loss 0 8.010538e-08
# Policy Loss 0 5.3023278e-08
# Policy Loss 0 3.858648e-08
# Policy Loss 0 1.8790004e-08
# Policy Loss 0 1.8190526e-08
# Policy Loss 0 3.336477e-08
# Policy Loss 0 0.0047162343
# Policy Loss 0 0.014098593
# Policy Loss 0 1.2783906e-06
# Policy Loss 0 3.819747e-06
# Policy Loss 0 6.9672797e-06
# Policy Loss 0 9.834654e-06
# Policy Loss 0 1.1401185e-05
# Policy Loss 0 1.2059476e-05
# Policy Loss 0 1.1351992e-05
# Policy Loss 0 9.510331e-06
# Policy Loss 0 0.004431726
# Policy Loss 0 6.655474e-06
# Policy Loss 0 5.171958e-06
# Policy Loss 0 3.7147004e-06
# Policy Loss 0 2.3696784e-06
# Policy Loss 0 1.2437075e-06
# Policy Loss 0 4.4554807e-07
# Policy Loss 0 9.862697e-08
# Policy Loss 0 9.2906106e-08
# Policy Loss 0 3.304037e-07
# Policy Loss 0 7.5855263e-07
# Policy Loss 0 1.1469803e-06
# Policy Loss 0 1.4411592e-06
# Policy Loss 0 1.6733411e-06
# Policy Loss 0 1.6863112e-06
# Policy Loss 0 1.5090849e-06
# Policy Loss 0 1.2529421e-06
# Policy Loss 0 9.196044e-07
# Policy Loss 0 0.0042095794
# Policy Loss 0 1.0449769e-07
# Policy Loss 0 4.1724599e-07
# Policy Loss 0 3.924348e-07
# Policy Loss 0 8.1707054e-07
# Policy Loss 0 1.3458564e-06
# Policy Loss 0 1.6956919e-06
# Policy Loss 0 1.924871e-06
# Policy Loss 0 1.9174022e-06
# Policy Loss 0 1.7604434e-06
# Policy Loss 0 0.004960634
# Policy Loss 0 1.6725874e-06
# Policy Loss 0 1.7767295e-06
# Policy Loss 0 1.6520805e-06
# Policy Loss 0 1.4621966e-06
# Policy Loss 0 1.1344337e-06
# Policy Loss 0 7.99189e-07
# Policy Loss 0 0.004596258
# Policy Loss 0 5.9749306e-07
# Policy Loss 0 6.243418e-07
# Policy Loss 0 5.895949e-07
# Policy Loss 0 5.144849e-07
# Policy Loss 0 0.0044724825
# Policy Loss 0 0.004381925
# Policy Loss 0 1.3636101e-06
# Policy Loss 0 2.1249894e-06
# Policy Loss 0 0.004521932
# Policy Loss 0 4.0371224e-06
# Policy Loss 0 5.168168e-06
# Policy Loss 0 5.5205674e-06
# Policy Loss 0 5.512373e-06
# Policy Loss 0 4.8775937e-06
# Policy Loss 0 3.9104025e-06
# Policy Loss 0 2.7984217e-06
# Policy Loss 0 1.7791677e-06
# Policy Loss 0 9.587147e-07
# Policy Loss 0 4.0141515e-07
# Policy Loss 0 8.55427e-08
# Policy Loss 0 6.9393366e-08
# Policy Loss 0 1.9362133e-07
# Policy Loss 0 4.4428415e-07
# Policy Loss 0 7.353075e-07
# Policy Loss 0 9.807256e-07
# Policy Loss 0 0.0049771233
# Policy Loss 0 6.814629e-07
# Policy Loss 0 0.009038482
# Policy Loss 0 7.3097524e-08
# Policy Loss 0 8.25856e-07
# Policy Loss 0 0.009521362
# Policy Loss 0 5.902514e-06
# Policy Loss 0 1.0002654e-05
# Policy Loss 0 1.3983874e-05
# Policy Loss 0 1.6217251e-05
# Policy Loss 0 1.7173206e-05
# Policy Loss 0 0.004520324
# Policy Loss 0 1.578496e-05
# Policy Loss 0 1.4118588e-05
# Policy Loss 0 1.1806216e-05
# Policy Loss 0 8.701147e-06
# Policy Loss 0 5.837427e-06
# Policy Loss 0 3.16838e-06
# Policy Loss 0 1.3204207e-06
# Policy Loss 0 2.6085218e-07
# Policy Loss 0 1.4778263e-07
# Policy Loss 0 5.567091e-07
# Policy Loss 0 1.3894607e-06
# Policy Loss 0 2.2211764e-06
# Policy Loss 0 2.9849098e-06
# Policy Loss 0 3.240582e-06
# Policy Loss 0 3.8404164e-06
# Policy Loss 0 2.8672657e-06
# Policy Loss 0 0.0046627955
# Policy Loss 0 8.5678084e-07
# Policy Loss 0 0.0051079225
# Policy Loss 0 2.4693946e-07
# Policy Loss 0 0.003896922
# Policy Loss 0 4.1281573e-06
# Policy Loss 0 7.241639e-06
# Policy Loss 0 9.812349e-06
# Policy Loss 0 1.0481372e-05
# Policy Loss 0 9.736244e-06
# Policy Loss 0 7.808312e-06
# Policy Loss 0 5.5270343e-06
# Policy Loss 0 3.5158505e-06
# Policy Loss 0 1.7914257e-06
# Policy Loss 0 9.162321e-07
# Policy Loss 0 4.9262314e-07
# Policy Loss 0 6.161901e-07
# Policy Loss 0 1.1618345e-06
# Policy Loss 0 1.3671158e-06
# Policy Loss 0 1.8243643e-06
# Policy Loss 0 1.7999736e-06
# Policy Loss 0 1.7451573e-06
# Policy Loss 0 1.4519647e-06
# Policy Loss 0 9.860514e-07
# Policy Loss 0 5.593643e-07
# Policy Loss 0 2.4466084e-07
# Policy Loss 0 7.170374e-08
# Policy Loss 0 3.283752e-08
# Policy Loss 0 1.0600574e-07
# Policy Loss 0 2.9420434e-07
# Policy Loss 0 4.5841102e-07
# Policy Loss 0 5.8626443e-07
# Policy Loss 0 5.284106e-07
# Policy Loss 0 5.03809e-07
# Policy Loss 0 4.97157e-07
# Policy Loss 0 3.8070493e-07
# Policy Loss 0 0.004389663
# Policy Loss 0 4.3970667e-07
# Policy Loss 0 6.652408e-07
# Policy Loss 0 8.193679e-07
# Policy Loss 0 8.8473826e-07
# Policy Loss 0 8.2894985e-07
# Policy Loss 0 6.646077e-07
# Policy Loss 0 4.7134083e-07
# Policy Loss 0 3.0151574e-07
# Policy Loss 0 1.377833e-07
# Policy Loss 0 4.284368e-08
# Policy Loss 0 1.7780794e-08
# Policy Loss 0 3.844964e-08
# Policy Loss 0 1.1400114e-07
# Policy Loss 0 1.5339064e-07
# Policy Loss 0 2.0747574e-07
# Policy Loss 0 2.305178e-07
# Policy Loss 0 2.3356415e-07
# Policy Loss 0 2.1202095e-07
# Policy Loss 0 1.6811691e-07
# Policy Loss 0 0.0045193005
# Policy Loss 0 1.1836824e-08
# Policy Loss 0 1.9857293e-07
# Policy Loss 0 5.45895e-07
# Policy Loss 0 0.004707145
# Policy Loss 0 2.088696e-06
# Policy Loss 0 0.004302632
# Policy Loss 0 5.2514106e-06
# Policy Loss 0 7.069036e-06
# Policy Loss 0 7.881812e-06
# Policy Loss 0 0.004248442
# Policy Loss 0 8.399777e-06
# Policy Loss 0 8.164244e-06
# Policy Loss 0 6.740214e-06
# Policy Loss 0 5.419471e-06
# Policy Loss 0 3.7205455e-06
# Policy Loss 0 2.2285021e-06
# Policy Loss 0 1.0299452e-06
# Policy Loss 0 2.9647973e-07
# Policy Loss 0 7.281743e-08
# Policy Loss 0 1.1755283e-07
# Policy Loss 0 4.5001872e-07
# Policy Loss 0 0.005130027
# Policy Loss 0 7.485232e-07
# Policy Loss 0 5.779758e-07
# Policy Loss 0 3.9090332e-07
# Policy Loss 0 2.1644476e-07
# Policy Loss 0 1.01076594e-07
# Policy Loss 0 2.9682292e-08
# Policy Loss 0 7.0261605e-09
# Policy Loss 0 2.3553596e-08
# Policy Loss 0 0.0043753446
# Policy Loss 0 3.6155942e-07
# Policy Loss 0 7.921899e-07
# Policy Loss 0 1.2354244e-06
# Policy Loss 0 1.5493306e-06
# Policy Loss 0 2.167349e-06
# Policy Loss 0 1.7139429e-06
# Policy Loss 0 1.6212196e-06
# Policy Loss 0 1.3726809e-06
# Policy Loss 0 1.0174205e-06
# Policy Loss 0 7.008525e-07
# Policy Loss 0 3.9784067e-07
# Policy Loss 0 1.9193268e-07
# Policy Loss 0 7.274261e-08
# Policy Loss 0 1.9744848e-08
# Policy Loss 0 5.2519457e-08
# Policy Loss 0 1.0668464e-07
# Policy Loss 0 2.1119216e-07
# Policy Loss 0 2.8092492e-07
# Policy Loss 0 3.462905e-07
# Policy Loss 0 3.690454e-07
# Policy Loss 0 0.004155588
# Policy Loss 0 1.0375883e-07
# Policy Loss 0 6.0309286e-09
# Policy Loss 0 4.936653e-08
# Policy Loss 0 1.8698549e-07
# Policy Loss 0 0.004395399
# Policy Loss 0 9.673977e-07
# Policy Loss 0 1.6645151e-06
# Policy Loss 0 2.2307943e-06
# Policy Loss 0 2.610373e-06
# Policy Loss 0 2.6886019e-06
# Policy Loss 0 2.5698787e-06
# Policy Loss 0 2.19906e-06
# Policy Loss 0 1.7273021e-06
# Policy Loss 0 1.2439536e-06
# Policy Loss 0 7.585856e-07
# Policy Loss 0 3.8226594e-07
# Policy Loss 0 1.3691621e-07
# Policy Loss 0 1.769857e-08
# Policy Loss 0 2.1994545e-08
# Policy Loss 0 1.16018526e-07
# Policy Loss 0 2.469368e-07
# Policy Loss 0 3.8182912e-07
# Policy Loss 0 1.0028866e-06
# Policy Loss 0 5.501807e-07
# Policy Loss 0 0.004673762
# Policy Loss 0 2.3338531e-07
# Policy Loss 0 4.39873e-08
# Policy Loss 0 4.81279e-07
# Policy Loss 0 8.5362345e-08
# Policy Loss 0 2.3153866e-07
# Policy Loss 0 3.9653332e-07
# Policy Loss 0 5.477481e-07
# Policy Loss 0 6.449979e-07
# Policy Loss 0 6.8149143e-07
# Policy Loss 0 6.4549187e-07
# Policy Loss 0 5.695948e-07
# Policy Loss 0 0.005147017
# Policy Loss 0 6.8509905e-07
# Policy Loss 0 8.615474e-07
# Policy Loss 0 8.971087e-07
# Policy Loss 0 1.3789293e-06
# Policy Loss 0 8.495217e-07
# Policy Loss 0 7.062455e-07
# Policy Loss 0 5.462257e-07
# Policy Loss 0 3.6814168e-07
# Policy Loss 0 2.1587195e-07
# Policy Loss 0 0.004512285
# Policy Loss 0 1.8490104e-07
# Policy Loss 0 2.3489424e-07
# Policy Loss 0 2.9077827e-07
# Policy Loss 0 7.719619e-07
# Policy Loss 0 0.0044217147
# Policy Loss 0 5.879597e-07
# Policy Loss 0 8.687309e-07
# Policy Loss 0 1.0704041e-06
# Policy Loss 0 1.1670003e-06
# Policy Loss 0 1.1572232e-06
# Policy Loss 0 1.0666317e-06
# Policy Loss 0 8.79127e-07
# Policy Loss 0 0.004457079
# Policy Loss 0 8.549394e-07
# Policy Loss 0 9.34548e-07
# Policy Loss 0 9.146562e-07
# Policy Loss 0 8.7445756e-07
# Policy Loss 0 7.591532e-07
# Policy Loss 0 5.391641e-07
# Policy Loss 0 3.973381e-07
# Policy Loss 0 2.2611476e-07
# Policy Loss 0 1.09186686e-07
# Policy Loss 0 3.7159182e-08
# Policy Loss 0 5.2189515e-09
# Policy Loss 0 1.6681389e-08
# Policy Loss 0 5.418316e-08
# Policy Loss 0 9.703531e-08
# Policy Loss 0 1.4479468e-07
# Policy Loss 0 1.8639392e-07
# Policy Loss 0 1.992648e-07
# Policy Loss 0 1.9757402e-07
# Policy Loss 0 1.8552916e-07
# Policy Loss 0 0.0043357806
# Policy Loss 0 1.0526118e-08
# Policy Loss 0 4.392662e-08
# Policy Loss 0 1.9405147e-07
# Policy Loss 0 3.9601423e-07
# Policy Loss 0 0.0052203154
# Policy Loss 0 1.3190916e-06
# Policy Loss 0 1.96791e-06
# Policy Loss 0 2.5112226e-06
# Policy Loss 0 2.822969e-06
# Policy Loss 0 2.8777517e-06
# Policy Loss 0 2.653384e-06
# Policy Loss 0 2.097926e-06
# Policy Loss 0 1.6373008e-06
# Policy Loss 0 1.0857359e-06
# Policy Loss 0 6.4072424e-07
# Policy Loss 0 2.9626216e-07
# Policy Loss 0 8.547082e-08
# Policy Loss 0 1.8009624e-08
# Policy Loss 0 0.0048686103
# Policy Loss 0 3.655184e-08
# Policy Loss 0 4.826776e-07
# Policy Loss 0 7.517768e-09
# Policy Loss 0 7.332022e-09
# Policy Loss 0 1.1309053e-08
# Policy Loss 0 1.9256131e-08
# Policy Loss 0 3.2003776e-08
# Policy Loss 0 0.004694787
# Policy Loss 0 1.9755343e-07
# Policy Loss 0 4.3675226e-07
# Policy Loss 0 6.8743594e-07
# Policy Loss 0 8.7941953e-07
# Policy Loss 0 9.822902e-07
# Policy Loss 0 9.977773e-07
# Policy Loss 0 9.470567e-07
# Policy Loss 0 8.033603e-07
# Policy Loss 0 6.157644e-07
# Policy Loss 0 4.0688997e-07
# Policy Loss 0 2.389217e-07
# Policy Loss 0 1.1558647e-07
# Policy Loss 0 3.7834475e-08
# Policy Loss 0 0.0053363056
# Policy Loss 0 2.8342177e-08
# Policy Loss 0 6.688079e-08
# Policy Loss 0 1.1722199e-07
# Policy Loss 0 1.535823e-07
# Policy Loss 0 0.00390111
# Policy Loss 0 4.6204343e-07
# Policy Loss 0 8.0416964e-07
# Policy Loss 0 0.0048281634
# Policy Loss 0 1.8963578e-06
# Policy Loss 0 0.004295484
# Policy Loss 0 4.107572e-06
# Policy Loss 0 5.377185e-06
# Policy Loss 0 6.1452424e-06
# Policy Loss 0 5.9914582e-06
# Policy Loss 0 5.3990593e-06
# Policy Loss 0 5.133813e-06
# Policy Loss 0 3.6088904e-06
# Policy Loss 0 2.448292e-06
# Policy Loss 0 1.4201053e-06
# Policy Loss 0 6.418319e-07
# Policy Loss 0 1.7467103e-07
# Policy Loss 0 0.003905866
# Policy Loss 0 1.3272558e-08
# Policy Loss 0 2.9821848e-08
# Policy Loss 0 0.003908125
# Policy Loss 0 1.59501e-08
# Policy Loss 0 7.507599e-08
# Policy Loss 0 1.7561803e-07
# Policy Loss 0 2.9169675e-07
# Policy Loss 0 3.973482e-07
# Policy Loss 0 4.6866342e-07
# Policy Loss 0 4.768262e-07
# Policy Loss 0 4.646726e-07
# Policy Loss 0 4.0118763e-07
# Policy Loss 0 3.3176946e-07
# Policy Loss 0 2.2729705e-07
# Policy Loss 0 1.475379e-07
# Policy Loss 0 7.951527e-08
# Policy Loss 0 3.195577e-08
# Policy Loss 0 8.529641e-09
# Policy Loss 0 7.880116e-09
# Policy Loss 0 0.004689948
# Policy Loss 0 9.59318e-09
# Policy Loss 0 5.356477e-08
# Policy Loss 0 5.4554107e-07
# Policy Loss 0 2.1095587e-07
# Policy Loss 0 2.9220524e-07
# Policy Loss 0 3.336119e-07
# Policy Loss 0 3.6236528e-07
# Policy Loss 0 3.4516478e-07
# Policy Loss 0 3.1173187e-07
# Policy Loss 0 2.4314554e-07
# Policy Loss 0 1.7634183e-07
# Policy Loss 0 1.1287687e-07
# Policy Loss 0 6.102836e-08
# Policy Loss 0 0.0046735047
# Policy Loss 0 0.0039026407
# Policy Loss 0 4.7624079e-07
# Policy Loss 0 1.0401754e-06
# Policy Loss 0 1.584486e-06
# Policy Loss 0 2.3620923e-06
# Policy Loss 0 2.2545385e-06
# Policy Loss 0 2.2394865e-06
# Policy Loss 0 2.1175956e-06
# Policy Loss 0 1.7464184e-06
# Policy Loss 0 1.7031075e-06
# Policy Loss 0 8.976449e-07
# Policy Loss 0 5.128961e-07
# Policy Loss 0 2.3835594e-07
# Policy Loss 0 6.495229e-08
# Policy Loss 0 6.8483583e-09
# Policy Loss 0 3.874237e-08
# Policy Loss 0 1.2998574e-07
# Policy Loss 0 2.5318622e-07
# Policy Loss 0 7.690096e-07
# Policy Loss 0 4.4640905e-07
# Policy Loss 0 4.8416916e-07
# Policy Loss 0 4.667408e-07
# Policy Loss 0 4.1883854e-07
# Policy Loss 0 3.5054165e-07
# Policy Loss 0 2.670003e-07
# Policy Loss 0 1.8332345e-07
# Policy Loss 0 9.685356e-08
# Policy Loss 0 5.63357e-08
# Policy Loss 0 2.1652365e-08
# Policy Loss 0 7.2052444e-09
# Policy Loss 0 1.6000557e-08
# Policy Loss 0 3.6397594e-08
# Policy Loss 0 6.0081696e-08
# Policy Loss 0 8.2735966e-08
# Policy Loss 0 0.003902543
# Policy Loss 0 3.2001665e-07
# Policy Loss 0 0.0043170685
# Policy Loss 0 1.4446316e-06
# Policy Loss 0 2.3305192e-06
# Policy Loss 0 3.0074084e-06
# Policy Loss 0 3.3790784e-06
# Policy Loss 0 3.2322093e-06
# Policy Loss 0 3.1611735e-06
# Policy Loss 0 2.80382e-06
# Policy Loss 0 2.2088639e-06
# Policy Loss 0 1.503428e-06
# Policy Loss 0 0.00444116
# Policy Loss 0 8.583441e-07
# Policy Loss 0 7.09318e-07
# Policy Loss 0 5.598495e-07
# Policy Loss 0 3.8601914e-07
# Policy Loss 0 2.3124619e-07
# Policy Loss 0 1.1412577e-07
# Policy Loss 0 4.3629143e-08
# Policy Loss 0 1.0195703e-08
# Policy Loss 0 2.1418217e-08
# Policy Loss 0 4.4508333e-08
# Policy Loss 0 9.59061e-08
# Policy Loss 0 1.320581e-07
# Policy Loss 0 1.6769673e-07
# Policy Loss 0 1.8395009e-07
# Policy Loss 0 1.8379755e-07
# Policy Loss 0 1.6703574e-07
# Policy Loss 0 1.3587179e-07
# Policy Loss 0 1.0716522e-07
# Policy Loss 0 7.359063e-08
# Policy Loss 0 4.3624198e-08
# Policy Loss 0 2.4524159e-08
# Policy Loss 0 1.17072805e-08
# Policy Loss 0 4.1939723e-09
# Policy Loss 0 0.004566789
# Policy Loss 0 1.3726336e-07
# Policy Loss 0 0.0038990476
# Policy Loss 0 1.1898585e-06
# Policy Loss 0 2.1106844e-06
# Policy Loss 0 2.9232797e-06
# Policy Loss 0 3.531971e-06
# Policy Loss 0 3.558871e-06
# Policy Loss 0 3.4873406e-06
# Policy Loss 0 0.0049931346
# Policy Loss 0 3.4749771e-06
# Policy Loss 0 0.004724195
# Policy Loss 0 0.0052126977
# Policy Loss 0 5.2793057e-06
# Policy Loss 0 6.1204632e-06
# Policy Loss 0 6.175539e-06
# Policy Loss 0 6.0162465e-06
# Policy Loss 0 0.0050199674
# Policy Loss 0 5.0324097e-06
# Policy Loss 0 4.5334305e-06
# Policy Loss 0 3.909957e-06
# Policy Loss 0 2.992066e-06
# Policy Loss 0 1.925072e-06
# Policy Loss 0 1.1214476e-06
# Policy Loss 0 4.9897926e-07
# Policy Loss 0 1.338922e-07
# Policy Loss 0 9.194847e-08
# Policy Loss 0 1.1405158e-07
# Policy Loss 0 7.7091266e-07
# Policy Loss 0 5.864638e-07
# Policy Loss 0 8.243053e-07
# Policy Loss 0 1.0097904e-06
# Policy Loss 0 1.0509211e-06
# Policy Loss 0 1.0446314e-06
# Policy Loss 0 9.1276047e-07
# Policy Loss 0 7.607869e-07
# Policy Loss 0 5.520716e-07
# Policy Loss 0 3.5677283e-07
# Policy Loss 0 2.0566222e-07
# Policy Loss 0 7.086542e-08
# Policy Loss 0 5.2391623e-08
# Policy Loss 0 5.1207405e-08
# Policy Loss 0 3.5410814e-08
# Policy Loss 0 0.004628137
# Policy Loss 0 4.2491575e-07
# Policy Loss 0 8.547022e-07
# Policy Loss 0 1.2741493e-06
# Policy Loss 0 1.6014737e-06
# Policy Loss 0 1.6991778e-06
# Policy Loss 0 1.7626867e-06
# Policy Loss 0 1.5960529e-06
# Policy Loss 0 1.3186088e-06
# Policy Loss 0 0.004466822
# Policy Loss 0 0.0045817667
# Policy Loss 0 1.7189786e-06
# Policy Loss 0 0.0045706667
# Policy Loss 0 3.5962598e-06
# Policy Loss 0 4.6175483e-06
# Policy Loss 0 0.00437837
# Policy Loss 0 6.3434713e-06
# Policy Loss 0 7.175646e-06
# Policy Loss 0 6.9458356e-06
# Policy Loss 0 6.1235096e-06
# Policy Loss 0 5.052148e-06
# Policy Loss 0 3.723773e-06
# Policy Loss 0 2.522908e-06
# Policy Loss 0 1.4310065e-06
# Policy Loss 0 6.1681766e-07
# Policy Loss 0 2.1278707e-07
# Policy Loss 0 3.651005e-08
# Policy Loss 0 0.005270548
# Policy Loss 0 1.8027593e-07
# Policy Loss 0 1.8670733e-07
# Policy Loss 0 1.593541e-07
# Policy Loss 0 1.3989829e-07
# Policy Loss 0 1.0944408e-07
# Policy Loss 0 8.017294e-08
# Policy Loss 0 0.0047343904
# Policy Loss 0 1.6186085e-08
# Policy Loss 0 1.611237e-07
# Policy Loss 0 3.9477385e-07
# Policy Loss 0 6.6125887e-07
# Policy Loss 0 0.009044403
# Policy Loss 0 2.3215675e-06
# Policy Loss 0 3.9308325e-06
# Policy Loss 0 5.2696523e-06
# Policy Loss 0 6.1500396e-06
# Policy Loss 0 6.449861e-06
# Policy Loss 0 6.002162e-06
# Policy Loss 0 5.227926e-06
# Policy Loss 0 4.106024e-06
# Policy Loss 0 2.9233279e-06
# Policy Loss 0 1.8353533e-06
# Policy Loss 0 9.234758e-07
# Policy Loss 0 3.3815942e-07
# Policy Loss 0 8.492873e-08
# Policy Loss 0 9.641316e-08
# Policy Loss 0 3.3008808e-07
# Policy Loss 0 5.7884574e-07
# Policy Loss 0 9.3090443e-07
# Policy Loss 0 1.1284471e-06
# Policy Loss 0 1.2946872e-06
# Policy Loss 0 1.3282283e-06
# Policy Loss 0 1.2301917e-06
# Policy Loss 0 1.0325285e-06
# Policy Loss 0 8.046097e-07
# Policy Loss 0 0.004491157
# Policy Loss 0 1.0601134e-07
# Policy Loss 0 1.060009e-08
# Policy Loss 0 1.8640236e-07
# Policy Loss 0 0.0043276893
# Policy Loss 0 1.4641317e-06
# Policy Loss 0 2.5201284e-06
# Policy Loss 0 3.4990655e-06
# Policy Loss 0 4.183329e-06
# Policy Loss 0 4.240658e-06
# Policy Loss 0 4.2087713e-06
# Policy Loss 0 3.5485132e-06
# Policy Loss 0 2.922909e-06
# Policy Loss 0 2.0559455e-06
# Policy Loss 0 1.2784444e-06
# Policy Loss 0 6.943891e-07
# Policy Loss 0 2.5788e-07
# Policy Loss 0 5.9427098e-08
# Policy Loss 0 4.5690328e-08
# Policy Loss 0 1.7758444e-07
# Policy Loss 0 3.7906926e-07
# Policy Loss 0 0.0051264972
# Policy Loss 0 3.7847087e-07
# Policy Loss 0 0.00899181
# Policy Loss 0 4.7129937e-08
# Policy Loss 0 5.8499e-07
# Policy Loss 0 1.5796752e-06
# Policy Loss 0 2.6289783e-06
# Policy Loss 0 3.6159818e-06
# Policy Loss 0 4.216043e-06
# Policy Loss 0 4.507065e-06
# Policy Loss 0 4.258979e-06
# Policy Loss 0 3.8072203e-06
# Policy Loss 0 3.0385336e-06
# Policy Loss 0 2.2048976e-06
# Policy Loss 0 0.0050950963
# Policy Loss 0 1.2115229e-06
# Policy Loss 0 9.865222e-07
# Policy Loss 0 7.1867703e-07
# Policy Loss 0 4.549796e-07
# Policy Loss 0 2.5485159e-07
# Policy Loss 0 1.0175955e-07
# Policy Loss 0 2.2953731e-08
# Policy Loss 0 7.742052e-09
# Policy Loss 0 4.1376925e-08
# Policy Loss 0 0.0045999954
# Policy Loss 0 3.1582964e-08
# Policy Loss 0 5.1940434e-09
# Policy Loss 0 0.004461028
# Policy Loss 0 2.2646184e-07
# Policy Loss 0 6.125625e-07
# Policy Loss 0 1.0146103e-06
# Policy Loss 0 1.3998745e-06
# Policy Loss 0 1.6398533e-06
# Policy Loss 0 0.004589039
# Policy Loss 0 2.3479333e-06
# Policy Loss 0 2.7295532e-06
# Policy Loss 0 3.2279258e-06
# Policy Loss 0 2.7617791e-06
# Policy Loss 0 0.004455082
# Policy Loss 0 2.8134293e-06
# Policy Loss 0 2.8558313e-06
# Policy Loss 0 2.5685933e-06
# Policy Loss 0 0.0047124187
# Policy Loss 0 2.3309765e-06
# Policy Loss 0 2.323138e-06
# Policy Loss 0 2.035843e-06
# Policy Loss 0 0.0046450477
# Policy Loss 0 2.4134788e-06
# Policy Loss 0 1.9844335e-06
# Policy Loss 0 1.8101928e-06
# Policy Loss 0 1.4559675e-06
# Policy Loss 0 0.004689843
# Policy Loss 0 1.2678682e-06
# Policy Loss 0 0.0039258692
# Policy Loss 0 1.5859937e-06
# Policy Loss 0 1.6763543e-06
# Policy Loss 0 1.6600991e-06
# Policy Loss 0 1.3912609e-06
# Policy Loss 0 1.1592148e-06
# Policy Loss 0 8.213676e-07
# Policy Loss 0 5.447885e-07
# Policy Loss 0 2.9593735e-07
# Policy Loss 0 0.004988065
# Policy Loss 0 1.6678261e-07
# Policy Loss 0 1.8851169e-07
# Policy Loss 0 2.0588621e-07
# Policy Loss 0 0.00516411
# Policy Loss 0 4.3729779e-07
# Policy Loss 0 0.0047527933
# Policy Loss 0 1.4790282e-06
# Policy Loss 0 2.2135705e-06
# Policy Loss 0 2.861045e-06
# Policy Loss 0 3.2043763e-06
# Policy Loss 0 3.1608997e-06
# Policy Loss 0 0.004395421
# Policy Loss 0 3.3240735e-06
# Policy Loss 0 3.362983e-06
# Policy Loss 0 3.0589456e-06
# Policy Loss 0 2.5827849e-06
# Policy Loss 0 1.9722688e-06
# Policy Loss 0 1.3858568e-06
# Policy Loss 0 0.004551472
# Policy Loss 0 7.890559e-07
# Policy Loss 0 6.527643e-07
# Policy Loss 0 5.255081e-07
# Policy Loss 0 3.7670765e-07
# Policy Loss 0 0.0050805407
# Policy Loss 0 0.0047181244
# Policy Loss 0 1.1693842e-06
# Policy Loss 0 1.3916141e-06
# Policy Loss 0 1.77677e-06
# Policy Loss 0 2.1053606e-06
# Policy Loss 0 2.1446965e-06
# Policy Loss 0 2.0052453e-06
# Policy Loss 0 1.7551984e-06
# Policy Loss 0 1.4024665e-06
# Policy Loss 0 0.00466542
# Policy Loss 0 1.1036122e-06
# Policy Loss 0 0.0046127457
# Policy Loss 0 1.4841648e-06
# Policy Loss 0 1.8017254e-06
# Policy Loss 0 1.96259e-06
# Policy Loss 0 1.8492908e-06
# Policy Loss 0 0.004954674
# Policy Loss 0 0.004471524
# Policy Loss 0 3.0072108e-06
# Policy Loss 0 0.0050115213
# Policy Loss 0 0.0049280953
# Policy Loss 0 7.1667923e-06
# Policy Loss 0 8.713894e-06
# Policy Loss 0 9.758809e-06
# Policy Loss 0 9.541958e-06
# Policy Loss 0 8.709258e-06
# Policy Loss 0 0.0045752516
# Policy Loss 0 6.526682e-06
# Policy Loss 0 5.5955343e-06
# Policy Loss 0 4.3916243e-06
# Policy Loss 0 2.9701232e-06
# Policy Loss 0 1.8356843e-06
# Policy Loss 0 9.223854e-07
# Policy Loss 0 3.466429e-07
# Policy Loss 0 1.3363118e-07
# Policy Loss 0 1.2794752e-07
# Policy Loss 0 3.050431e-07
# Policy Loss 0 0.0046220366
# Policy Loss 0 5.5217873e-07
# Policy Loss 0 4.4924764e-07
# Policy Loss 0 3.0602155e-07
# Policy Loss 0 0.0043672565
# Policy Loss 0 1.6175795e-08
# Policy Loss 0 8.193567e-08
# Policy Loss 0 0.009697373
# Policy Loss 0 1.6856412e-06
# Policy Loss 0 3.5913167e-06
# Policy Loss 0 5.472068e-06
# Policy Loss 0 6.9256184e-06
# Policy Loss 0 7.845877e-06
# Policy Loss 0 0.0044063316
# Policy Loss 0 8.80501e-06
# Policy Loss 0 8.568872e-06
# Policy Loss 0 7.5569887e-06
# Policy Loss 0 6.633335e-06
# Policy Loss 0 5.2224696e-06
# Policy Loss 0 3.45622e-06
# Policy Loss 0 2.153206e-06
# Policy Loss 0 1.1968052e-06
# Policy Loss 0 4.3023456e-07
# Policy Loss 0 6.4900014e-08
# Policy Loss 0 0.008907894
# Policy Loss 0 2.0316728e-07
# Policy Loss 0 1.10664814e-07
# Policy Loss 0 2.0098351e-07
# Policy Loss 0 1.1472782e-07
# Policy Loss 0 1.7498155e-07
# Policy Loss 0 1.9846505e-07
# Policy Loss 0 2.157586e-07
# Policy Loss 0 2.327379e-07
# Policy Loss 0 2.1951385e-07
# Policy Loss 0 1.9885196e-07
# Policy Loss 0 1.8833727e-07
# Policy Loss 0 1.5827598e-07
# Policy Loss 0 1.07467436e-07
# Policy Loss 0 6.684693e-08
# Policy Loss 0 8.430972e-08
# Policy Loss 0 2.5233842e-08
# Policy Loss 0 3.085808e-08
# Policy Loss 0 3.9947274e-08
# Policy Loss 0 3.0680344e-08
# Policy Loss 0 3.8712425e-08
# Policy Loss 0 4.701433e-08
# Policy Loss 0 5.0942415e-08
# Policy Loss 0 5.2255167e-08
# Policy Loss 0 5.4130226e-08
# Policy Loss 0 5.5035112e-08
# Policy Loss 0 0.004549657
# Policy Loss 0 2.2672246e-08
# Policy Loss 0 0.0039030495
# Policy Loss 0 5.85673e-07
# Policy Loss 0 1.282098e-06
# Policy Loss 0 0.0046608555
# Policy Loss 0 0.005123025
# Policy Loss 0 5.753612e-06
# Policy Loss 0 7.70501e-06
# Policy Loss 0 9.180026e-06
# Policy Loss 0 9.634288e-06
# Policy Loss 0 9.041516e-06
# Policy Loss 0 7.960136e-06
# Policy Loss 0 6.679264e-06
# Policy Loss 0 4.8021748e-06
# Policy Loss 0 3.1010961e-06
# Policy Loss 0 1.7650896e-06
# Policy Loss 0 7.913577e-07
# Policy Loss 0 2.1580762e-07
# Policy Loss 0 7.341402e-09
# Policy Loss 0 1.5643184e-07
# Policy Loss 0 5.054094e-07
# Policy Loss 0 9.2247546e-07
# Policy Loss 0 0.0044511706
# Policy Loss 0 1.4789066e-06
# Policy Loss 0 7.5264325e-07
# Policy Loss 0 4.9072514e-07
# Policy Loss 0 2.6849582e-07
# Policy Loss 0 1.11999626e-07
# Policy Loss 0 4.0880956e-08
# Policy Loss 0 3.872077e-08
# Policy Loss 0 7.8474386e-08
# Policy Loss 0 1.261389e-07
# Policy Loss 0 1.9933455e-07
# Policy Loss 0 2.542527e-07
# Policy Loss 0 3.000814e-07
# Policy Loss 0 3.104864e-07
# Policy Loss 0 2.9845927e-07
# Policy Loss 0 2.683393e-07
# Policy Loss 0 2.1106521e-07
# Policy Loss 0 0.0041981856
# Policy Loss 0 3.2535382e-07
# Policy Loss 0 4.915951e-07
# Policy Loss 0 6.132898e-07
# Policy Loss 0 6.828412e-07
# Policy Loss 0 6.904966e-07
# Policy Loss 0 6.4342373e-07
# Policy Loss 0 5.398624e-07
# Policy Loss 0 4.0188706e-07
# Policy Loss 0 2.820645e-07
# Policy Loss 0 1.6835259e-07
# Policy Loss 0 8.137948e-08
# Policy Loss 0 3.1101465e-08
# Policy Loss 0 1.6091764e-08
# Policy Loss 0 0.009163362
# Policy Loss 0 1.0686103e-07
# Policy Loss 0 4.401985e-07
# Policy Loss 0 8.9013076e-07
# Policy Loss 0 1.3130525e-06
# Policy Loss 0 1.6693036e-06
# Policy Loss 0 1.8893527e-06
# Policy Loss 0 1.9047841e-06
# Policy Loss 0 1.7409989e-06
# Policy Loss 0 1.4237165e-06
# Policy Loss 0 1.1117579e-06
# Policy Loss 0 7.279481e-07
# Policy Loss 0 4.2781198e-07
# Policy Loss 0 1.992604e-07
# Policy Loss 0 6.401265e-08
# Policy Loss 0 1.3229994e-08
# Policy Loss 0 3.5994603e-08
# Policy Loss 0 0.0039919373
# Policy Loss 0 0.0042089666
# Policy Loss 0 4.5043876e-08
# Policy Loss 0 2.2307597e-07
# Policy Loss 0 5.172774e-07
# Policy Loss 0 8.2755435e-07
# Policy Loss 0 0.009548966
# Policy Loss 0 2.5938066e-06
# Policy Loss 0 4.230167e-06
# Policy Loss 0 5.4820875e-06
# Policy Loss 0 0.004586095
# Policy Loss 0 7.77789e-06
# Policy Loss 0 8.5092e-06
# Policy Loss 0 0.004360659
# Policy Loss 0 9.292644e-06
# Policy Loss 0 0.004659498
# Policy Loss 0 9.958247e-06
# Policy Loss 0 9.6368685e-06
# Policy Loss 0 8.353207e-06
# Policy Loss 0 6.5820877e-06
# Policy Loss 0 5.154818e-06
# Policy Loss 0 3.3899541e-06
# Policy Loss 0 1.934738e-06
# Policy Loss 0 9.288708e-07
# Policy Loss 0 2.687985e-07
# Policy Loss 0 2.3512454e-08
# Policy Loss 0 1.862123e-07
# Policy Loss 0 5.364343e-07
# Policy Loss 0 1.0041297e-06
# Policy Loss 0 1.3876316e-06
# Policy Loss 0 1.6744712e-06
# Policy Loss 0 1.901444e-06
# Policy Loss 0 1.8306565e-06
# Policy Loss 0 1.7146408e-06
# Policy Loss 0 1.4123186e-06
# Policy Loss 0 1.1061984e-06
# Policy Loss 0 7.3551234e-07
# Policy Loss 0 4.4865345e-07
# Policy Loss 0 2.422237e-07
# Policy Loss 0 8.328187e-08
# Policy Loss 0 7.863628e-08
# Policy Loss 0 6.7854174e-08
# Policy Loss 0 1.1415899e-07
# Policy Loss 0 2.0031891e-07
# Policy Loss 0 2.9580087e-07
# Policy Loss 0 6.796235e-07
# Policy Loss 0 3.534129e-07
# Policy Loss 0 3.553016e-07
# Policy Loss 0 0.004675371
# Policy Loss 0 5.9267086e-07
# Policy Loss 0 8.516196e-07
# Policy Loss 0 0.004568117
# Policy Loss 0 1.6193235e-06
# Policy Loss 0 2.1804974e-06
# Policy Loss 0 2.5687605e-06
# Policy Loss 0 2.6728148e-06
# Policy Loss 0 2.5123168e-06
# Policy Loss 0 2.236604e-06
# Policy Loss 0 1.8254309e-06
# Policy Loss 0 1.2908454e-06
# Policy Loss 0 8.2657607e-07
# Policy Loss 0 4.445053e-07
# Policy Loss 0 2.1309691e-07
# Policy Loss 0 7.0326635e-08
# Policy Loss 0 4.3060435e-08
# Policy Loss 0 9.0424855e-08
# Policy Loss 0 1.8899193e-07
# Policy Loss 0 3.1021762e-07
# Policy Loss 0 4.175214e-07
# Policy Loss 0 4.782619e-07
# Policy Loss 0 4.9688765e-07
# Policy Loss 0 0.004479943
# Policy Loss 0 1.974447e-07
# Policy Loss 0 4.403713e-08
# Policy Loss 0 2.7369719e-08
# Policy Loss 0 1.1864813e-07
# Policy Loss 0 2.518356e-07
# Policy Loss 0 4.2978905e-07
# Policy Loss 0 5.5118346e-07
# Policy Loss 0 9.710329e-07
# Policy Loss 0 6.7279575e-07
# Policy Loss 0 6.436469e-07
# Policy Loss 0 5.617576e-07
# Policy Loss 0 4.6386475e-07
# Policy Loss 0 3.4381117e-07
# Policy Loss 0 2.206155e-07
# Policy Loss 0 1.3326479e-07
# Policy Loss 0 5.8947915e-08
# Policy Loss 0 2.4123597e-08
# Policy Loss 0 1.8706492e-08
# Policy Loss 0 2.6330287e-08
# Policy Loss 0 5.0951154e-08
# Policy Loss 0 7.049795e-08

# %%
tot_reward = 0
dqn.set_mode(training=False)
obs = env.reset()
while True:
    action = dqn.act(np.array(obs), deterministic=True)
    obs_new, r, is_terminal, info = env.step(action)

    tot_reward += r
    obs = obs_new
    if is_terminal:
        break
print('total_reward', tot_reward)

dqn.set_mode(training=True)
# Out:
# total_reward 12.0

# %% [markdown]
# Training Progress
# total_reward -535.8000000000001
# total_reward -3.3000000000000003
# total_reward -2.3
# total_reward -3.8000000000000003
# total_reward -1.7
