# %% [markdown]
# ## memory

# %%
import numpy as np
import collections

class Memory:
    def __init__(self, max_memory):
        self.max_memory = max_memory
        self.state = []
        self.new_state = []
        self.action = []
        self.reward = []
        self.is_terminal = []
        self.idx = 0

    def __len__(self):
        return len(self.state)

    def store_transition(self, s, s1, a, r, is_terminal):
        if len(self.state) <= self.max_memory:
            self.state.append(s)
            self.new_state.append(s1)
            self.action.append(a)
            self.reward.append(r)
            self.is_terminal.append(is_terminal)
        else:
            self.state[self.idx] = s
            self.new_state[self.idx] = s1
            self.action[self.idx] = a
            self.reward[self.idx] = r
            self.is_terminal[self.idx] = is_terminal
            self.idx = (self.idx + 1) % self.max_memory
        assert len(self.state) == len(self.new_state) == len(self.reward) == len(self.is_terminal) == len(self.action)


    def clear_memory(self):
        del self.state[:]
        del self.new_state[:]
        del self.action[:]
        del self.reward[:]
        del self.is_terminal[:]

    def sample(self, bs):
        idx = np.random.randint(len(self.state), size=bs)
        state, new_state, action, reward, is_terminal = [], [], [], [], []
        for i in idx:
            state.append(self.state[i])
            new_state.append(self.new_state[i])
            action.append(self.action[i])
            reward.append(self.reward[i])
            is_terminal.append(int(self.is_terminal[i]))
        return state, new_state, action, reward, is_terminal

    def update(self, **kwargs):
        pass

# %% [markdown]
# ## model DQN

# %%
import numpy as np
import torch
from rl.model import DDQN_Model, ICM_Model
from rl.per import PERMemory
from torch.nn.functional import mse_loss, cross_entropy, smooth_l1_loss, softmax
import settings as sett
import itertools
import os


class DQN:
    def __init__(self, state_dim, tau, action_dim, gamma, hidd_ch, lam, lr,
                 eps_sub, eps_sub_decay, beta, bs, target_interval, train_steps, max_memory,
                 conv, reward_rescale, n_proc, per=False, norm_input=True, logger=None):
        """
        :param state_dim: Shape of the state
        :param float tau: Weight for agent loss
        :param int action_dim: Number of actions
        :param float gamma: Discount for sub controller
        :param int hidd_ch: Number of hidden channels
        :param float lam: Scaler for ICM reward
        :param float lr: Learning rate
        :param float eps_sub: Eps greedy change for sub policies
        :param float eps_sub_decay: Epsilon decay for sub policy computed as eps * (1 - eps_decay) each step
        :param float beta: Weight for loss of fwd net vs inv net
        :param int bs: Batch size
        :param int target_interval: Number of train steps between target updates
        :param int train_steps: Number of training iterations for each call
        :param int max_memory: Max memory
        :param bool conv: Use or not convolutional networks
        :param bool per: Use or not prioritized experience replay
        """

        # Parameters
        self.logger = logger
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.target_interval = target_interval
        self.lr = lr
        self.bs = bs
        # policy parameters
        self.tau = tau
        self.eps_sub = eps_sub
        self.eps_sub_decay = 1 - eps_sub_decay
        self.gamma = gamma
        # ICM parameters
        self.beta = beta
        self.lam = lam

        self.n_proc = n_proc
        self.train_steps = train_steps
        self.reward_rescale = reward_rescale
        self.norm_input = norm_input
        self.per = per
        self.target_count = 0

        if self.per:
            memory = PERMemory
        else:
            memory = Memory

        # Create Policies / ICM modules / Memories
        self.agent = DDQN_Model(self.state_dim, self.action_dim, hidd_ch)
        self.agent_target = DDQN_Model(self.state_dim, self.action_dim, hidd_ch)
        self.agent_target.update_target(self.agent)
        self.agent_memory = memory(max_memory)
        self.agent_opt = torch.optim.Adam(self.agent.parameters(), lr=self.lr)
        # self.icm = ICM_Model(self.state_dim, self.action_dim, conv).to(sett.device)
        # self.icm_opt = torch.optim.Adam(self.icm.parameters(), lr=1e-3)

        # Send macro to correct device
        self.agent = self.agent.to(sett.device)
        self.agent_target = self.agent_target.to(sett.device)

    def act(self, obs, deterministic=False):
        x = torch.from_numpy(obs).float().to(sett.device)
        if self.norm_input:
            x /= 255

        eps = max(0.01, self.eps_sub) if not deterministic else 0.01
        actions = self.agent.act(x, eps=eps)
        return actions

    def set_mode(self, training=False):
        self.agent.train(training)

    def process_reward(self, reward):
        # Rescale reward if a scaling is provided
        if self.reward_rescale != 0:
            if self.reward_rescale == 1:
                reward = np.sign(reward)
            elif self.reward_rescale == 2:
                reward = np.clip(reward, -1, 1)
            else:
                reward *= self.reward_rescale
        return reward

    def save(self, i):
        if not os.path.isdir(sett.SAVEPATH):
            os.makedirs(sett.SAVEPATH)
        torch.save(self.agent.state_dict(), os.path.join(sett.SAVEPATH, 'agent_%s.pth' % i))

    def load(self, path, i):
        self.agent.load_state_dict(torch.load(os.path.join(path, 'agent_%s.pth' % i), map_location=sett.device))

    def store_transition(self, s, s1, a, reward, is_terminal):
        reward = self.process_reward(reward)
        self.agent_memory.store_transition(s, s1, a, reward, is_terminal)
#         for i in range(len(s)):
#             self.agent_memory.store_transition(s[i], s1[i], a[i], reward[i], is_terminal[i])

    def update(self):
        for i in range(self.train_steps):
            self._update()
            if self.logger is not None:
                self.logger.step += 1

    def _update(self):
        # First train each sub policy
        i = 0
        memory = self.agent_memory
        if len(memory) < self.bs * 10:
            return

        policy = self.agent
        target = self.agent_target
        # icm = self.icm
        policy_opt = self.agent_opt
        # icm_opt = self.icm_opt

        if self.per:
            state, new_state, action, reward, is_terminal, idxs, w_is = memory.sample(self.bs)
            reduction = 'none'
            self.logger.log_scalar(tag='Beta PER %i' % i, value=memory.beta)
        else:
            state, new_state, action, reward, is_terminal = memory.sample(self.bs)
            reduction = 'mean'

        if self.norm_input:
            state = np.array(state, dtype=np.float) / 255
            new_state = np.array(new_state, dtype=np.float) / 255

        state = torch.tensor(np.stack(state), dtype=torch.float).detach().to(sett.device)
        new_state = torch.tensor(np.stack(new_state), dtype=torch.float).detach().to(sett.device)
        action = torch.tensor(action).detach().to(sett.device)
        reward = torch.tensor(reward, dtype=torch.float).detach().to(sett.device)
        is_terminal = 1. - torch.tensor(is_terminal, dtype=torch.float).detach().to(sett.device)

        # Augment rewards with curiosity
        # curiosity_rewards = icm.curiosity_rew(state, new_state, action)
        # reward = (1 - 0.01) * reward + 0.01 * self.lam * curiosity_rewards
        reward = reward

        # Policy loss
        q = policy.forward(state)[torch.arange(self.bs), action]
        max_action = torch.argmax(policy.forward(new_state), dim=1)
        y = reward + self.gamma * target.forward(new_state)[torch.arange(self.bs), max_action] * is_terminal
        policy_loss = smooth_l1_loss(input=q, target=y.detach(), reduction=reduction).mean(-1)

        # ICM Loss
        # phi_hat = icm.forward(state, action)
        # phi_true = icm.phi_state(new_state)
        # fwd_loss = mse_loss(input=phi_hat, target=phi_true.detach(), reduction=reduction).mean(-1)
        # a_hat = icm.inverse_pred(state, new_state)
        # inv_loss = cross_entropy(input=a_hat, target=action.detach(), reduction=reduction)

        # Total loss
        # inv_loss = (1 - self.beta) * inv_loss
        # fwd_loss = self.beta * fwd_loss * 288
        # loss = self.tau * policy_loss + inv_loss + fwd_loss
        loss = policy_loss

        policy_opt.zero_grad()
        # icm_opt.zero_grad()
        loss.backward()
        # for param in policy.parameters():
        #     param.grad.data.clamp(-1, 1)
        policy_opt.step()
        # icm_opt.step()

        self.target_count += 1
        if self.target_count == self.target_interval:
            self.target_count = 0
            self.agent_target.update_target(self.agent)

        print('Policy Loss %i' % i, policy_loss.mean().cpu().data.numpy())
#         print('ICM Fwd Loss %i' % i, fwd_loss.mean().cpu().data.numpy())
#         print('ICM Inv Loss %i' % i, inv_loss.mean().cpu().data.numpy())
#         print('Total Policy Loss %i' % i, loss.mean().cpu().data.numpy())
#         print('Mean Curiosity Reward %i' % i, curiosity_rewards.mean().cpu().data.numpy())
        # print('Q values %i' % i, q.mean().cpu().data.numpy())
#         print('Target Boltz %i' % i, y.mean().cpu().data.numpy())

        # Reduce sub eps
        self.eps_sub = self.eps_sub * self.eps_sub_decay

        
import torch
from torch import nn
import torch.nn.functional as F
import numpy as np
import settings as sett


class DDQN_Model(nn.Module):
    def __init__(self, state_size, action_size, conv, macro=None, hidd_ch=256, conv_ch=32):
        super(DDQN_Model, self).__init__()
        self.action_size = action_size
        self.hidd_ch = hidd_ch
        state_size = 4
        if macro is None:
            self.backbone = nn.Sequential(
                nn.Linear(4, 256),
                nn.ReLU(),
            )


        self.features = nn.Sequential(
            nn.Linear(256, hidd_ch),
            nn.ReLU(),
            #nn.Linear(hidd_ch, hidd_ch),
            #nn.ReLU()
        )

        out_shape = hidd_ch
        # self.lstm_out = nn.LSTM(out_shape, hidd_ch, 1, batch_first=True)

        self.advantage = nn.Sequential(
            nn.Linear(hidd_ch, self.action_size)
        )

        self.value = nn.Sequential(
            nn.Linear(hidd_ch, 1)
        )

    def forward(self, obs, macro=None):
        obs = obs.view(-1, 4).float()
        backbone = self.backbone if macro is None else macro.backbone
        x = self.features(backbone(obs))
        x = x.view(x.size(0), -1)

        # h0 = torch.zeros(1, self.hidd_ch).to(sett.device)
        # c0 = torch.zeros(1, self.hidd_ch).to(sett.device)

        # lstm_out, (hn, cn) = self.lstm_out(x, (h0.detach(), c0.detach()))
        # x = lstm_out
        adv = self.advantage(x)
        value = self.value(x)
        return value + (adv - adv.mean(-1, keepdim=True))

    def act(self, state, eps, backbone=None):
        if np.random.random() > eps:
            q = self.forward(state, backbone)
            action = torch.argmax(q, dim=-1).cpu().data.numpy()
        else:
            action = np.random.randint(self.action_size, size=1)
        return action.item() if action.shape == (1,) else list(action.astype(np.int64))

    def update_target(self, model):
        self.load_state_dict(model.state_dict())


class ICM_Model(nn.Module):
    def __init__(self, state_size, action_size, conv):
        super(ICM_Model, self).__init__()

        self.action_size = action_size
        self.state_size = 4

        self.phi = nn.Sequential(
            nn.Linear(4, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU()
        )

        out_shape = self.phi(torch.randn(*((1,) + tuple([self.state_size])))).view(-1).size().numel()

        # Forward Model
        self.fwd = nn.Sequential(
            nn.Linear(out_shape + 1, 256),
            nn.ReLU(),
            nn.Linear(256, out_shape)
        )

        # Inverse Model
        self.inv = nn.Sequential(
            nn.Linear(out_shape * 2, 256),
            nn.ELU(),
            nn.Linear(256, action_size)
        )

    def forward(self, *input):
        obs, action = input
        action = action.view(-1, 1)
        phi = self.phi_state(obs)
        x = torch.cat((phi, action.float()), -1)
        phi_hat = self.fwd(x)
        return phi_hat

    def phi_state(self, s):
        s = s.view(-1, 4)
        x = s
        x = self.phi(x)
        return x.view(x.size(0), -1)

    def inverse_pred(self, s, s1):
        s = self.phi_state(s.view(-1, 4).float())
        s1 = self.phi_state(s1.view(-1, 4).float())
        x = torch.cat((s, s1), -1)
        return self.inv(x)

    def curiosity_rew(self, s, s1, a):
        phi_hat = self.forward(s.view(-1, 4), a)
        phi_s1 = self.phi_state(s1.view(-1, 4))
        cur_rew = 1 / 2 * (torch.norm(phi_hat - phi_s1, p=2, dim=-1) ** 2)
        return cur_rew

# %% [markdown]
# ## wrapper

# %%
import numpy as np
from gym import Wrapper
from gym.spaces import Box


class TimeLimit(Wrapper):
    def __init__(self, env, max_episode_steps=None):
        super(TimeLimit, self).__init__(env)
        self.max_episode_steps = max_episode_steps
        self._max_episode_steps = max_episode_steps
        self._elapsed_steps = None

    def step(self, action):
        observation, reward, done, terminal, info = self.env.step(action)
        self._elapsed_steps += 1
        if self._elapsed_steps >= self._max_episode_steps:
            done = True
        return observation, reward, done or terminal, info

    def reset(self, **kwargs):
        self._elapsed_steps = 0
        obs, info = self.env.reset(**kwargs)
        return obs

    from collections import deque
import numpy as np

from gym.spaces import Box
from gym import ObservationWrapper
from collections import deque


class LazyFrames(object):
    r"""Ensures common frames are only stored once to optimize memory use. 

    To further reduce the memory use, it is optionally to turn on lz4 to 
    compress the observations.

    .. note::

        This object should only be converted to numpy array just before forward pass. 

    """
    def __init__(self, frames, lz4_compress=False):
        if lz4_compress:
            from lz4.block import compress
            self.shape = frames[0].shape
            self.dtype = frames[0].dtype
            frames = [compress(frame) for frame in frames]
        self._frames = frames
        self.lz4_compress = lz4_compress

    def __array__(self, dtype=None):
        if self.lz4_compress:
            from lz4.block import decompress
            frames = [np.frombuffer(decompress(frame), dtype=self.dtype).reshape(self.shape) for frame in self._frames]
        else:
            frames = self._frames
        out = np.stack(frames, axis=0)
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self.__array__())

    def __getitem__(self, i):
        return self.__array__()[i]


class FrameStack(ObservationWrapper):
    r"""Observation wrapper that stacks the observations in a rolling manner. 

    For example, if the number of stacks is 4, then the returned observation contains
    the most recent 4 observations. For environment 'Pendulum-v0', the original observation
    is an array with shape [3], so if we stack 4 observations, the processed observation
    has shape [3, 4]. 

    .. note::

        To be memory efficient, the stacked observations are wrapped by :class:`LazyFrame`.

    .. note::

        The observation space must be `Box` type. If one uses `Dict`
        as observation space, it should apply `FlattenDictWrapper` at first. 

    Example::

        >>> import gym
        >>> env = gym.make('PongNoFrameskip-v0')
        >>> env = FrameStack(env, 4)
        >>> env.observation_space
        Box(4, 210, 160, 3)

    Args:
        env (Env): environment object
        num_stack (int): number of stacks

    """
    def __init__(self, env, num_stack, lz4_compress=False):
        super(FrameStack, self).__init__(env)
        self.num_stack = num_stack
        self.lz4_compress = lz4_compress

        self.frames = deque(maxlen=num_stack)

        low = np.repeat(self.observation_space.low[np.newaxis, ...], num_stack, axis=0)
        high = np.repeat(self.observation_space.high[np.newaxis, ...], num_stack, axis=0)
        self.observation_space = Box(low=low, high=high, dtype=self.observation_space.dtype)

    def _get_observation(self):
        assert len(self.frames) == self.num_stack, (len(self.frames), self.num_stack)
        return LazyFrames(list(self.frames), self.lz4_compress)

    def step(self, action):
        observation, reward, done, info = self.env.step(action)
        self.frames.append(observation)
        return self._get_observation(), reward, done, info

    def reset(self, **kwargs):
        observation = self.env.reset(**kwargs)
        [self.frames.append(observation) for _ in range(self.num_stack)]
        return self._get_observation()

# %% [markdown]
# ## env

# %%
from gym import Env
import numpy as np
from gym import error, spaces, utils
from gym.utils import seeding
import logging
import gym

logger = logging.getLogger(__name__)


class DimGridEnvironment(Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, size, hard):
        super(DimGridEnvironment, self).__init__()
        self.size = size
        self.observation_space = spaces.Box(0, 1, [self.size, self.size, 1])
        self.action_space = spaces.Discrete(5)
        self.alternate_dim = False
        self.dim0 = None
        self.dim1 = None
        self.dict = {'0': {'empty': 0, 'wall': 0.33, 'player': 0.66, 'goal': 1},
                     '1': {'empty': 1, 'wall': 0.66, 'player': 0.33, 'goal': 0}}
        self.action_dict = {0: [0, -1], 1: [-1, 0], 2: [0, 1], 3: [1, 0], 4: 4}
        self.goal = None
        self.player_pos = None
        self.walls = None
        self.hard = hard
        self.seed = self._seed()

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return seed

    def _compute_action(self, action):
        action = self.action_dict[action]
        reward = 0.

        if action == 4: # Change dimension
            self.alternate_dim = not self.alternate_dim
        else:
            new_pos = tuple(np.array(self.player_pos) + action)
            if any(np.array(new_pos) == self.size) or any(np.array(new_pos) < 0):
                reward = -1. if not self.hard else 0.
                return reward, True
            self.player_pos = new_pos
            touched_wall = self.walls[self.player_pos]
            if self.alternate_dim:
                reward += -0.1
            else:
                if touched_wall:
                    reward += -0.5
                    if self.hard:
                        return 0., True

        terminal = True if self.player_pos == self.goal else False
        reward += int(terminal)
        return reward, terminal

    def step(self, action):
        reward, terminal = self._compute_action(action)
        obs = self._get_obs()
        return obs, reward, terminal, {}

    def _get_obs(self):
        if self.alternate_dim:
            self.dim1[self.walls] = self.dict['1']['wall']
            self.dim1[self.player_pos] = self.dict['1']['player']
            return self.dim1
        else:
            self.dim0[self.walls] = self.dict['0']['wall']
            self.dim0[self.player_pos] = self.dict['0']['player']
            return self.dim0

    def reset(self):
        y = np.random.choice(self.size, 2, replace=False)
        x = np.random.choice(self.size, 2, replace=False)
        self.player_pos = tuple([x[0], y[0]])
        self.goal = tuple([x[1], y[1]])

        # Fill dim0
        self.dim0 = np.zeros(self.observation_space.shape)
        self.walls = np.random.rand(*self.observation_space.shape) > 0.5
        self.dim0[self.walls] = self.dict['0']['wall']
        self.dim0[self.goal] = self.dict['0']['goal']
        self.dim0[self.player_pos] = self.dict['0']['player']

        # Fill dim1
        self.dim1 = np.ones(self.observation_space.shape)
        self.dim1[self.walls] = self.dict['1']['wall']
        self.dim1[self.goal] = self.dict['1']['goal']
        self.dim1[self.player_pos] = self.dict['1']['player']

        self.walls[self.goal] = False
        self.walls[self.player_pos] = False
        self.alternate_dim = False
        return self._get_obs()

    def render(self, mode='human', close=False):
        logger.info('\n Dim0: %s \n Dim1:  %s' % (self.dim0, self.dim1))

# %% [markdown]
# ## core

# %%
# Setup env
env = gym.make('CartPole-v1')
env = TimeLimit(env, max_episode_steps=500)
# env = FrameStack(env, num_stack=1)

# %%
obs = env.reset()

# Setup Model
n_actions = env.action_space.n if env.action_space.shape == () else env.action_space.shape[0]
n_state = env.observation_space.n if env.observation_space.shape == () else env.observation_space.shape
print('n_actions', n_actions)
print('n_state', n_state)

conv = True if isinstance(n_state, tuple) else False
conv = False
print('conv', conv)
# Out:
# n_actions 2
# n_state (4,)
# conv False

# %%
dqn = DQN(state_dim=4,
          tau=0.001,
          action_dim=n_actions,
          gamma=0.95,
          hidd_ch=256,
          lam=0.001,
          lr=1e-4,
          eps_sub=0.3,
          eps_sub_decay=1,
          beta=0.9,
          bs=128,
          target_interval=10,
          train_steps=1,
          max_memory=int(1e6),
          conv=conv,
          per=None,
          n_proc=1,
          reward_rescale=False,
          logger=None,
          norm_input=False
          )

# %%
np.array(obs).reshape(-1)
# Out:
# array([ 0.14419308,  1.5188859 , -0.2162334 , -2.5654423 ], dtype=float32)

# %%
for _ in range(10000):
    dqn.set_mode(training=False)
    obs = env.reset()
    for i in range(512):
        action = dqn.act(np.array(obs).reshape(-1))
        obs_new, r, is_terminal, info = env.step(action)
        dqn.store_transition(np.array(obs).reshape(-1), np.array(obs_new).reshape(-1), action, r, is_terminal)
        if is_terminal:
            obs = env.reset()
    dqn.set_mode(training=True)
    dqn.update()
# Out:
# Policy Loss 0 604.7045
# Policy Loss 0 675.34216
# Policy Loss 0 989.8718
# Policy Loss 0 1610.032
# Policy Loss 0 1452.9939
# Policy Loss 0 1975.2595
# Policy Loss 0 1958.0645
# Policy Loss 0 1830.3772
# Policy Loss 0 2064.954
# Policy Loss 0 1726.6636
# Policy Loss 0 2004.5303
# Policy Loss 0 2927.1484
# Policy Loss 0 2753.8633
# Policy Loss 0 1953.72
# Policy Loss 0 3033.5583
# Policy Loss 0 3021.8313
# Policy Loss 0 3560.927
# Policy Loss 0 3797.3677
# Policy Loss 0 3560.0483
# Policy Loss 0 3405.7344
# Policy Loss 0 4924.661
# Policy Loss 0 5250.58
# Policy Loss 0 4910.124
# Policy Loss 0 4356.9424
# Policy Loss 0 4207.614
# Policy Loss 0 4679.3457
# Policy Loss 0 5033.8857
# Policy Loss 0 4336.6626
# Policy Loss 0 5366.8877
# Policy Loss 0 5742.596
# Policy Loss 0 6741.076
# Policy Loss 0 6032.355
# Policy Loss 0 6656.4326
# Policy Loss 0 6418.996
# Policy Loss 0 7455.3906
# Policy Loss 0 5829.415
# Policy Loss 0 6153.4033
# Policy Loss 0 6508.756
# Policy Loss 0 6364.0664
# Policy Loss 0 6597.4478
# Policy Loss 0 6847.6997
# Policy Loss 0 8106.9336
# Policy Loss 0 7964.78
# Policy Loss 0 8295.283
# Policy Loss 0 8000.4795
# Policy Loss 0 8532.653
# Policy Loss 0 7967.6567
# Policy Loss 0 9369.785
# Policy Loss 0 9518.844
# Policy Loss 0 9399.365
# Policy Loss 0 9290.777
# Policy Loss 0 9194.805
# Policy Loss 0 9354.763
# Policy Loss 0 8799.065
# Policy Loss 0 8199.809
# Policy Loss 0 9150.429
# Policy Loss 0 8963.585
# Policy Loss 0 9363.228
# Policy Loss 0 8122.656
# Policy Loss 0 8885.625
# Policy Loss 0 9572.633
# Policy Loss 0 10126.877
# Policy Loss 0 8809.164
# Policy Loss 0 9955.798
# Policy Loss 0 8767.102
# Policy Loss 0 9032.625
# Policy Loss 0 10174.145
# Policy Loss 0 9069.119
# Policy Loss 0 8539.449
# Policy Loss 0 7775.8535
# Policy Loss 0 9372.485
# Policy Loss 0 8716.264
# Policy Loss 0 9703.853
# Policy Loss 0 8961.78
# Policy Loss 0 9336.758
# Policy Loss 0 9069.42
# Policy Loss 0 9745.29
# Policy Loss 0 8078.91
# Policy Loss 0 8510.643
# Policy Loss 0 8663.699
# Policy Loss 0 7983.7236
# Policy Loss 0 9155.916
# Policy Loss 0 9684.222
# Policy Loss 0 9192.486
# Policy Loss 0 8923.402
# Policy Loss 0 8458.587
# Policy Loss 0 9079.227
# Policy Loss 0 8838.592
# Policy Loss 0 8908.037
# Policy Loss 0 9031.709
# Policy Loss 0 9356.65
# Policy Loss 0 8890.53
# Policy Loss 0 9141.897
# Policy Loss 0 8644.681
# Policy Loss 0 9310.06
# Policy Loss 0 7971.7354
# Policy Loss 0 9565.65
# Policy Loss 0 8468.373
# Policy Loss 0 10356.152
# Policy Loss 0 9890.66
# Policy Loss 0 8416.545
# Policy Loss 0 8021.3267
# Policy Loss 0 8632.737
# Policy Loss 0 8312.416
# Policy Loss 0 8397.16
# Policy Loss 0 8289.155
# Policy Loss 0 9077.805
# Policy Loss 0 9442.681
# Policy Loss 0 9050.49
# Policy Loss 0 9917.406
# Policy Loss 0 9255.031
# Policy Loss 0 8798.964
# Policy Loss 0 8904.488
# Policy Loss 0 8943.169
# Policy Loss 0 9435.766
# Policy Loss 0 8706.572
# Policy Loss 0 9055.16
# Policy Loss 0 9187.795
# Policy Loss 0 8028.1484
# Policy Loss 0 8614.092
# Policy Loss 0 9235.806
# Policy Loss 0 8574.404
# Policy Loss 0 9285.213
# Policy Loss 0 10301.3955
# Policy Loss 0 9183.653
# Policy Loss 0 9053.371
# Policy Loss 0 9019.713
# Policy Loss 0 9216.674
# Policy Loss 0 9308.459
# Policy Loss 0 9592.062
# Policy Loss 0 8399.48
# Policy Loss 0 9012.518
# Policy Loss 0 9228.649
# Policy Loss 0 8161.2305
# Policy Loss 0 9254.826
# Policy Loss 0 9331.64
# Policy Loss 0 7179.235
# Policy Loss 0 7918.08
# Policy Loss 0 9565.487
# Policy Loss 0 8841.15
# Policy Loss 0 8102.0166
# Policy Loss 0 9082.4
# Policy Loss 0 8260.862
# Policy Loss 0 9154.426
# Policy Loss 0 7955.033
# Policy Loss 0 9002.767
# Policy Loss 0 8791.808
# Policy Loss 0 9426.711
# Policy Loss 0 9835.332
# Policy Loss 0 8702.848
# Policy Loss 0 8860.717
# Policy Loss 0 9876.573
# Policy Loss 0 9885.908
# Policy Loss 0 8346.661
# Policy Loss 0 9420.632
# Policy Loss 0 8184.7793
# Policy Loss 0 8966.535
# Policy Loss 0 9608.652
# Policy Loss 0 9609.299
# Policy Loss 0 8684.422
# Policy Loss 0 8587.268
# Policy Loss 0 8568.694
# Policy Loss 0 10282.205
# Policy Loss 0 9323.51
# Policy Loss 0 9234.352
# Policy Loss 0 7776.465
# Policy Loss 0 9174.423
# Policy Loss 0 8362.842
# Policy Loss 0 8685.746
# Policy Loss 0 9523.898
# Policy Loss 0 9415.641
# Policy Loss 0 9383.161
# Policy Loss 0 8976.44
# Policy Loss 0 9514.961
# Policy Loss 0 10510.574
# Policy Loss 0 9056.869
# Policy Loss 0 9928.996
# Policy Loss 0 9360.919
# Policy Loss 0 8899.523
# Policy Loss 0 9485.388
# Policy Loss 0 10231.828
# Policy Loss 0 10767.638
# Policy Loss 0 10039.775
# Policy Loss 0 9410.732
# Policy Loss 0 8837.765
# Policy Loss 0 8299.131
# Policy Loss 0 8876.071
# Policy Loss 0 9889.446
# Policy Loss 0 8311.555
# Policy Loss 0 9179.396
# Policy Loss 0 9300.9
# Policy Loss 0 10377.711
# Policy Loss 0 10089.388
# Policy Loss 0 10499.5205
# Policy Loss 0 9098.84
# Policy Loss 0 8682.636
# Policy Loss 0 9367.696
# Policy Loss 0 9796.41
# Policy Loss 0 9571.056
# Policy Loss 0 9472.385
# Policy Loss 0 8967.046
# Policy Loss 0 9614.646
# Policy Loss 0 8165.8896
# Policy Loss 0 9470.596
# Policy Loss 0 8751.652
# Policy Loss 0 9203.601
# Policy Loss 0 8772.527
# Policy Loss 0 10224.318
# Policy Loss 0 8763.928
# Policy Loss 0 9128.16
# Policy Loss 0 9971.504
# Policy Loss 0 9217.707
# Policy Loss 0 8894.279
# Policy Loss 0 8963.219
# Policy Loss 0 9601.135
# Policy Loss 0 10193.027
# Policy Loss 0 8316.441
# Policy Loss 0 9515.086
# Policy Loss 0 9036.508
# Policy Loss 0 10245.65
# Policy Loss 0 8617.468
# Policy Loss 0 8544.157
# Policy Loss 0 8930.582
# Policy Loss 0 10710.152
# Policy Loss 0 9314.123
# Policy Loss 0 9794.909
# Policy Loss 0 8815.979
# Policy Loss 0 8925.07
# Policy Loss 0 9569.285
# Policy Loss 0 10054.215
# Policy Loss 0 9873.202
# Policy Loss 0 8836.799
# Policy Loss 0 9480.269
# Policy Loss 0 9436.276
# Policy Loss 0 8962.101
# Policy Loss 0 9010.637
# Policy Loss 0 8484.591
# Policy Loss 0 11746.693
# Policy Loss 0 8922.018
# Policy Loss 0 8423.908
# Policy Loss 0 9305.621
# Policy Loss 0 8396.227
# Policy Loss 0 8575.297
# Policy Loss 0 9159.404
# Policy Loss 0 9366.691
# Policy Loss 0 9378.161
# Policy Loss 0 8372.428
# Policy Loss 0 8758.994
# Policy Loss 0 9580.284
# Policy Loss 0 7715.414
# Policy Loss 0 9926.365
# Policy Loss 0 9063.877
# Policy Loss 0 9708.742
# Policy Loss 0 9817.0
# Policy Loss 0 9423.422
# Policy Loss 0 9076.646
# Policy Loss 0 8109.9775
# Policy Loss 0 8355.081
# Policy Loss 0 9966.34
# Policy Loss 0 7718.8936
# Policy Loss 0 9481.285
# Policy Loss 0 8979.39
# Policy Loss 0 8547.744
# Policy Loss 0 9795.613
# Policy Loss 0 8695.515
# Policy Loss 0 8931.444
# Policy Loss 0 9443.83
# Policy Loss 0 8805.308
# Policy Loss 0 9876.725
# Policy Loss 0 10276.277
# Policy Loss 0 8408.329
# Policy Loss 0 9001.559
# Policy Loss 0 8289.611
# Policy Loss 0 9287.146
# Policy Loss 0 10182.774
# Policy Loss 0 9799.83
# Policy Loss 0 8545.997
# Policy Loss 0 9479.295
# Policy Loss 0 9761.199
# Policy Loss 0 8645.265
# Policy Loss 0 8963.641
# Policy Loss 0 7691.0864
# Policy Loss 0 10111.637
# Policy Loss 0 9073.979
# Policy Loss 0 8783.34
# Policy Loss 0 9716.035
# Policy Loss 0 9966.066
# Policy Loss 0 10143.758
# Policy Loss 0 10566.042
# Policy Loss 0 9376.275
# Policy Loss 0 9462.466
# Policy Loss 0 8256.119
# Policy Loss 0 9770.594
# Policy Loss 0 10365.302
# Policy Loss 0 8503.944
# Policy Loss 0 10184.593
# Policy Loss 0 10110.036
# Policy Loss 0 9468.009
# Policy Loss 0 8635.629
# Policy Loss 0 9112.539
# Policy Loss 0 7731.634
# Policy Loss 0 10141.543
# Policy Loss 0 9786.801
# Policy Loss 0 9050.448
# Policy Loss 0 8997.394
# Policy Loss 0 9309.981
# Policy Loss 0 8717.35
# Policy Loss 0 9861.88
# Policy Loss 0 9405.02
# Policy Loss 0 8993.219
# Policy Loss 0 8360.41
# Policy Loss 0 9120.214
# Policy Loss 0 8835.555
# Policy Loss 0 9169.963
# Policy Loss 0 10195.798
# Policy Loss 0 9326.741
# Policy Loss 0 8903.059
# Policy Loss 0 9619.898
# Policy Loss 0 9824.164
# Policy Loss 0 9907.181
# Policy Loss 0 9261.885
# Policy Loss 0 10234.881
# Policy Loss 0 10885.837
# Policy Loss 0 9513.122
# Policy Loss 0 10254.374
# Policy Loss 0 9904.884
# Policy Loss 0 9411.694
# Policy Loss 0 10270.933
# Policy Loss 0 9265.334
# Policy Loss 0 10237.594
# Policy Loss 0 10096.119
# Policy Loss 0 9748.314
# Policy Loss 0 8658.869
# Policy Loss 0 8134.1533
# Policy Loss 0 9218.362
# Policy Loss 0 8368.357
# Policy Loss 0 9084.957
# Policy Loss 0 9819.078
# Policy Loss 0 9630.451
# Policy Loss 0 9305.481
# Policy Loss 0 8865.972
# Policy Loss 0 10036.877
# Policy Loss 0 9116.648
# Policy Loss 0 8030.1206
# Policy Loss 0 9563.035
# Policy Loss 0 8672.163
# Policy Loss 0 8820.553
# Policy Loss 0 8303.816
# Policy Loss 0 8072.2617
# Policy Loss 0 10699.226
# Policy Loss 0 9873.545
# Policy Loss 0 9519.932
# Policy Loss 0 8286.494
# Policy Loss 0 9007.802
# Policy Loss 0 8445.927
# Policy Loss 0 9215.367
# Policy Loss 0 8698.646
# Policy Loss 0 10626.385
# Policy Loss 0 9687.709
# Policy Loss 0 10465.1045
# Policy Loss 0 9149.719
# Policy Loss 0 10171.099
# Policy Loss 0 10490.943
# Policy Loss 0 9706.064
# Policy Loss 0 9354.295
# Policy Loss 0 8944.268
# Policy Loss 0 9564.354
# Policy Loss 0 8762.836
# Policy Loss 0 9846.121
# Policy Loss 0 10274.445
# Policy Loss 0 9987.539
# Policy Loss 0 8435.448
# Policy Loss 0 10680.208
# Policy Loss 0 8807.286
# Policy Loss 0 10632.146
# Policy Loss 0 9673.611
# Policy Loss 0 10804.795
# Policy Loss 0 9835.402
# Policy Loss 0 8751.574
# Policy Loss 0 9749.145
# Policy Loss 0 9867.527
# Policy Loss 0 8617.137
# Policy Loss 0 8184.6255
# Policy Loss 0 9213.229
# Policy Loss 0 9754.245
# Policy Loss 0 9159.678
# Policy Loss 0 10543.814
# Policy Loss 0 9489.931
# Policy Loss 0 9903.147
# Policy Loss 0 9041.405
# Policy Loss 0 9882.09
# Policy Loss 0 9187.804
# Policy Loss 0 10081.178
# Policy Loss 0 8375.463
# Policy Loss 0 9828.568
# Policy Loss 0 9139.102
# Policy Loss 0 9260.53
# Policy Loss 0 9661.779
# Policy Loss 0 9472.963
# Policy Loss 0 7914.8936
# Policy Loss 0 9672.611
# Policy Loss 0 9545.437
# Policy Loss 0 9101.533
# Policy Loss 0 9873.896
# Policy Loss 0 9877.109
# Policy Loss 0 10416.807
# Policy Loss 0 8838.164
# Policy Loss 0 9821.535
# Policy Loss 0 9282.739
# Policy Loss 0 9496.863
# Policy Loss 0 10550.972
# Policy Loss 0 10387.597
# Policy Loss 0 10811.48
# Policy Loss 0 10058.745
# Policy Loss 0 8403.629
# Policy Loss 0 9222.359
# Policy Loss 0 9726.879
# Policy Loss 0 8737.619
# Policy Loss 0 9590.293
# Policy Loss 0 10205.352
# Policy Loss 0 9740.447
# Policy Loss 0 10794.115
# Policy Loss 0 9910.693
# Policy Loss 0 9379.155
# Policy Loss 0 8588.865
# Policy Loss 0 9699.963
# Policy Loss 0 9213.711
# Policy Loss 0 9401.152
# Policy Loss 0 9122.567
# Policy Loss 0 8137.7085
# Policy Loss 0 8868.437
# Policy Loss 0 8371.42
# Policy Loss 0 10320.704
# Policy Loss 0 9177.402
# Policy Loss 0 9626.457
# Policy Loss 0 9994.79
# Policy Loss 0 9879.637
# Policy Loss 0 10460.062
# Policy Loss 0 9783.699
# Policy Loss 0 9737.594
# Policy Loss 0 9158.734
# Policy Loss 0 10081.345
# Policy Loss 0 9970.106
# Policy Loss 0 9166.885
# Policy Loss 0 9939.822
# Policy Loss 0 9316.297
# Policy Loss 0 9379.857
# Policy Loss 0 10688.328
# Policy Loss 0 10784.014
# Policy Loss 0 10198.3955
# Policy Loss 0 11305.454
# Policy Loss 0 8370.334
# Policy Loss 0 9672.064
# Policy Loss 0 9270.418
# Policy Loss 0 10210.621
# Policy Loss 0 9558.781
# Policy Loss 0 9152.121
# Policy Loss 0 10877.894
# Policy Loss 0 9549.373
# Policy Loss 0 9155.541
# Policy Loss 0 9521.719
# Policy Loss 0 8291.897
# Policy Loss 0 10309.546
# Policy Loss 0 10308.109
# Policy Loss 0 9658.451
# Policy Loss 0 9608.193
# Policy Loss 0 9143.107
# Policy Loss 0 8610.491
# Policy Loss 0 9204.351
# Policy Loss 0 10192.482
# Policy Loss 0 9450.577
# Policy Loss 0 9685.338
# Policy Loss 0 9829.786
# Policy Loss 0 9176.625
# Policy Loss 0 8983.43
# Policy Loss 0 10843.646
# Policy Loss 0 9691.631
# Policy Loss 0 10305.5205
# Policy Loss 0 9788.845
# Policy Loss 0 9907.992
# Policy Loss 0 9384.991
# Policy Loss 0 10888.993
# Policy Loss 0 10200.8955
# Policy Loss 0 9928.645
# Policy Loss 0 10548.358
# Policy Loss 0 10936.304
# Policy Loss 0 9208.508
# Policy Loss 0 10080.808
# Policy Loss 0 9654.27
# Policy Loss 0 9451.57
# Policy Loss 0 10424.832
# Policy Loss 0 10718.168
# Policy Loss 0 9047.769
# Policy Loss 0 10006.656
# Policy Loss 0 9127.674
# Policy Loss 0 9234.49
# Policy Loss 0 9272.658
# Policy Loss 0 10151.298
# Policy Loss 0 9152.037
# Policy Loss 0 10246.909
# Policy Loss 0 10092.617
# Policy Loss 0 11377.435
# Policy Loss 0 9637.065
# Policy Loss 0 8132.0986
# Policy Loss 0 9788.115
# Policy Loss 0 10367.651
# Policy Loss 0 9387.019
# Policy Loss 0 9792.977
# Policy Loss 0 9055.931
# Policy Loss 0 10589.336
# Policy Loss 0 10614.428
# Policy Loss 0 9204.814
# Policy Loss 0 9675.129
# Policy Loss 0 10257.26
# Policy Loss 0 10422.065
# Policy Loss 0 8637.459
# Policy Loss 0 8618.751
# Policy Loss 0 10170.977
# Policy Loss 0 8891.064
# Policy Loss 0 10575.473
# Policy Loss 0 10354.322
# Policy Loss 0 10127.29
# Policy Loss 0 10688.761
# Policy Loss 0 9694.769
# Policy Loss 0 10533.292
# Policy Loss 0 8888.225
# Policy Loss 0 11081.832
# Policy Loss 0 9152.295
# Policy Loss 0 10938.625
# Policy Loss 0 9518.163
# Policy Loss 0 11649.403
# Policy Loss 0 9691.387
# Policy Loss 0 9925.738
# Policy Loss 0 9917.558
# Policy Loss 0 10395.498
# Policy Loss 0 9909.76
# Policy Loss 0 9848.644
# Policy Loss 0 10350.326
# Policy Loss 0 9279.724
# Policy Loss 0 9752.433
# Policy Loss 0 8415.946
# Policy Loss 0 10861.904
# Policy Loss 0 9264.859
# Policy Loss 0 10633.6875
# Policy Loss 0 10720.993
# Policy Loss 0 10132.858
# Policy Loss 0 10627.48
# Policy Loss 0 10376.533
# Policy Loss 0 10181.734
# Policy Loss 0 10724.609
# Policy Loss 0 9504.848
# Policy Loss 0 9942.969
# Policy Loss 0 11313.23
# Policy Loss 0 9212.029
# Policy Loss 0 10842.318
# Policy Loss 0 10710.484
# Policy Loss 0 10284.642
# Policy Loss 0 10677.235
# Policy Loss 0 9860.637
# Policy Loss 0 9796.221
# Policy Loss 0 10099.762
# Policy Loss 0 9817.342
# Policy Loss 0 9543.631
# Policy Loss 0 10519.34
# Policy Loss 0 9751.252
# Policy Loss 0 9852.424
# Policy Loss 0 9477.911
# Policy Loss 0 9229.809
# Policy Loss 0 10339.287
# Policy Loss 0 9062.206
# Policy Loss 0 8951.672
# Policy Loss 0 9967.609
# Policy Loss 0 9057.222
# Policy Loss 0 9266.536
# Policy Loss 0 10044.329
# Policy Loss 0 9525.876
# Policy Loss 0 10663.42
# Policy Loss 0 9966.372
# Policy Loss 0 10979.949
# Policy Loss 0 11517.017
# Policy Loss 0 10671.016
# Policy Loss 0 10331.268
# Policy Loss 0 10658.865
# Policy Loss 0 10646.648
# Policy Loss 0 10500.855
# Policy Loss 0 10115.229
# Policy Loss 0 10936.703
# Policy Loss 0 9126.049
# Policy Loss 0 8791.83
# Policy Loss 0 9824.592
# Policy Loss 0 10938.254
# Policy Loss 0 10640.854
# Policy Loss 0 10159.578
# Policy Loss 0 10432.841
# Policy Loss 0 8842.714
# Policy Loss 0 9806.675
# Policy Loss 0 9744.623
# Policy Loss 0 9445.616
# Policy Loss 0 10089.422
# Policy Loss 0 11174.951
# Policy Loss 0 10941.588
# Policy Loss 0 9206.455
# Policy Loss 0 10832.907
# Policy Loss 0 10043.25
# Policy Loss 0 9938.044
# Policy Loss 0 9182.2295
# Policy Loss 0 10285.197
# Policy Loss 0 9633.196
# Policy Loss 0 10374.367
# Policy Loss 0 9722.227
# Policy Loss 0 11140.316
# Policy Loss 0 9379.894
# Policy Loss 0 10295.873
# Policy Loss 0 10292.754
# Policy Loss 0 10057.846
# Policy Loss 0 9943.557
# Policy Loss 0 9781.561
# Policy Loss 0 10139.877
# Policy Loss 0 11039.3545
# Policy Loss 0 9061.996
# Policy Loss 0 9129.523
# Policy Loss 0 10619.424
# Policy Loss 0 10892.586
# Policy Loss 0 8732.556
# Policy Loss 0 8830.394
# Policy Loss 0 9973.955
# Policy Loss 0 8714.201
# Policy Loss 0 8449.658
# Policy Loss 0 9855.225
# Policy Loss 0 9673.197
# Policy Loss 0 9005.264
# Policy Loss 0 10662.533
# Policy Loss 0 10505.591
# Policy Loss 0 10047.341
# Policy Loss 0 9927.6
# Policy Loss 0 11088.099
# Policy Loss 0 10171.478
# Policy Loss 0 9527.123
# Policy Loss 0 8528.328
# Policy Loss 0 10690.069
# Policy Loss 0 10197.427
# Policy Loss 0 10458.28
# Policy Loss 0 10652.492
# Policy Loss 0 9501.849
# Policy Loss 0 9776.8125
# Policy Loss 0 9783.307
# Policy Loss 0 11302.9375
# Policy Loss 0 9091.489
# Policy Loss 0 9305.389
# Policy Loss 0 9582.498
# Policy Loss 0 10128.601
# Policy Loss 0 9626.137
# Policy Loss 0 9540.209
# Policy Loss 0 10694.223
# Policy Loss 0 9804.25
# Policy Loss 0 10191.857
# Policy Loss 0 9013.295
# Policy Loss 0 11044.467
# Policy Loss 0 9730.557
# Policy Loss 0 9156.054
# Policy Loss 0 9055.24
# Policy Loss 0 10098.947
# Policy Loss 0 9617.145
# Policy Loss 0 9708.807
# Policy Loss 0 10971.505
# Policy Loss 0 9917.564
# Policy Loss 0 8930.496
# Policy Loss 0 10740.91
# Policy Loss 0 10128.016
# Policy Loss 0 10096.721
# Policy Loss 0 9666.405
# Policy Loss 0 10385.553
# Policy Loss 0 9129.279
# Policy Loss 0 10521.625
# Policy Loss 0 8460.058
# Policy Loss 0 9331.067
# Policy Loss 0 10335.42
# Policy Loss 0 10159.559
# Policy Loss 0 10706.3125
# Policy Loss 0 10751.729
# Policy Loss 0 9458.569
# Policy Loss 0 8949.687
# Policy Loss 0 11014.883
# Policy Loss 0 10539.467
# Policy Loss 0 9073.777
# Policy Loss 0 10342.5
# Policy Loss 0 9258.197
# Policy Loss 0 9283.686
# Policy Loss 0 9061.27
# Policy Loss 0 9842.818
# Policy Loss 0 10488.258
# Policy Loss 0 11226.773
# Policy Loss 0 10919.666
# Policy Loss 0 9767.745
# Policy Loss 0 10633.811
# Policy Loss 0 10083.946
# Policy Loss 0 8803.298
# Policy Loss 0 10058.418
# Policy Loss 0 10752.822
# Policy Loss 0 10103.221
# Policy Loss 0 10122.121
# Policy Loss 0 11405.268
# Policy Loss 0 11060.134
# Policy Loss 0 8827.736
# Policy Loss 0 10999.527
# Policy Loss 0 10123.0
# Policy Loss 0 10959.789
# Policy Loss 0 9202.01
# Policy Loss 0 9934.307
# Policy Loss 0 8574.432
# Policy Loss 0 10973.074
# Policy Loss 0 9885.921
# Policy Loss 0 10294.49
# Policy Loss 0 8766.316
# Policy Loss 0 9384.453
# Policy Loss 0 8959.107
# Policy Loss 0 9695.354
# Policy Loss 0 10629.287
# Policy Loss 0 10043.654
# Policy Loss 0 10828.9
# Policy Loss 0 9324.629
# Policy Loss 0 10393.684
# Policy Loss 0 9369.926
# Policy Loss 0 11852.65
# Policy Loss 0 9620.428
# Policy Loss 0 10569.193
# Policy Loss 0 10323.467
# Policy Loss 0 9969.783
# Policy Loss 0 11045.382
# Policy Loss 0 10875.908
# Policy Loss 0 10192.1
# Policy Loss 0 11136.621
# Policy Loss 0 10623.08
# Policy Loss 0 9579.33
# Policy Loss 0 10486.123
# Policy Loss 0 10089.545
# Policy Loss 0 10696.047
# Policy Loss 0 10143.717
# Policy Loss 0 9326.357
# Policy Loss 0 9345.545
# Policy Loss 0 10247.243
# Policy Loss 0 9370.742
# Policy Loss 0 11236.181
# Policy Loss 0 10113.584
# Policy Loss 0 9031.009
# Policy Loss 0 9345.191
# Policy Loss 0 10103.582
# Policy Loss 0 10420.137
# Policy Loss 0 9215.375
# Policy Loss 0 11340.617
# Policy Loss 0 9539.215
# Policy Loss 0 10594.868
# Policy Loss 0 10059.62
# Policy Loss 0 9671.764
# Policy Loss 0 9411.879
# Policy Loss 0 9711.526
# Policy Loss 0 11293.452
# Policy Loss 0 9718.682
# Policy Loss 0 9210.242
# Policy Loss 0 9937.618
# Policy Loss 0 10785.713
# Policy Loss 0 9208.543
# Policy Loss 0 11058.406
# Policy Loss 0 10195.7295
# Policy Loss 0 8658.348
# Policy Loss 0 10946.984
# Policy Loss 0 10595.102
# Policy Loss 0 9710.381
# Policy Loss 0 10645.543
# Policy Loss 0 9661.666
# Policy Loss 0 8959.933
# Policy Loss 0 10874.677
# Policy Loss 0 9647.669
# Policy Loss 0 9717.175
# Policy Loss 0 11410.096
# Policy Loss 0 11469.445
# Policy Loss 0 9951.875
# Policy Loss 0 10057.529
# Policy Loss 0 10025.209
# Policy Loss 0 10982.311
# Policy Loss 0 10306.533
# Policy Loss 0 9603.549
# Policy Loss 0 10958.988
# Policy Loss 0 8690.1045
# Policy Loss 0 9467.389
# Policy Loss 0 10421.637
# Policy Loss 0 10606.834
# Policy Loss 0 9730.654
# Policy Loss 0 10425.381
# Policy Loss 0 8947.647
# Policy Loss 0 10007.314
# Policy Loss 0 10660.809
# Policy Loss 0 9333.369
# Policy Loss 0 9843.732
# Policy Loss 0 9962.222
# Policy Loss 0 10132.916
# Policy Loss 0 9882.454
# Policy Loss 0 9881.277
# Policy Loss 0 8994.083
# Policy Loss 0 10235.67
# Policy Loss 0 9260.167
# Policy Loss 0 9543.924
# Policy Loss 0 10472.641
# Policy Loss 0 9037.665
# Policy Loss 0 9283.138
# Policy Loss 0 10032.428
# Policy Loss 0 9723.865
# Policy Loss 0 8939.916
# Policy Loss 0 10271.063
# Policy Loss 0 10553.049
# Policy Loss 0 9420.778
# Policy Loss 0 11212.754
# Policy Loss 0 10801.77
# Policy Loss 0 9816.16
# Policy Loss 0 10234.484
# Policy Loss 0 9695.33
# Policy Loss 0 11731.397
# Policy Loss 0 10312.105
# Policy Loss 0 10710.123
# Policy Loss 0 9449.789
# Policy Loss 0 9947.567
# Policy Loss 0 9440.368
# Policy Loss 0 10248.363
# Policy Loss 0 9806.143
# Policy Loss 0 10525.074
# Policy Loss 0 10390.128
# Policy Loss 0 9055.367
# Policy Loss 0 10199.139
# Policy Loss 0 9524.06
# Policy Loss 0 10205.201
# Policy Loss 0 9276.39
# Policy Loss 0 10579.127
# Policy Loss 0 9493.069
# Policy Loss 0 9413.804
# Policy Loss 0 11493.195
# Policy Loss 0 10189.731
# Policy Loss 0 10067.257
# Policy Loss 0 9457.106
# Policy Loss 0 10041.1875
# Policy Loss 0 11046.845
# Policy Loss 0 9971.11
# Policy Loss 0 10874.59
# Policy Loss 0 10355.5625
# Policy Loss 0 10830.201
# Policy Loss 0 10888.841
# Policy Loss 0 10334.383
# Policy Loss 0 11180.063
# Policy Loss 0 9801.58
# Policy Loss 0 9073.666
# Policy Loss 0 11197.307
# Policy Loss 0 9355.238
# Policy Loss 0 10831.481
# Policy Loss 0 9236.507
# Policy Loss 0 9369.048
# Policy Loss 0 8564.019
# Policy Loss 0 9913.926
# Policy Loss 0 10768.924
# Policy Loss 0 11253.33
# Policy Loss 0 10409.116
# Policy Loss 0 8754.288
# Policy Loss 0 9144.596
# Policy Loss 0 10694.296
# Policy Loss 0 10702.767
# Policy Loss 0 9103.871
# Policy Loss 0 9826.697
# Policy Loss 0 10019.434
# Policy Loss 0 9506.56
# Policy Loss 0 9257.1045
# Policy Loss 0 8957.641
# Policy Loss 0 8352.906
# Policy Loss 0 10829.674
# Policy Loss 0 9952.91
# Policy Loss 0 10543.747
# Policy Loss 0 10357.023
# Policy Loss 0 8294.38
# Policy Loss 0 10206.164
# Policy Loss 0 9442.28
# Policy Loss 0 8583.021
# Policy Loss 0 9968.324
# Policy Loss 0 10457.524
# Policy Loss 0 11859.707
# Policy Loss 0 9912.859
# Policy Loss 0 10054.012
# Policy Loss 0 10683.2
# Policy Loss 0 9638.229
# Policy Loss 0 11594.42
# Policy Loss 0 9931.748
# Policy Loss 0 10079.121
# Policy Loss 0 9629.594
# Policy Loss 0 9533.28
# Policy Loss 0 10849.105
# Policy Loss 0 10423.793
# Policy Loss 0 11313.87
# Policy Loss 0 9766.761
# Policy Loss 0 11433.177
# Policy Loss 0 8978.208
# Policy Loss 0 10031.336
# Policy Loss 0 9904.979
# Policy Loss 0 11440.583
# Policy Loss 0 10659.184
# Policy Loss 0 11664.288
# Policy Loss 0 9279.429
# Policy Loss 0 10461.283
# Policy Loss 0 10712.58
# Policy Loss 0 10055.445
# Policy Loss 0 9786.162
# Policy Loss 0 10919.454
# Policy Loss 0 9841.113
# Policy Loss 0 11439.577
# Policy Loss 0 10787.875
# Policy Loss 0 9758.33
# Policy Loss 0 10869.691
# Policy Loss 0 10042.851
# Policy Loss 0 10115.293
# Policy Loss 0 9777.99
# Policy Loss 0 9509.555
# Policy Loss 0 9582.84
# Policy Loss 0 10736.399
# Policy Loss 0 9227.927
# Policy Loss 0 9370.107
# Policy Loss 0 11030.182
# Policy Loss 0 10125.087
# Policy Loss 0 9823.085
# Policy Loss 0 9579.623
# Policy Loss 0 9351.567
# Policy Loss 0 10381.354
# Policy Loss 0 9308.182
# Policy Loss 0 9806.217
# Policy Loss 0 10613.031
# Policy Loss 0 9176.721
# Policy Loss 0 8871.58
# Policy Loss 0 9439.211
# Policy Loss 0 9365.844
# Policy Loss 0 9877.17
# Policy Loss 0 11871.107
# Policy Loss 0 10211.148
# Policy Loss 0 10728.197
# Policy Loss 0 10670.208
# Policy Loss 0 8899.926
# Policy Loss 0 10467.689
# Policy Loss 0 10438.426
# Policy Loss 0 8488.676
# Policy Loss 0 9302.787
# Policy Loss 0 10143.365
# Policy Loss 0 10008.162
# Policy Loss 0 9826.158
# Policy Loss 0 11280.593
# Policy Loss 0 10300.735
# Policy Loss 0 9002.342
# Policy Loss 0 10736.8125
# Policy Loss 0 11018.792
# Policy Loss 0 10702.256
# Policy Loss 0 10190.678
# Policy Loss 0 10239.189
# Policy Loss 0 10305.393
# Policy Loss 0 9097.565
# Policy Loss 0 9479.912
# Policy Loss 0 10694.391
# Policy Loss 0 10885.262
# Policy Loss 0 10315.055
# Policy Loss 0 11498.037
# Policy Loss 0 9111.466
# Policy Loss 0 12014.144
# Policy Loss 0 10637.044
# Policy Loss 0 10379.998
# Policy Loss 0 10365.902
# Policy Loss 0 8623.738
# Policy Loss 0 10453.344
# Policy Loss 0 11453.262
# Policy Loss 0 10216.7295
# Policy Loss 0 10509.346
# Policy Loss 0 10681.946
# Policy Loss 0 10396.295
# Policy Loss 0 9758.383
# Policy Loss 0 10524.408
# Policy Loss 0 11348.977
# Policy Loss 0 10656.766
# Policy Loss 0 10702.716
# Policy Loss 0 10117.729
# Policy Loss 0 10718.559
# Policy Loss 0 8480.2
# Policy Loss 0 10701.072
# Policy Loss 0 9794.964
# Policy Loss 0 11085.717
# Policy Loss 0 10024.942
# Policy Loss 0 11706.945
# Policy Loss 0 9474.615
# Policy Loss 0 11196.354
# Policy Loss 0 9634.605
# Policy Loss 0 10485.157
# Policy Loss 0 12190.165
# Policy Loss 0 9675.906
# Policy Loss 0 9444.198
# Policy Loss 0 9277.211
# Policy Loss 0 10551.5205
# Policy Loss 0 11103.582
# Policy Loss 0 10824.953
# Policy Loss 0 8384.639
# Policy Loss 0 10722.016
# Policy Loss 0 9549.21
# Policy Loss 0 9483.901
# Policy Loss 0 11098.483
# Policy Loss 0 9952.477
# Policy Loss 0 10345.003
# Policy Loss 0 11520.061
# Policy Loss 0 9041.441
# Policy Loss 0 11526.928
# Policy Loss 0 9713.389
# Policy Loss 0 10936.738
# Policy Loss 0 11072.838
# Policy Loss 0 11010.556
# Policy Loss 0 10944.816
# Policy Loss 0 10520.908
# Policy Loss 0 8551.92
# Policy Loss 0 11860.855
# Policy Loss 0 9770.209
# Policy Loss 0 9130.051
# Policy Loss 0 8493.238
# Policy Loss 0 11314.971
# Policy Loss 0 9353.406
# Policy Loss 0 10822.258
# Policy Loss 0 10457.275
# Policy Loss 0 11372.522
# Policy Loss 0 9713.363
# Policy Loss 0 9757.141
# Policy Loss 0 11091.971
# Policy Loss 0 10850.002
# Policy Loss 0 9166.703
# Policy Loss 0 11161.952
# Policy Loss 0 11232.381
# Policy Loss 0 10603.939
# Policy Loss 0 9567.689
# Policy Loss 0 10105.087
# Policy Loss 0 11438.803
# Policy Loss 0 10978.972
# Policy Loss 0 10946.687
# Policy Loss 0 9837.894
# Policy Loss 0 11167.32
# Policy Loss 0 9398.303
# Policy Loss 0 10245.738
# Policy Loss 0 10431.494
# Policy Loss 0 11231.621
# Policy Loss 0 10679.331
# Policy Loss 0 11318.428
# Policy Loss 0 10781.152
# Policy Loss 0 10034.276
# Policy Loss 0 10689.894
# Policy Loss 0 10486.975
# Policy Loss 0 9871.162
# Policy Loss 0 10646.495
# Policy Loss 0 9270.184
# Policy Loss 0 8853.685
# Policy Loss 0 9339.182
# Policy Loss 0 10103.588
# Policy Loss 0 10378.053
# Policy Loss 0 9794.252
# Policy Loss 0 10552.837
# Policy Loss 0 10717.162
# Policy Loss 0 10804.015
# Policy Loss 0 9471.739
# Policy Loss 0 10948.162
# Policy Loss 0 10667.008
# Policy Loss 0 8977.344
# Policy Loss 0 10115.816
# Policy Loss 0 8947.74
# Policy Loss 0 10305.3125
# Policy Loss 0 9324.015
# Policy Loss 0 9319.695
# Policy Loss 0 10865.885
# Policy Loss 0 10150.116
# Policy Loss 0 9686.288
# Policy Loss 0 10863.698
# Policy Loss 0 8947.691
# Policy Loss 0 9318.48
# Policy Loss 0 11455.898
# Policy Loss 0 9838.739
# Policy Loss 0 10197.924
# Policy Loss 0 10792.982
# Policy Loss 0 9833.575
# Policy Loss 0 10834.239
# Policy Loss 0 10851.787
# Policy Loss 0 9401.123
# Policy Loss 0 9681.566
# Policy Loss 0 10454.398
# Policy Loss 0 8960.695
# Policy Loss 0 11011.887
# Policy Loss 0 10499.366
# Policy Loss 0 9066.196
# Policy Loss 0 10531.605
# Policy Loss 0 11781.314
# Policy Loss 0 8829.398
# Policy Loss 0 10181.633
# Policy Loss 0 11634.559
# Policy Loss 0 10667.946
# Policy Loss 0 10209.943
# Policy Loss 0 10004.542
# Policy Loss 0 10868.26
# Policy Loss 0 11283.705
# Policy Loss 0 9949.941
# Policy Loss 0 11457.016
# Policy Loss 0 9212.142
# Policy Loss 0 10176.787
# Policy Loss 0 9454.714
# Policy Loss 0 10710.843
# Policy Loss 0 11399.191
# Policy Loss 0 9682.668
# Policy Loss 0 12210.864
# Policy Loss 0 10315.97
# Policy Loss 0 10600.296
# Policy Loss 0 11089.604
# Policy Loss 0 10027.986
# Policy Loss 0 10431.041
# Policy Loss 0 10766.391
# Policy Loss 0 9755.515
# Policy Loss 0 10437.905
# Policy Loss 0 9941.737
# Policy Loss 0 10274.102
# Policy Loss 0 10904.63
# Policy Loss 0 11124.014
# Policy Loss 0 10406.169
# Policy Loss 0 10193.918
# Policy Loss 0 12452.82
# Policy Loss 0 8296.127
# Policy Loss 0 8953.617
# Policy Loss 0 10759.435
# Policy Loss 0 10890.643
# Policy Loss 0 9562.416
# Policy Loss 0 10164.108
# Policy Loss 0 11058.449
# Policy Loss 0 10296.129
# Policy Loss 0 10218.344
# Policy Loss 0 10238.201
# Policy Loss 0 10851.466
# Policy Loss 0 11051.845
# Policy Loss 0 12392.133
# Policy Loss 0 9537.002
# Policy Loss 0 11001.47
# Policy Loss 0 11365.982
# Policy Loss 0 10761.645
# Policy Loss 0 10674.55
# Policy Loss 0 11948.359
# Policy Loss 0 10222.088
# Policy Loss 0 9996.051
# Policy Loss 0 10752.679
# Policy Loss 0 9722.986
# Policy Loss 0 10937.65
# Policy Loss 0 10029.934
# Policy Loss 0 12903.959
# Policy Loss 0 10186.125
# Policy Loss 0 10227.865
# Policy Loss 0 11018.625
# Policy Loss 0 8721.234
# Policy Loss 0 10629.906
# Policy Loss 0 11579.818
# Policy Loss 0 11731.09
# Policy Loss 0 10508.318
# Policy Loss 0 9495.611
# Policy Loss 0 11427.051
# Policy Loss 0 10808.5625
# Policy Loss 0 11467.341
# Policy Loss 0 9471.855
# Policy Loss 0 10086.49
# Policy Loss 0 10727.944
# Policy Loss 0 10408.316
# Policy Loss 0 11027.845
# Policy Loss 0 11191.018
# Policy Loss 0 8612.254
# Policy Loss 0 11564.345
# Policy Loss 0 9612.478
# Policy Loss 0 11658.76
# Policy Loss 0 12100.859
# Policy Loss 0 10916.305
# Policy Loss 0 11526.273
# Policy Loss 0 10446.078
# Policy Loss 0 10328.23
# Policy Loss 0 9863.664
# Policy Loss 0 9860.901
# Policy Loss 0 10240.375
# Policy Loss 0 10719.869
# Policy Loss 0 11523.602
# Policy Loss 0 10410.186
# Policy Loss 0 9182.833
# Policy Loss 0 12230.358
# Policy Loss 0 10800.063
# Policy Loss 0 9860.684
# Policy Loss 0 12062.541
# Policy Loss 0 10755.442
# Policy Loss 0 11432.874
# Policy Loss 0 9801.642
# Policy Loss 0 8863.048
# Policy Loss 0 10637.129
# Policy Loss 0 9130.811
# Policy Loss 0 11087.229
# Policy Loss 0 10882.913
# Policy Loss 0 10433.825
# Policy Loss 0 9148.604
# Policy Loss 0 11411.85
# Policy Loss 0 9450.898
# Policy Loss 0 9069.804
# Policy Loss 0 10078.816
# Policy Loss 0 10513.525
# Policy Loss 0 9313.977
# Policy Loss 0 11519.743
# Policy Loss 0 11605.41
# Policy Loss 0 11958.391
# Policy Loss 0 10931.234
# Policy Loss 0 11689.662
# Policy Loss 0 11263.783
# Policy Loss 0 9540.369
# Policy Loss 0 10917.447
# Policy Loss 0 10023.387
# Policy Loss 0 9330.9
# Policy Loss 0 9696.672
# Policy Loss 0 10179.008
# Policy Loss 0 10840.607
# Policy Loss 0 10912.008
# Policy Loss 0 11393.924
# Policy Loss 0 10009.847
# Policy Loss 0 11316.084
# Policy Loss 0 11631.125
# Policy Loss 0 10779.652
# Policy Loss 0 10839.534
# Policy Loss 0 9889.45
# Policy Loss 0 12529.5
# Policy Loss 0 9819.352
# Policy Loss 0 11185.834
# Policy Loss 0 10027.83
# Policy Loss 0 11428.512
# Policy Loss 0 11012.843
# Policy Loss 0 10315.457
# Policy Loss 0 10813.498
# Policy Loss 0 11157.867
# Policy Loss 0 10327.385
# Policy Loss 0 9371.727
# Policy Loss 0 12197.445
# Policy Loss 0 8985.777
# Policy Loss 0 9791.222
# Policy Loss 0 10436.209
# Policy Loss 0 10236.853
# Policy Loss 0 10388.982
# Policy Loss 0 10336.893
# Policy Loss 0 10550.729
# Policy Loss 0 10205.518
# Policy Loss 0 10000.166
# Policy Loss 0 11579.545
# Policy Loss 0 10020.424
# Policy Loss 0 10922.658
# Policy Loss 0 10251.117
# Policy Loss 0 12211.846
# Policy Loss 0 9707.602
# Policy Loss 0 11612.127
# Policy Loss 0 11567.469
# Policy Loss 0 11444.593
# Policy Loss 0 10501.711
# Policy Loss 0 11248.432
# Policy Loss 0 10050.006
# Policy Loss 0 12283.846
# Policy Loss 0 11478.46
# Policy Loss 0 10592.514
# Policy Loss 0 11199.9375
# Policy Loss 0 12084.543
# Policy Loss 0 12143.686
# Policy Loss 0 12074.155
# Policy Loss 0 11772.604
# Policy Loss 0 10965.35
# Policy Loss 0 10144.189
# Policy Loss 0 11203.979
# Policy Loss 0 11063.465
# Policy Loss 0 10620.18
# Policy Loss 0 11485.571
# Policy Loss 0 10178.779
# Policy Loss 0 10221.017
# Policy Loss 0 11164.687
# Policy Loss 0 11319.775
# Policy Loss 0 10913.018
# Policy Loss 0 10162.963
# Policy Loss 0 11435.422
# Policy Loss 0 11437.109
# Policy Loss 0 10374.714
# Policy Loss 0 11622.105
# Policy Loss 0 10839.414
# Policy Loss 0 10525.324
# Policy Loss 0 9891.373
# Policy Loss 0 9408.385
# Policy Loss 0 9433.777
# Policy Loss 0 9534.129
# Policy Loss 0 11624.486
# Policy Loss 0 10385.404
# Policy Loss 0 10298.3
# Policy Loss 0 10315.874
# Policy Loss 0 12262.377
# Policy Loss 0 10395.097
# Policy Loss 0 10959.59
# Policy Loss 0 10350.852
# Policy Loss 0 12770.318
# Policy Loss 0 11141.167
# Policy Loss 0 11491.68
# Policy Loss 0 11485.844
# Policy Loss 0 11146.109
# Policy Loss 0 11707.564
# Policy Loss 0 10934.265
# Policy Loss 0 11288.025
# Policy Loss 0 11596.114
# Policy Loss 0 11051.936
# Policy Loss 0 11026.312
# Policy Loss 0 12067.148
# Policy Loss 0 11523.477
# Policy Loss 0 11775.492
# Policy Loss 0 11083.824
# Policy Loss 0 12367.509
# Policy Loss 0 10945.913
# Policy Loss 0 11317.805
# Policy Loss 0 11408.885
# Policy Loss 0 12130.287
# Policy Loss 0 10930.436
# Policy Loss 0 12100.613
# Policy Loss 0 10577.141
# Policy Loss 0 10713.461
# Policy Loss 0 10918.26
# Policy Loss 0 9630.23
# Policy Loss 0 11418.98
# Policy Loss 0 9647.012
# Policy Loss 0 11886.457
# Policy Loss 0 10511.789
# Policy Loss 0 10312.61
# Policy Loss 0 8907.063
# Policy Loss 0 9906.33
# Policy Loss 0 13069.922
# Policy Loss 0 10953.518
# Policy Loss 0 10134.635
# Policy Loss 0 11024.054
# Policy Loss 0 9900.245
# Policy Loss 0 10191.314
# Policy Loss 0 11541.698
# Policy Loss 0 10716.705
# Policy Loss 0 10992.752
# Policy Loss 0 10064.256
# Policy Loss 0 9463.707
# Policy Loss 0 10538.344
# Policy Loss 0 10355.193
# Policy Loss 0 11178.91
# Policy Loss 0 10512.355
# Policy Loss 0 11236.507
# Policy Loss 0 10265.118
# Policy Loss 0 10671.829
# Policy Loss 0 10479.23
# Policy Loss 0 12059.885
# Policy Loss 0 11945.368
# Policy Loss 0 9781.406
# Policy Loss 0 9078.753
# Policy Loss 0 10998.958
# Policy Loss 0 10959.711
# Policy Loss 0 10565.4795
# Policy Loss 0 10495.33
# Policy Loss 0 10534.776
# Policy Loss 0 10577.885
# Policy Loss 0 11303.0
# Policy Loss 0 11897.356
# Policy Loss 0 10201.201
# Policy Loss 0 10438.143
# Policy Loss 0 11245.221
# Policy Loss 0 10627.728
# Policy Loss 0 10390.844
# Policy Loss 0 11347.251
# Policy Loss 0 11488.316
# Policy Loss 0 9970.777
# Policy Loss 0 11416.819
# Policy Loss 0 10319.271
# Policy Loss 0 11626.832
# Policy Loss 0 11220.334
# Policy Loss 0 10103.9
# Policy Loss 0 10245.885
# Policy Loss 0 11222.305
# Policy Loss 0 10813.742
# Policy Loss 0 11411.268
# Policy Loss 0 10281.555
# Policy Loss 0 10871.883
# Policy Loss 0 10451.796
# Policy Loss 0 10922.678
# Policy Loss 0 10945.877
# Policy Loss 0 10918.07
# Policy Loss 0 10833.2705
# Policy Loss 0 10844.029
# Policy Loss 0 11041.182
# Policy Loss 0 10831.84
# Policy Loss 0 9229.945
# Policy Loss 0 10832.494
# Policy Loss 0 12392.783
# Policy Loss 0 11962.605
# Policy Loss 0 12408.637
# Policy Loss 0 11443.731
# Policy Loss 0 11999.554
# Policy Loss 0 12305.805
# Policy Loss 0 10340.292
# Policy Loss 0 10242.886
# Policy Loss 0 12070.811
# Policy Loss 0 10210.849
# Policy Loss 0 9743.559
# Policy Loss 0 9864.375
# Policy Loss 0 10769.527
# Policy Loss 0 10090.318
# Policy Loss 0 10997.1045
# Policy Loss 0 10648.479
# Policy Loss 0 11325.536
# Policy Loss 0 10998.936
# Policy Loss 0 10436.424
# Policy Loss 0 10280.561
# Policy Loss 0 11356.145
# Policy Loss 0 9395.717
# Policy Loss 0 11018.742
# Policy Loss 0 11840.911
# Policy Loss 0 9522.404
# Policy Loss 0 10991.889
# Policy Loss 0 11310.064
# Policy Loss 0 10391.652
# Policy Loss 0 9615.691
# Policy Loss 0 11164.026
# Policy Loss 0 10483.524
# Policy Loss 0 10115.219
# Policy Loss 0 12743.086
# Policy Loss 0 9336.592
# Policy Loss 0 11542.588
# Policy Loss 0 10871.274
# Policy Loss 0 10651.941
# Policy Loss 0 9368.197
# Policy Loss 0 11379.592
# Policy Loss 0 11744.619
# Policy Loss 0 10431.297
# Policy Loss 0 10958.918
# Policy Loss 0 9804.189
# Policy Loss 0 10764.15
# Policy Loss 0 10992.058
# Policy Loss 0 12148.314
# Policy Loss 0 11008.093
# Policy Loss 0 11406.016
# Policy Loss 0 11747.44
# Policy Loss 0 9320.266
# Policy Loss 0 10922.216
# Policy Loss 0 11972.359
# Policy Loss 0 9651.135
# Policy Loss 0 11727.424
# Policy Loss 0 10606.201
# Policy Loss 0 11202.736
# Policy Loss 0 10980.197
# Policy Loss 0 10602.568
# Policy Loss 0 10801.721
# Policy Loss 0 11196.205
# Policy Loss 0 10233.34
# Policy Loss 0 11707.577
# Policy Loss 0 11334.655
# Policy Loss 0 11790.039
# Policy Loss 0 10034.574
# Policy Loss 0 11302.087
# Policy Loss 0 11329.766
# Policy Loss 0 11879.464
# Policy Loss 0 11583.647
# Policy Loss 0 11527.585
# Policy Loss 0 11717.043
# Policy Loss 0 13184.96
# Policy Loss 0 9961.715
# Policy Loss 0 9581.614
# Policy Loss 0 11665.256
# Policy Loss 0 9575.09
# Policy Loss 0 10449.045
# Policy Loss 0 11189.1
# Policy Loss 0 9448.277
# Policy Loss 0 11546.639
# Policy Loss 0 10079.335
# Policy Loss 0 9397.525
# Policy Loss 0 11907.194
# Policy Loss 0 11655.67
# Policy Loss 0 10488.24
# Policy Loss 0 10970.281
# Policy Loss 0 12493.691
# Policy Loss 0 9984.385
# Policy Loss 0 11427.708
# Policy Loss 0 13017.473
# Policy Loss 0 10145.33
# Policy Loss 0 11345.458
# Policy Loss 0 11987.553
# Policy Loss 0 9346.52
# Policy Loss 0 8639.211
# Policy Loss 0 10526.295
# Policy Loss 0 10373.63
# Policy Loss 0 9522.189
# Policy Loss 0 8915.494
# Policy Loss 0 11094.717
# Policy Loss 0 10550.643
# Policy Loss 0 12610.401
# Policy Loss 0 9829.418
# Policy Loss 0 11962.193
# Policy Loss 0 12106.891
# Policy Loss 0 11038.465
# Policy Loss 0 9547.275
# Policy Loss 0 11585.499
# Policy Loss 0 10505.203
# Policy Loss 0 12559.646
# Policy Loss 0 10048.956
# Policy Loss 0 11839.064
# Policy Loss 0 10241.42
# Policy Loss 0 10677.498
# Policy Loss 0 10483.973
# Policy Loss 0 11298.769
# Policy Loss 0 10118.889
# Policy Loss 0 11231.576
# Policy Loss 0 11303.602
# Policy Loss 0 11673.186
# Policy Loss 0 10772.792
# Policy Loss 0 10643.626
# Policy Loss 0 11007.502
# Policy Loss 0 12198.521
# Policy Loss 0 12556.58
# Policy Loss 0 11230.0205
# Policy Loss 0 11080.3125
# Policy Loss 0 11799.6875
# Policy Loss 0 10907.754
# Policy Loss 0 10456.422
# Policy Loss 0 12099.674
# Policy Loss 0 10355.551
# Policy Loss 0 12522.424
# Policy Loss 0 10052.582
# Policy Loss 0 10731.565
# Policy Loss 0 11584.6045
# Policy Loss 0 11439.25
# Policy Loss 0 13112.738
# Policy Loss 0 11386.807
# Policy Loss 0 13318.626
# Policy Loss 0 12065.089
# Policy Loss 0 10671.036
# Policy Loss 0 10992.534
# Policy Loss 0 12553.406
# Policy Loss 0 9433.49
# Policy Loss 0 11172.939
# Policy Loss 0 10814.541
# Policy Loss 0 11207.607
# Policy Loss 0 11435.041
# Policy Loss 0 10355.231
# Policy Loss 0 9804.458
# Policy Loss 0 10261.701
# Policy Loss 0 11011.459
# Policy Loss 0 12935.4
# Policy Loss 0 11801.757
# Policy Loss 0 10788.386
# Policy Loss 0 11200.808
# Policy Loss 0 10514.743
# Policy Loss 0 10686.754
# Policy Loss 0 10711.057
# Policy Loss 0 10710.096
# Policy Loss 0 10784.607
# Policy Loss 0 10629.155
# Policy Loss 0 11820.015
# Policy Loss 0 12155.822
# Policy Loss 0 11836.816
# Policy Loss 0 10092.676
# Policy Loss 0 13132.695
# Policy Loss 0 9859.501
# Policy Loss 0 10868.884
# Policy Loss 0 10377.698
# Policy Loss 0 9190.303
# Policy Loss 0 10627.004
# Policy Loss 0 11414.312
# Policy Loss 0 11346.342
# Policy Loss 0 11064.434
# Policy Loss 0 11960.835
# Policy Loss 0 10603.611
# Policy Loss 0 9729.014
# Policy Loss 0 10489.275
# Policy Loss 0 10073.621
# Policy Loss 0 10239.29
# Policy Loss 0 10892.752
# Policy Loss 0 10193.242
# Policy Loss 0 10378.69
# Policy Loss 0 12892.218
# Policy Loss 0 10817.402
# Policy Loss 0 10804.773
# Policy Loss 0 9993.779
# Policy Loss 0 10210.325
# Policy Loss 0 10825.554
# Policy Loss 0 10483.844
# Policy Loss 0 12717.719
# Policy Loss 0 11668.412
# Policy Loss 0 11183.491
# Policy Loss 0 12101.493
# Policy Loss 0 10446.304
# Policy Loss 0 10506.705
# Policy Loss 0 10059.559
# Policy Loss 0 10870.182
# Policy Loss 0 12294.824
# Policy Loss 0 11503.1045
# Policy Loss 0 8841.182
# Policy Loss 0 10348.485
# Policy Loss 0 11195.54
# Policy Loss 0 11696.576
# Policy Loss 0 10518.186
# Policy Loss 0 10748.353
# Policy Loss 0 11674.548
# Policy Loss 0 12032.653
# Policy Loss 0 10804.994
# Policy Loss 0 10386.925
# Policy Loss 0 10792.603
# Policy Loss 0 13223.893
# Policy Loss 0 11592.215
# Policy Loss 0 11425.35
# Policy Loss 0 10839.234
# Policy Loss 0 9449.475
# Policy Loss 0 11185.993
# Policy Loss 0 10843.902
# Policy Loss 0 11647.952
# Policy Loss 0 11639.178
# Policy Loss 0 11813.254
# Policy Loss 0 11773.799
# Policy Loss 0 11380.256
# Policy Loss 0 11261.371
# Policy Loss 0 11233.787
# Policy Loss 0 10437.849
# Policy Loss 0 11444.78
# Policy Loss 0 12844.223
# Policy Loss 0 10922.957
# Policy Loss 0 12568.041
# Policy Loss 0 11637.797
# Policy Loss 0 10729.295
# Policy Loss 0 11889.341
# Policy Loss 0 11162.974
# Policy Loss 0 10215.212
# Policy Loss 0 10745.567
# Policy Loss 0 12031.968
# Policy Loss 0 12337.089
# Policy Loss 0 10553.422
# Policy Loss 0 10213.238
# Policy Loss 0 12274.387
# Policy Loss 0 13086.607
# Policy Loss 0 10676.19
# Policy Loss 0 11224.603
# Policy Loss 0 11793.76
# Policy Loss 0 12116.386
# Policy Loss 0 11394.225
# Policy Loss 0 11776.932
# Policy Loss 0 10960.2295
# Policy Loss 0 11363.178
# Policy Loss 0 12517.249
# Policy Loss 0 10835.466
# Policy Loss 0 12378.674
# Policy Loss 0 12373.049
# Policy Loss 0 11550.968
# Policy Loss 0 12289.146
# Policy Loss 0 11311.737
# Policy Loss 0 11480.096
# Policy Loss 0 10170.617
# Policy Loss 0 11314.756
# Policy Loss 0 10021.291
# Policy Loss 0 12990.895
# Policy Loss 0 10131.785
# Policy Loss 0 11067.177
# Policy Loss 0 11369.885
# Policy Loss 0 11977.106
# Policy Loss 0 10309.326
# Policy Loss 0 11813.152
# Policy Loss 0 8574.35
# Policy Loss 0 10540.885
# Policy Loss 0 12911.744
# Policy Loss 0 13534.518
# Policy Loss 0 11398.488
# Policy Loss 0 11817.062
# Policy Loss 0 11227.982
# Policy Loss 0 11298.632
# Policy Loss 0 11876.326
# Policy Loss 0 10184.401
# Policy Loss 0 12970.816
# Policy Loss 0 11023.102
# Policy Loss 0 13298.899
# Policy Loss 0 11455.493
# Policy Loss 0 11381.704
# Policy Loss 0 11536.993
# Policy Loss 0 12073.98
# Policy Loss 0 13094.793
# Policy Loss 0 11045.53
# Policy Loss 0 11243.99
# Policy Loss 0 11736.43
# Policy Loss 0 11524.884
# Policy Loss 0 12102.068
# Policy Loss 0 11862.622
# Policy Loss 0 11463.473
# Policy Loss 0 10613.86
# Policy Loss 0 11828.695
# Policy Loss 0 11346.417
# Policy Loss 0 9302.866
# Policy Loss 0 11222.293
# Policy Loss 0 12323.387
# Policy Loss 0 11879.937
# Policy Loss 0 13496.379
# Policy Loss 0 9769.258
# Policy Loss 0 10256.901
# Policy Loss 0 12018.652
# Policy Loss 0 12846.941
# Policy Loss 0 12574.47
# Policy Loss 0 12005.606
# Policy Loss 0 11631.227
# Policy Loss 0 10657.086
# Policy Loss 0 11791.328
# Policy Loss 0 10593.662
# Policy Loss 0 10978.014
# Policy Loss 0 14605.6045
# Policy Loss 0 10047.822
# Policy Loss 0 11738.592
# Policy Loss 0 13330.654
# Policy Loss 0 10639.282
# Policy Loss 0 12005.586
# Policy Loss 0 12909.038
# Policy Loss 0 11099.673
# Policy Loss 0 11293.406
# Policy Loss 0 11014.231
# Policy Loss 0 11224.078
# Policy Loss 0 12769.658
# Policy Loss 0 10934.078
# Policy Loss 0 13139.846
# Policy Loss 0 11641.422
# Policy Loss 0 12416.409
# Policy Loss 0 11293.588
# Policy Loss 0 12754.985
# Policy Loss 0 13139.92
# Policy Loss 0 11523.196
# Policy Loss 0 12260.086
# Policy Loss 0 12871.978
# Policy Loss 0 12263.092
# Policy Loss 0 12719.206
# Policy Loss 0 11925.129
# Policy Loss 0 11239.704
# Policy Loss 0 10058.316
# Policy Loss 0 11093.604
# Policy Loss 0 12349.168
# Policy Loss 0 10679.839
# Policy Loss 0 12934.552
# Policy Loss 0 12478.365
# Policy Loss 0 11664.594
# Policy Loss 0 12090.986
# Policy Loss 0 11868.093
# Policy Loss 0 12836.918
# Policy Loss 0 12542.168
# Policy Loss 0 10339.909
# Policy Loss 0 11105.052
# Policy Loss 0 11462.972
# Policy Loss 0 10826.195
# Policy Loss 0 12366.543
# Policy Loss 0 10109.285
# Policy Loss 0 11275.085
# Policy Loss 0 9954.109
# Policy Loss 0 12104.528
# Policy Loss 0 11223.292
# Policy Loss 0 13222.658
# Policy Loss 0 12137.401
# Policy Loss 0 12608.908
# Policy Loss 0 12053.991
# Policy Loss 0 11297.239
# Policy Loss 0 11141.941
# Policy Loss 0 10994.0
# Policy Loss 0 12221.969
# Policy Loss 0 12216.26
# Policy Loss 0 12712.756
# Policy Loss 0 11016.69
# Policy Loss 0 14222.258
# Policy Loss 0 13905.197
# Policy Loss 0 12378.646
# Policy Loss 0 10249.078
# Policy Loss 0 10235.413
# Policy Loss 0 13405.613
# Policy Loss 0 10099.471
# Policy Loss 0 12070.946
# Policy Loss 0 11944.771
# Policy Loss 0 12284.803
# Policy Loss 0 11183.119
# Policy Loss 0 13107.9375
# Policy Loss 0 11927.824
# Policy Loss 0 12923.57
# Policy Loss 0 12857.212
# Policy Loss 0 12280.916
# Policy Loss 0 13671.057
# Policy Loss 0 11046.887
# Policy Loss 0 11417.004
# Policy Loss 0 11884.201
# Policy Loss 0 12388.279
# Policy Loss 0 10883.92
# Policy Loss 0 12326.27
# Policy Loss 0 11661.182
# Policy Loss 0 11349.817
# Policy Loss 0 12917.975
# Policy Loss 0 11305.017
# Policy Loss 0 14401.895
# Policy Loss 0 12392.084
# Policy Loss 0 11725.908
# Policy Loss 0 12435.322
# Policy Loss 0 13384.402
# Policy Loss 0 12432.113
# Policy Loss 0 13571.419
# Policy Loss 0 12757.697
# Policy Loss 0 12471.791
# Policy Loss 0 13180.125
# Policy Loss 0 11864.756
# Policy Loss 0 12307.709
# Policy Loss 0 11069.698
# Policy Loss 0 12030.415
# Policy Loss 0 12719.926
# Policy Loss 0 11575.75
# Policy Loss 0 12450.688
# Policy Loss 0 11553.314
# Policy Loss 0 11642.959
# Policy Loss 0 11484.881
# Policy Loss 0 12171.998
# Policy Loss 0 13045.926
# Policy Loss 0 11467.901
# Policy Loss 0 12542.381
# Policy Loss 0 12848.4795
# Policy Loss 0 11960.924
# Policy Loss 0 12660.588
# Policy Loss 0 13755.695
# Policy Loss 0 12524.157
# Policy Loss 0 11710.758
# Policy Loss 0 11968.014
# Policy Loss 0 10677.713
# Policy Loss 0 12879.361
# Policy Loss 0 11949.4
# Policy Loss 0 12049.16
# Policy Loss 0 11683.1875
# Policy Loss 0 12441.888
# Policy Loss 0 12607.592
# Policy Loss 0 12441.143
# Policy Loss 0 12220.379
# Policy Loss 0 12593.23
# Policy Loss 0 13129.444
# Policy Loss 0 12318.065
# Policy Loss 0 10774.436
# Policy Loss 0 13530.799
# Policy Loss 0 12092.937
# Policy Loss 0 10905.504
# Policy Loss 0 13318.955
# Policy Loss 0 11665.318
# Policy Loss 0 13490.733
# Policy Loss 0 12482.38
# Policy Loss 0 11597.879
# Policy Loss 0 12728.195
# Policy Loss 0 11503.057
# Policy Loss 0 10397.097
# Policy Loss 0 12804.902
# Policy Loss 0 12448.776
# Policy Loss 0 11590.947
# Policy Loss 0 12796.717
# Policy Loss 0 11213.164
# Policy Loss 0 12219.791
# Policy Loss 0 13279.08
# Policy Loss 0 14085.115
# Policy Loss 0 10593.186
# Policy Loss 0 10788.751
# Policy Loss 0 12015.656
# Policy Loss 0 10225.964
# Policy Loss 0 13209.947
# Policy Loss 0 12020.113
# Policy Loss 0 11292.903
# Policy Loss 0 12231.389
# Policy Loss 0 12699.479
# Policy Loss 0 12796.847
# Policy Loss 0 13008.353
# Policy Loss 0 11242.242
# Policy Loss 0 12105.703
# Policy Loss 0 13612.639
# Policy Loss 0 13372.411
# Policy Loss 0 13014.029
# Policy Loss 0 10901.478
# Policy Loss 0 12007.689
# Policy Loss 0 12278.809
# Policy Loss 0 14163.106
# Policy Loss 0 12095.768
# Policy Loss 0 12582.425
# Policy Loss 0 12916.355
# Policy Loss 0 12856.304
# Policy Loss 0 12984.621
# Policy Loss 0 11595.102
# Policy Loss 0 12272.288
# Policy Loss 0 12550.762
# Policy Loss 0 12600.998
# Policy Loss 0 13369.142
# Policy Loss 0 11496.526
# Policy Loss 0 12088.42
# Policy Loss 0 10861.286
# Policy Loss 0 11451.357
# Policy Loss 0 12268.5205
# Policy Loss 0 10586.836
# Policy Loss 0 12555.992
# Policy Loss 0 13143.197
# Policy Loss 0 13957.664
# Policy Loss 0 12487.036
# Policy Loss 0 11930.529
# Policy Loss 0 10917.924
# Policy Loss 0 13731.325
# Policy Loss 0 11870.45
# Policy Loss 0 12307.043
# Policy Loss 0 13464.279
# Policy Loss 0 11444.252
# Policy Loss 0 12291.281
# Policy Loss 0 12336.99
# Policy Loss 0 12282.793
# Policy Loss 0 10129.136
# Policy Loss 0 11902.629
# Policy Loss 0 13167.338
# Policy Loss 0 12173.699
# Policy Loss 0 13285.752
# Policy Loss 0 14272.702
# Policy Loss 0 13388.681
# Policy Loss 0 12621.264
# Policy Loss 0 10164.697
# Policy Loss 0 11949.315
# Policy Loss 0 11581.669
# Policy Loss 0 12508.653
# Policy Loss 0 11704.008
# Policy Loss 0 11726.49
# Policy Loss 0 12980.469
# Policy Loss 0 10787.913
# Policy Loss 0 11261.869
# Policy Loss 0 12298.421
# Policy Loss 0 12999.842
# Policy Loss 0 12488.509
# Policy Loss 0 11410.692
# Policy Loss 0 13080.941
# Policy Loss 0 13512.051
# Policy Loss 0 12374.668
# Policy Loss 0 12774.514
# Policy Loss 0 9727.015
# Policy Loss 0 14056.745
# Policy Loss 0 12316.67
# Policy Loss 0 11650.123
# Policy Loss 0 12482.407
# Policy Loss 0 12991.836
# Policy Loss 0 13211.459
# Policy Loss 0 13207.824
# Policy Loss 0 12887.556
# Policy Loss 0 11286.028
# Policy Loss 0 10985.435
# Policy Loss 0 11945.834
# Policy Loss 0 11023.639
# Policy Loss 0 12736.773
# Policy Loss 0 11495.443
# Policy Loss 0 10928.73
# Policy Loss 0 11653.939
# Policy Loss 0 13777.585
# Policy Loss 0 12707.413
# Policy Loss 0 13222.198
# Policy Loss 0 13051.82
# Policy Loss 0 13507.432
# Policy Loss 0 13400.8545
# Policy Loss 0 12061.637
# Policy Loss 0 11961.558
# Policy Loss 0 11748.617
# Policy Loss 0 12424.727
# Policy Loss 0 10385.523
# Policy Loss 0 12190.777
# Policy Loss 0 12993.478
# Policy Loss 0 10221.375
# Policy Loss 0 13908.6
# Policy Loss 0 11540.957
# Policy Loss 0 12374.441
# Policy Loss 0 12418.463
# Policy Loss 0 11740.379
# Policy Loss 0 12437.393
# Policy Loss 0 13818.002
# Policy Loss 0 11428.795
# Policy Loss 0 12566.881
# Policy Loss 0 13184.922
# Policy Loss 0 11965.938
# Policy Loss 0 13280.9795
# Policy Loss 0 11235.993
# Policy Loss 0 14816.421
# Policy Loss 0 11717.014
# Policy Loss 0 11349.619
# Policy Loss 0 12217.365
# Policy Loss 0 12861.662
# Policy Loss 0 11540.404
# Policy Loss 0 12464.787
# Policy Loss 0 12455.451
# Policy Loss 0 12227.944
# Policy Loss 0 12262.814
# Policy Loss 0 12770.142
# Policy Loss 0 11714.417
# Policy Loss 0 14071.969
# Policy Loss 0 10395.188
# Policy Loss 0 12532.566
# Policy Loss 0 11203.307
# Policy Loss 0 11815.762
# Policy Loss 0 11469.602
# Policy Loss 0 12169.1045
# Policy Loss 0 12437.338
# Policy Loss 0 10853.357
# Policy Loss 0 11916.992
# Policy Loss 0 13709.816
# Policy Loss 0 15154.928
# Policy Loss 0 13323.072
# Policy Loss 0 10740.636
# Policy Loss 0 13062.424
# Policy Loss 0 12774.916
# Policy Loss 0 12296.632
# Policy Loss 0 12034.073
# Policy Loss 0 11829.841
# Policy Loss 0 12669.133
# Policy Loss 0 13238.062
# Policy Loss 0 14469.509
# Policy Loss 0 13199.521
# Policy Loss 0 13177.7295
# Policy Loss 0 14164.424
# Policy Loss 0 11646.152
# Policy Loss 0 11815.748
# Policy Loss 0 11252.604
# Policy Loss 0 13461.211
# Policy Loss 0 13003.708
# Policy Loss 0 13587.421
# Policy Loss 0 14224.27
# Policy Loss 0 11794.176
# Policy Loss 0 12942.616
# Policy Loss 0 14058.654
# Policy Loss 0 13020.375
# Policy Loss 0 12523.1875
# Policy Loss 0 14319.853
# Policy Loss 0 12938.389
# Policy Loss 0 13338.328
# Policy Loss 0 9660.146
# Policy Loss 0 15528.717
# Policy Loss 0 12267.59
# Policy Loss 0 11858.504
# Policy Loss 0 13002.547
# Policy Loss 0 12362.467
# Policy Loss 0 13319.165
# Policy Loss 0 11348.405
# Policy Loss 0 11257.848
# Policy Loss 0 12328.237
# Policy Loss 0 14250.14
# Policy Loss 0 11996.209
# Policy Loss 0 14164.86
# Policy Loss 0 12256.197
# Policy Loss 0 12328.215
# Policy Loss 0 13263.4795
# Policy Loss 0 11354.388
# ...
# Policy Loss 0 14298.34
# Policy Loss 0 13421.574
# Policy Loss 0 13540.654
# Policy Loss 0 13195.1875
# Policy Loss 0 14177.313
# Policy Loss 0 13955.311
# Policy Loss 0 14655.394
# Policy Loss 0 14459.598
# Policy Loss 0 13345.55
# Policy Loss 0 14736.757
# Policy Loss 0 15410.266
# Policy Loss 0 15285.77
# Policy Loss 0 14651.781
# Policy Loss 0 14761.529
# Policy Loss 0 13517.977
# Policy Loss 0 14428.883
# Policy Loss 0 15340.644
# Policy Loss 0 13817.552
# Policy Loss 0 14748.317
# Policy Loss 0 12184.596
# Policy Loss 0 14531.088
# Policy Loss 0 12433.273
# Policy Loss 0 14578.731
# Policy Loss 0 12557.82
# Policy Loss 0 13370.204
# Policy Loss 0 17031.703
# Policy Loss 0 15639.0
# Policy Loss 0 14250.958
# Policy Loss 0 16236.871
# Policy Loss 0 15581.348
# Policy Loss 0 16347.691
# Policy Loss 0 13852.619
# Policy Loss 0 13707.321
# Policy Loss 0 15194.556
# Policy Loss 0 12650.68
# Policy Loss 0 13412.251
# Policy Loss 0 14441.896
# Policy Loss 0 15774.381
# Policy Loss 0 13493.761
# Policy Loss 0 13144.072
# Policy Loss 0 13119.114
# Policy Loss 0 15130.3955
# Policy Loss 0 14758.09
# Policy Loss 0 11979.284
# Policy Loss 0 12845.572
# Policy Loss 0 16789.945
# Policy Loss 0 15851.482
# Policy Loss 0 14561.982
# Policy Loss 0 13439.054
# Policy Loss 0 13977.216
# Policy Loss 0 16164.56
# Policy Loss 0 15928.219
# Policy Loss 0 13148.125
# Policy Loss 0 14253.729
# Policy Loss 0 13071.502
# Policy Loss 0 13740.16
# Policy Loss 0 12592.574
# Policy Loss 0 13960.059
# Policy Loss 0 13411.414
# Policy Loss 0 14839.768
# Policy Loss 0 13790.558
# Policy Loss 0 13070.162
# Policy Loss 0 13912.083
# Policy Loss 0 12924.115
# Policy Loss 0 14415.385
# Policy Loss 0 13432.824
# Policy Loss 0 13232.269
# Policy Loss 0 11837.725
# Policy Loss 0 13515.678
# Policy Loss 0 12806.283
# Policy Loss 0 12601.998
# Policy Loss 0 12868.17
# Policy Loss 0 13984.539
# Policy Loss 0 13594.826
# Policy Loss 0 14983.146
# Policy Loss 0 12252.582
# Policy Loss 0 15545.419
# Policy Loss 0 15941.871
# Policy Loss 0 14621.93
# Policy Loss 0 13223.946
# Policy Loss 0 14246.004
# Policy Loss 0 15881.851
# Policy Loss 0 14467.924
# Policy Loss 0 15343.379
# Policy Loss 0 12008.396
# Policy Loss 0 15235.146
# Policy Loss 0 14274.371
# Policy Loss 0 14281.406
# Policy Loss 0 14258.849
# Policy Loss 0 15317.55
# Policy Loss 0 15657.797
# Policy Loss 0 11899.504
# Policy Loss 0 15525.033
# Policy Loss 0 12647.748
# Policy Loss 0 17876.531
# Policy Loss 0 15884.867
# Policy Loss 0 16597.605
# Policy Loss 0 16383.781
# Policy Loss 0 13702.17
# Policy Loss 0 14563.977
# Policy Loss 0 16319.174
# Policy Loss 0 15350.531
# Policy Loss 0 15596.93
# Policy Loss 0 13173.203
# Policy Loss 0 12131.334
# Policy Loss 0 14362.174
# Policy Loss 0 15593.787
# Policy Loss 0 14126.738
# Policy Loss 0 16540.707
# Policy Loss 0 14821.467
# Policy Loss 0 15117.955
# Policy Loss 0 12298.139
# Policy Loss 0 14566.016
# Policy Loss 0 12850.381
# Policy Loss 0 13006.943
# Policy Loss 0 12929.265
# Policy Loss 0 14423.718
# Policy Loss 0 14437.128
# Policy Loss 0 14004.652
# Policy Loss 0 16193.251
# Policy Loss 0 12752.904
# Policy Loss 0 14369.323
# Policy Loss 0 13645.238
# Policy Loss 0 13351.459
# Policy Loss 0 15135.291
# Policy Loss 0 14147.258
# Policy Loss 0 12573.508
# Policy Loss 0 14008.726
# Policy Loss 0 15990.114
# Policy Loss 0 14939.56
# Policy Loss 0 14154.449
# Policy Loss 0 16360.295
# Policy Loss 0 14550.229
# Policy Loss 0 14607.881
# Policy Loss 0 14348.145
# Policy Loss 0 15600.857
# Policy Loss 0 13441.34
# Policy Loss 0 15570.975
# Policy Loss 0 14220.264
# Policy Loss 0 14687.583
# Policy Loss 0 13333.373
# Policy Loss 0 15851.002
# Policy Loss 0 16620.016
# Policy Loss 0 14457.67
# Policy Loss 0 13780.979
# Policy Loss 0 14368.334
# Policy Loss 0 15220.02
# Policy Loss 0 13433.994
# Policy Loss 0 14423.209
# Policy Loss 0 13649.98
# Policy Loss 0 13524.868
# Policy Loss 0 14807.8545
# Policy Loss 0 12861.807
# Policy Loss 0 14228.631
# Policy Loss 0 14504.829
# Policy Loss 0 13210.525
# Policy Loss 0 12797.816
# Policy Loss 0 15582.636
# Policy Loss 0 13509.652
# Policy Loss 0 13263.444
# Policy Loss 0 12142.34
# Policy Loss 0 16876.05
# Policy Loss 0 15573.953
# Policy Loss 0 14307.649
# Policy Loss 0 16154.442
# Policy Loss 0 13706.941
# Policy Loss 0 12998.629
# Policy Loss 0 14596.729
# Policy Loss 0 15839.652
# Policy Loss 0 14328.779
# Policy Loss 0 13836.376
# Policy Loss 0 14381.998
# Policy Loss 0 15965.182
# Policy Loss 0 17595.08
# Policy Loss 0 14282.084
# Policy Loss 0 17458.975
# Policy Loss 0 13528.732
# Policy Loss 0 14419.539
# Policy Loss 0 13440.213
# Policy Loss 0 13746.798
# Policy Loss 0 13820.2705
# Policy Loss 0 15194.736
# Policy Loss 0 13361.445
# Policy Loss 0 15630.366
# Policy Loss 0 15232.973
# Policy Loss 0 14644.305
# Policy Loss 0 13554.436
# Policy Loss 0 13744.357
# Policy Loss 0 12919.621
# Policy Loss 0 16169.281
# Policy Loss 0 14147.594
# Policy Loss 0 14864.353
# Policy Loss 0 16667.57
# Policy Loss 0 16736.203
# Policy Loss 0 15352.975
# Policy Loss 0 16672.143
# Policy Loss 0 15219.48
# Policy Loss 0 12914.176
# Policy Loss 0 16332.281
# Policy Loss 0 13632.794
# Policy Loss 0 13050.362
# Policy Loss 0 13791.934
# Policy Loss 0 14075.257
# Policy Loss 0 16087.072
# Policy Loss 0 15896.609
# Policy Loss 0 15417.855
# Policy Loss 0 13934.015
# Policy Loss 0 13193.928
# Policy Loss 0 14081.6875
# Policy Loss 0 14559.082
# Policy Loss 0 16363.759
# Policy Loss 0 13932.023
# Policy Loss 0 13800.4
# Policy Loss 0 15291.0205
# Policy Loss 0 13214.658
# Policy Loss 0 13955.831
# Policy Loss 0 16266.803
# Policy Loss 0 16721.453
# Policy Loss 0 13519.391
# Policy Loss 0 15221.018
# Policy Loss 0 16718.281
# Policy Loss 0 15821.649
# Policy Loss 0 15864.292
# Policy Loss 0 15600.416
# Policy Loss 0 14308.811
# Policy Loss 0 12342.383
# Policy Loss 0 16284.1875
# Policy Loss 0 12730.025
# Policy Loss 0 15029.09
# Policy Loss 0 11768.544
# Policy Loss 0 13288.906
# Policy Loss 0 15372.301
# Policy Loss 0 15819.043
# Policy Loss 0 13268.184
# Policy Loss 0 13866.098
# Policy Loss 0 17175.078
# Policy Loss 0 16845.68
# Policy Loss 0 16293.892
# Policy Loss 0 14690.893
# Policy Loss 0 15249.441
# Policy Loss 0 14936.097
# Policy Loss 0 12861.89
# Policy Loss 0 14793.301
# Policy Loss 0 16216.469
# Policy Loss 0 14656.652
# Policy Loss 0 13939.482
# Policy Loss 0 16883.586
# Policy Loss 0 14366.853
# Policy Loss 0 15303.413
# Policy Loss 0 12847.674
# Policy Loss 0 17499.092
# Policy Loss 0 15917.658
# Policy Loss 0 14641.924
# Policy Loss 0 16230.227
# Policy Loss 0 17327.502
# Policy Loss 0 15013.57
# Policy Loss 0 15853.676
# Policy Loss 0 15732.859
# Policy Loss 0 14345.545
# Policy Loss 0 14578.289
# Policy Loss 0 16987.336
# Policy Loss 0 14015.93
# Policy Loss 0 12500.982
# Policy Loss 0 14897.267
# Policy Loss 0 15680.815
# Policy Loss 0 16727.527
# Policy Loss 0 14536.137
# Policy Loss 0 13626.896
# Policy Loss 0 13854.049
# Policy Loss 0 13679.81
# Policy Loss 0 15841.063
# Policy Loss 0 14251.834
# Policy Loss 0 16157.92
# Policy Loss 0 16165.034
# Policy Loss 0 14590.154
# Policy Loss 0 14996.541
# Policy Loss 0 14516.873
# Policy Loss 0 13276.848
# Policy Loss 0 14176.968
# Policy Loss 0 16938.617
# Policy Loss 0 16132.116
# Policy Loss 0 12923.652
# Policy Loss 0 18124.43
# Policy Loss 0 14510.609
# Policy Loss 0 12393.225
# Policy Loss 0 14351.599
# Policy Loss 0 17058.61
# Policy Loss 0 13715.734
# Policy Loss 0 18673.867
# Policy Loss 0 13464.157
# Policy Loss 0 13740.922
# Policy Loss 0 15341.393
# Policy Loss 0 13819.4795
# Policy Loss 0 15831.854
# Policy Loss 0 16234.789
# Policy Loss 0 14476.209
# Policy Loss 0 13273.725
# Policy Loss 0 12268.387
# Policy Loss 0 14872.666
# Policy Loss 0 13439.969
# Policy Loss 0 14360.0625
# Policy Loss 0 12369.303
# Policy Loss 0 16561.89
# Policy Loss 0 15997.483
# Policy Loss 0 15301.87
# Policy Loss 0 14977.493
# Policy Loss 0 13955.989
# Policy Loss 0 14742.189
# Policy Loss 0 16651.3
# Policy Loss 0 13791.733
# Policy Loss 0 14674.362
# Policy Loss 0 15851.054
# Policy Loss 0 14849.099
# Policy Loss 0 14133.231
# Policy Loss 0 14857.873
# Policy Loss 0 16885.775
# Policy Loss 0 12845.636
# Policy Loss 0 14303.79
# Policy Loss 0 15543.582
# Policy Loss 0 15973.789
# Policy Loss 0 14888.056
# Policy Loss 0 14879.779
# Policy Loss 0 14736.798
# Policy Loss 0 13848.65
# Policy Loss 0 12225.033
# Policy Loss 0 12889.193
# Policy Loss 0 15979.956
# Policy Loss 0 16236.248
# Policy Loss 0 14976.53
# Policy Loss 0 13864.515
# Policy Loss 0 15860.822
# Policy Loss 0 15485.346
# Policy Loss 0 15970.921
# Policy Loss 0 13376.75
# Policy Loss 0 13228.125
# Policy Loss 0 17596.41
# Policy Loss 0 16482.393
# Policy Loss 0 14492.621
# Policy Loss 0 16682.281
# Policy Loss 0 15032.879
# Policy Loss 0 15110.432
# Policy Loss 0 13756.0
# Policy Loss 0 14340.809
# Policy Loss 0 14617.362
# Policy Loss 0 17216.555
# Policy Loss 0 12539.471
# Policy Loss 0 13786.777
# Policy Loss 0 16943.473
# Policy Loss 0 15985.686
# Policy Loss 0 15170.168
# Policy Loss 0 14164.766
# Policy Loss 0 15450.783
# Policy Loss 0 15444.39
# Policy Loss 0 14953.916
# Policy Loss 0 14474.02
# Policy Loss 0 16061.041
# Policy Loss 0 15381.075
# Policy Loss 0 16107.686
# Policy Loss 0 15897.436
# Policy Loss 0 14147.932
# Policy Loss 0 14749.404
# Policy Loss 0 15227.246
# Policy Loss 0 16435.393
# Policy Loss 0 14536.707
# Policy Loss 0 16124.767
# Policy Loss 0 14778.788
# Policy Loss 0 14442.729
# Policy Loss 0 12986.553
# Policy Loss 0 16613.723
# Policy Loss 0 13111.805
# Policy Loss 0 14530.078
# Policy Loss 0 15615.969
# Policy Loss 0 13240.055
# Policy Loss 0 15871.613
# Policy Loss 0 17870.746
# Policy Loss 0 13531.693
# Policy Loss 0 14049.467
# Policy Loss 0 13928.159
# Policy Loss 0 17897.879
# Policy Loss 0 14500.747
# Policy Loss 0 15007.912
# Policy Loss 0 16996.205
# Policy Loss 0 14307.746
# Policy Loss 0 15754.274
# Policy Loss 0 17065.098
# Policy Loss 0 15171.789
# Policy Loss 0 16058.456
# Policy Loss 0 15445.223
# Policy Loss 0 13822.651
# Policy Loss 0 15716.553
# Policy Loss 0 16443.184
# Policy Loss 0 15158.053
# Policy Loss 0 15407.041
# Policy Loss 0 16056.576
# Policy Loss 0 15907.625
# Policy Loss 0 15061.899
# Policy Loss 0 14416.861
# Policy Loss 0 17300.916
# Policy Loss 0 14042.411
# Policy Loss 0 16249.826
# Policy Loss 0 15115.023
# Policy Loss 0 14904.402
# Policy Loss 0 17698.086
# Policy Loss 0 18430.676
# Policy Loss 0 15317.793
# Policy Loss 0 15372.942
# Policy Loss 0 15490.654
# Policy Loss 0 16765.277
# Policy Loss 0 12435.877
# Policy Loss 0 13694.373
# Policy Loss 0 15788.841
# Policy Loss 0 13930.828
# Policy Loss 0 14515.296
# Policy Loss 0 16326.709
# Policy Loss 0 15061.383
# Policy Loss 0 14443.301
# Policy Loss 0 15996.576
# Policy Loss 0 15948.658
# Policy Loss 0 15018.266
# Policy Loss 0 14437.436
# Policy Loss 0 14338.008
# Policy Loss 0 13825.555
# Policy Loss 0 17650.215
# Policy Loss 0 16453.434
# Policy Loss 0 16155.106
# Policy Loss 0 16798.021
# Policy Loss 0 16271.816
# Policy Loss 0 14416.174
# Policy Loss 0 15965.862
# Policy Loss 0 15177.461
# Policy Loss 0 15642.007
# Policy Loss 0 15855.182
# Policy Loss 0 16375.73
# Policy Loss 0 16324.843
# Policy Loss 0 14630.441
# Policy Loss 0 16167.512
# Policy Loss 0 15016.18
# Policy Loss 0 14426.6045
# Policy Loss 0 14944.961
# Policy Loss 0 12156.0625
# Policy Loss 0 14104.234
# Policy Loss 0 13852.871
# Policy Loss 0 13844.628
# Policy Loss 0 14825.103
# Policy Loss 0 13002.418
# Policy Loss 0 14245.201
# Policy Loss 0 14112.939
# Policy Loss 0 16359.647
# Policy Loss 0 16983.672
# Policy Loss 0 15422.764
# Policy Loss 0 17303.494
# Policy Loss 0 15388.771
# Policy Loss 0 15030.952
# Policy Loss 0 15465.617
# Policy Loss 0 18605.871
# Policy Loss 0 15879.807
# Policy Loss 0 14138.614
# Policy Loss 0 13594.942
# Policy Loss 0 15662.271
# Policy Loss 0 15698.778
# Policy Loss 0 15817.199
# Policy Loss 0 15097.641
# Policy Loss 0 16112.467
# Policy Loss 0 16498.75
# Policy Loss 0 13190.17
# Policy Loss 0 15472.914
# Policy Loss 0 16534.148
# Policy Loss 0 16969.848
# Policy Loss 0 13305.654
# Policy Loss 0 15534.736
# Policy Loss 0 14863.783
# Policy Loss 0 16718.104
# Policy Loss 0 17235.014
# Policy Loss 0 16491.85
# Policy Loss 0 15049.625
# Policy Loss 0 14869.578
# Policy Loss 0 12344.111
# Policy Loss 0 13662.006
# Policy Loss 0 17155.242
# Policy Loss 0 15927.494
# Policy Loss 0 12851.407
# Policy Loss 0 16103.176
# Policy Loss 0 15709.359
# Policy Loss 0 14865.457
# Policy Loss 0 13764.746
# Policy Loss 0 16232.312
# Policy Loss 0 18587.705
# Policy Loss 0 14721.655
# Policy Loss 0 13517.982
# Policy Loss 0 16090.485
# Policy Loss 0 15111.156
# Policy Loss 0 14409.172
# Policy Loss 0 17573.258
# Policy Loss 0 13274.59
# Policy Loss 0 13136.565
# Policy Loss 0 17851.57
# Policy Loss 0 14514.9375
# Policy Loss 0 18783.43
# Policy Loss 0 14251.497
# Policy Loss 0 17650.969
# Policy Loss 0 14465.658
# Policy Loss 0 14911.195
# Policy Loss 0 15940.793
# Policy Loss 0 16524.564
# Policy Loss 0 14620.789
# Policy Loss 0 14414.291
# Policy Loss 0 13810.437
# Policy Loss 0 14386.551
# Policy Loss 0 15325.584
# Policy Loss 0 16058.38
# Policy Loss 0 15473.764
# Policy Loss 0 15226.339
# Policy Loss 0 15459.645
# Policy Loss 0 14237.996
# Policy Loss 0 15082.75
# Policy Loss 0 16375.929
# Policy Loss 0 15482.0
# Policy Loss 0 16531.234
# Policy Loss 0 17400.988
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb 单元格 14 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         obs = env.reset()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> dqn.set_mode(training=True)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> dqn.update()
#
# /home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb 单元格 14 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=111'>112</a> def update(self):
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=112'>113</a>     for i in range(self.train_steps):
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=113'>114</a>         self._update()
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=114'>115</a>         if self.logger is not None:
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=115'>116</a>             self.logger.step += 1
#
# /home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb 单元格 14 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=140'>141</a>     new_state = np.array(new_state, dtype=np.float) / 255
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=142'>143</a> state = torch.tensor(np.stack(state), dtype=torch.float).detach().to(sett.device)
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=143'>144</a> new_state = torch.tensor(np.stack(new_state), dtype=torch.float).detach().to(sett.device)
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=144'>145</a> action = torch.tensor(action).detach().to(sett.device)
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22506368227d/home/zhx/word/DriverOrderOfflineRL/E-HDQN/src/train_cartpole.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=145'>146</a> reward = torch.tensor(reward, dtype=torch.float).detach().to(sett.device)
#
# KeyboardInterrupt:

# %%
tot_reward = 0
dqn.set_mode(training=False)
obs = env.reset()
while True:
    action = dqn.act(np.array(obs), deterministic=True)
    obs_new, r, is_terminal, info = env.step(action)
    tot_reward += r
    obs = obs_new
    if is_terminal:
        break
print('total_reward', tot_reward)

dqn.set_mode(training=True)
# Out:
# total_reward 10.0

# %% [markdown]
# Training Progress
# total_reward -535.8000000000001
# total_reward -3.3000000000000003
# total_reward -2.3
# total_reward -3.8000000000000003
# total_reward -1.7
